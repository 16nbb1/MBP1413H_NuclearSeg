# %%
import os
import sys
import glob
import random
import warnings
import shutil
from distutils.dir_util import copy_tree


import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

from keras.models import Model, load_model
from keras.layers import Input
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
# from keras.layers.merge import concatenate
from keras.layers import concatenate

from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

import tensorflow as tf
from tensorflow.keras.metrics import Metric

import skimage.io

# %%
# Set some parameters
IMG_WIDTH = 128
IMG_HEIGHT = 128
# IMG_CHANNELS = 3
IMG_CHANNELS = 1

# %%
# the small set for experimentation!
TRAIN_PATH = './FORmodels/trainset_raw/'

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
seed = 42
random.seed = seed
np.random.seed = seed

# Get train and test IDs
train_ids = next(os.walk(TRAIN_PATH))[1]
len(train_ids)
# Out:
# 1809

# %%
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH), dtype=np.bool)
Y_train.shape
# Out:
# /var/folders/qr/np1v1r_53zqc4t2j9qztcrxh0000gn/T/ipykernel_33764/187304916.py:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH), dtype=np.bool)
# (1809, 128, 128)

# %%
# Get and resize train images and masks
X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH), dtype=np.uint8)
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
print('Getting and resizing train images and masks ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    pather = TRAIN_PATH + id_    
    img = imread(pather + '/images/' + id_ + '.png')
    X_train[n] = img
    
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
        
    pattern = pather+'/masks/*'
    for fname in glob.glob(pattern, recursive=True):

        mask_ = imread(fname)     
        mask_ = resize(mask_,(IMG_HEIGHT, IMG_WIDTH, 1))
#         mask_ = np.expand_dims(mask_, axis=1)        
        mask = np.maximum(mask, mask_)
        
    Y_train[n] = mask
# Out:
# Getting and resizing train images and masks ...
# /var/folders/qr/np1v1r_53zqc4t2j9qztcrxh0000gn/T/ipykernel_33764/431872359.py:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
#   0%|                                                  | 0/1809 [00:00<?, ?it/s]/var/folders/qr/np1v1r_53zqc4t2j9qztcrxh0000gn/T/ipykernel_33764/431872359.py:11: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
# 100%|███████████████████████████████████████| 1809/1809 [02:50<00:00, 10.63it/s]

# %%
# Check if training data looks all right
# DOUBLE CHECK MASKS!!
ix = random.randint(0, len(train_ids))

print(ix, train_ids[ix])
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()
# Out:
# 1348 094afe36759e7daffe12188ab5987581d405b06720f1d5acf3f2614f404df380_mirror

# %%
# allowing for hyperparam tuning
import keras_tuner as kt
hp = kt.HyperParameters()

# %%
def model_builder(hp):

    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    s = Lambda(lambda x: x / 255) (inputs)

    c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (s)
    c1 = Dropout(0.1) (c1)
    c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c1)
    p1 = MaxPooling2D((2, 2)) (c1)

    c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p1)
    c2 = Dropout(0.1) (c2)
    c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c2)
    p2 = MaxPooling2D((2, 2)) (c2)

    c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p2)
    c3 = Dropout(0.2) (c3)
    c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c3)
    p3 = MaxPooling2D((2, 2)) (c3)

    c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p3)
    c4 = Dropout(0.2) (c4)
    c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c4)
    p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

    c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p4)
    c5 = Dropout(0.3) (c5)
    c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c5)

    u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c5)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u6)
    c6 = Dropout(0.2) (c6)
    c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c6)

    u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u7)
    c7 = Dropout(0.2) (c7)
    c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c7)

    u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u8)
    c8 = Dropout(0.1) (c8)
    c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c8)

    u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u9)
    c9 = Dropout(0.1) (c9)
    c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c9)

    outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)

    model = Model(inputs=[inputs], outputs=[outputs])

    # here we're using the hyperparam for learning rate!
    model.compile(tf.keras.optimizers.Adam(hp.Float('learning_rate', 1e-4, 1e-2, sampling='log'), amsgrad= True), loss='binary_crossentropy', metrics=tf.keras.metrics.BinaryIoU(target_class_ids=[0, 1], threshold=0.3))

#     model.summary()
    
    return model

# %%
tuner = kt.RandomSearch(
    model_builder,
    objective = kt.Objective("mean_io_u", direction="max"),
    max_trials=5)
# Out:
# INFO:tensorflow:Reloading Tuner from ./untitled_project/tuner0.json

# %%
# TURNING OFF STOP EARLY
tuner.search(X_train, Y_train, epochs=5, validation_split=0.2)

best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"""
The hyperparameter search is complete. The optimal number of units in the first densely-connected
layer is ... and the optimal learning rate for the optimizer
is {best_hps.get('learning_rate')}.
""")
# Out:
# INFO:tensorflow:Oracle triggered exit
#
# The hyperparameter search is complete. The optimal number of units in the first densely-connected
# layer is ... and the optimal learning rate for the optimizer
# is 0.0017991073735913667.

# %%
model = tuner.hypermodel.build(best_hps)
# Out:
# 2023-04-01 14:31:43.248163: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
## ADDING ADVERSARIAL ATTACK...
loss_object = tf.keras.losses.BinaryCrossentropy()

def create_adversarial_pattern(input_image, input_label):
    input_image = tf.convert_to_tensor(np.reshape(input_image, (-1, 128, 128, 1)), dtype=tf.float32)
    input_label = np.reshape(input_label, (-1, 128, 128, 1))

#     Record operations for automatic differentiation??
    with tf.GradientTape() as tape:

        tape.watch(input_image)
        prediction = model(input_image)
        
        loss = loss_object(input_label, prediction)

#   # Get the gradients of the loss w.r.t to the input image.
    gradient = tape.gradient(loss, input_image)

    # Get the sign of the gradients to create the perturbation
    signed_grad = tf.sign(gradient)
    
    return signed_grad

# %%
# Get the input label of the image. -->  THIS NEEDS TO BE A LOOP THROUGH THE IMAGES!!
# WE CAN RANDOMIZE HOW MANY GET A PERTURBATION!!

pert = []

for i in range(len(X_train)):
    pert.append(create_adversarial_pattern(X_train[i],Y_train[i]))

# %%
# making a function for adding peterubation!!!!!
def addingep (ep):
    newtrain = []

    for i in range(len(X_train)): 
        pert[i] = tf.reshape(pert[i], [1, 128, 128])
        new = X_train[i] + ep* pert[i] * 0.5 + 0.5
        newtrain.append(np.squeeze(new.numpy()))

    newtrain = np.asarray(newtrain)
    newtrain = np.squeeze(newtrain)
    
    return newtrain

# %%
# Generates a new X_train
newtrain_2 = addingep(2)

# %%
X_train.shape
# Out:
# (1809, 128, 128)

# %%
newtrain_2.shape
# Out:
# (1809, 128, 128)

# %%
# Let's visualize what we've done here...
# Perform a sanity check on some random training samples
ix = random.randint(0, len(newtrain_2))
print(ix)
imshow(X_train[ix])
plt.title('Raw Image')
plt.show()
imshow(newtrain_2[ix].astype('uint8'))
plt.title('Ep=2 Image')
plt.show()
imshow(np.squeeze(pert[ix]))
plt.title('Ep=2 Perturbation')
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.title('Mask')
plt.show()
# Out:
# 95

# %%
# increasing epoch val to 50!!
# tf.config.run_functions_eagerly(True)
history = model.fit(newtrain_2, Y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 46/46 [==============================] - 64s 1s/step - loss: 0.3077 - binary_io_u: 0.5483 - val_loss: 0.1898 - val_binary_io_u: 0.7611
# Epoch 2/50
# 46/46 [==============================] - 67s 1s/step - loss: 0.1614 - binary_io_u: 0.7732 - val_loss: 0.1536 - val_binary_io_u: 0.8086
# Epoch 3/50
# 46/46 [==============================] - 65s 1s/step - loss: 0.1477 - binary_io_u: 0.7925 - val_loss: 0.1359 - val_binary_io_u: 0.8205
# Epoch 4/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.1316 - binary_io_u: 0.8134 - val_loss: 0.1123 - val_binary_io_u: 0.8395
# Epoch 5/50
# 46/46 [==============================] - 64s 1s/step - loss: 0.1188 - binary_io_u: 0.8305 - val_loss: 0.1068 - val_binary_io_u: 0.8464
# Epoch 6/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.1197 - binary_io_u: 0.8277 - val_loss: 0.1033 - val_binary_io_u: 0.8640
# Epoch 7/50
# 46/46 [==============================] - 64s 1s/step - loss: 0.1078 - binary_io_u: 0.8446 - val_loss: 0.0974 - val_binary_io_u: 0.8676
# Epoch 8/50
# 46/46 [==============================] - 65s 1s/step - loss: 0.0999 - binary_io_u: 0.8523 - val_loss: 0.1013 - val_binary_io_u: 0.8656
# Epoch 9/50
# 46/46 [==============================] - 65s 1s/step - loss: 0.1028 - binary_io_u: 0.8487 - val_loss: 0.0850 - val_binary_io_u: 0.8719
# Epoch 10/50
# 46/46 [==============================] - 66s 1s/step - loss: 0.0938 - binary_io_u: 0.8581 - val_loss: 0.0843 - val_binary_io_u: 0.8753
# Epoch 11/50
# 46/46 [==============================] - 66s 1s/step - loss: 0.0922 - binary_io_u: 0.8613 - val_loss: 0.0874 - val_binary_io_u: 0.8722
# Epoch 12/50
# 46/46 [==============================] - 64s 1s/step - loss: 0.0925 - binary_io_u: 0.8601 - val_loss: 0.0832 - val_binary_io_u: 0.8768
# Epoch 13/50
# 46/46 [==============================] - 67s 1s/step - loss: 0.0900 - binary_io_u: 0.8629 - val_loss: 0.0839 - val_binary_io_u: 0.8707
# Epoch 14/50
# 46/46 [==============================] - 63s 1s/step - loss: 0.0881 - binary_io_u: 0.8652 - val_loss: 0.0822 - val_binary_io_u: 0.8698
# Epoch 15/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0886 - binary_io_u: 0.8653 - val_loss: 0.0819 - val_binary_io_u: 0.8759
# Epoch 16/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0878 - binary_io_u: 0.8660 - val_loss: 0.0827 - val_binary_io_u: 0.8600
# Epoch 17/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0858 - binary_io_u: 0.8683 - val_loss: 0.0852 - val_binary_io_u: 0.8608
# Epoch 18/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0905 - binary_io_u: 0.8628 - val_loss: 0.0799 - val_binary_io_u: 0.8750
# Epoch 19/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0850 - binary_io_u: 0.8703 - val_loss: 0.0771 - val_binary_io_u: 0.8787
# Epoch 20/50
# 46/46 [==============================] - 64s 1s/step - loss: 0.0828 - binary_io_u: 0.8718 - val_loss: 0.0799 - val_binary_io_u: 0.8843
# Epoch 21/50
# 46/46 [==============================] - 65s 1s/step - loss: 0.0825 - binary_io_u: 0.8719 - val_loss: 0.0782 - val_binary_io_u: 0.8880
# Epoch 22/50
# 46/46 [==============================] - 60s 1s/step - loss: 0.0818 - binary_io_u: 0.8740 - val_loss: 0.0785 - val_binary_io_u: 0.8653
# Epoch 23/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.0824 - binary_io_u: 0.8717 - val_loss: 0.0768 - val_binary_io_u: 0.8759
# Epoch 24/50
# 46/46 [==============================] - 63s 1s/step - loss: 0.0838 - binary_io_u: 0.8711 - val_loss: 0.0792 - val_binary_io_u: 0.8716
# Epoch 25/50
# 46/46 [==============================] - 64s 1s/step - loss: 0.0832 - binary_io_u: 0.8713 - val_loss: 0.0789 - val_binary_io_u: 0.8724
# Epoch 26/50
# 46/46 [==============================] - 66s 1s/step - loss: 0.0832 - binary_io_u: 0.8712 - val_loss: 0.0803 - val_binary_io_u: 0.8764
# Epoch 27/50
# 46/46 [==============================] - 65s 1s/step - loss: 0.0817 - binary_io_u: 0.8732 - val_loss: 0.0755 - val_binary_io_u: 0.8742
# Epoch 28/50
# 46/46 [==============================] - 65s 1s/step - loss: 0.0806 - binary_io_u: 0.8738 - val_loss: 0.0776 - val_binary_io_u: 0.8746
# Epoch 29/50
# 46/46 [==============================] - 66s 1s/step - loss: 0.0796 - binary_io_u: 0.8752 - val_loss: 0.0754 - val_binary_io_u: 0.8761
# Epoch 30/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0799 - binary_io_u: 0.8742 - val_loss: 0.0753 - val_binary_io_u: 0.8843
# Epoch 31/50
# 46/46 [==============================] - 64s 1s/step - loss: 0.0804 - binary_io_u: 0.8746 - val_loss: 0.0754 - val_binary_io_u: 0.8887
# Epoch 32/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0784 - binary_io_u: 0.8781 - val_loss: 0.0752 - val_binary_io_u: 0.8764
# Epoch 33/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.0786 - binary_io_u: 0.8768 - val_loss: 0.0754 - val_binary_io_u: 0.8913
# Epoch 34/50
# 46/46 [==============================] - 65s 1s/step - loss: 0.0774 - binary_io_u: 0.8779 - val_loss: 0.0758 - val_binary_io_u: 0.8874
# Epoch 35/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0777 - binary_io_u: 0.8780 - val_loss: 0.0718 - val_binary_io_u: 0.8838
# Epoch 36/50
# 46/46 [==============================] - 63s 1s/step - loss: 0.0766 - binary_io_u: 0.8793 - val_loss: 0.0726 - val_binary_io_u: 0.8876
# Epoch 37/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0769 - binary_io_u: 0.8784 - val_loss: 0.0734 - val_binary_io_u: 0.8870
# Epoch 38/50
# 46/46 [==============================] - 63s 1s/step - loss: 0.0766 - binary_io_u: 0.8785 - val_loss: 0.0707 - val_binary_io_u: 0.8881
# Epoch 39/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0760 - binary_io_u: 0.8790 - val_loss: 0.0712 - val_binary_io_u: 0.8904
# Epoch 40/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0766 - binary_io_u: 0.8785 - val_loss: 0.0720 - val_binary_io_u: 0.8913
# Epoch 41/50
# 46/46 [==============================] - 66s 1s/step - loss: 0.0798 - binary_io_u: 0.8749 - val_loss: 0.0751 - val_binary_io_u: 0.8824
# Epoch 42/50
# 46/46 [==============================] - 65s 1s/step - loss: 0.0774 - binary_io_u: 0.8774 - val_loss: 0.0728 - val_binary_io_u: 0.8871
# Epoch 43/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0748 - binary_io_u: 0.8806 - val_loss: 0.0728 - val_binary_io_u: 0.8886
# Epoch 44/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.0788 - binary_io_u: 0.8763 - val_loss: 0.0807 - val_binary_io_u: 0.8806
# Epoch 45/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0808 - binary_io_u: 0.8758 - val_loss: 0.0713 - val_binary_io_u: 0.8842
# Epoch 46/50
# 46/46 [==============================] - 63s 1s/step - loss: 0.0772 - binary_io_u: 0.8782 - val_loss: 0.0735 - val_binary_io_u: 0.8859
# Epoch 47/50
# 46/46 [==============================] - 65s 1s/step - loss: 0.0775 - binary_io_u: 0.8776 - val_loss: 0.0726 - val_binary_io_u: 0.8905
# Epoch 48/50
# 46/46 [==============================] - 63s 1s/step - loss: 0.0755 - binary_io_u: 0.8798 - val_loss: 0.0714 - val_binary_io_u: 0.8898
# Epoch 49/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0749 - binary_io_u: 0.8807 - val_loss: 0.0771 - val_binary_io_u: 0.8861
# Epoch 50/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0746 - binary_io_u: 0.8815 - val_loss: 0.0712 - val_binary_io_u: 0.8884

# %%
val_acc_per_epoch = history.history['val_binary_io_u']
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Best epoch: 40

# %%
# use the best number of epochs
hypermodel = tuner.hypermodel.build(best_hps)

# FROM = 2023/03/30
# # REMEMBER TO CHANGE THE NAME OF THE MODEL!!
checkpointer = ModelCheckpoint('model-UNetEp=2Model_20230330.h5', verbose=1, save_best_only=True)
# Retrain the model--> USE THE NEW_TRAIN
result = hypermodel.fit(newtrain_2, Y_train, epochs=best_epoch, validation_split=0.2, callbacks=[checkpointer])
# Out:
# Epoch 1/40
# 46/46 [==============================] - ETA: 0s - loss: 0.2648 - binary_io_u_1: 0.6185
# Epoch 1: val_loss improved from inf to 0.13846, saving model to model-UNetEp=2Model_20230330.h5
# 46/46 [==============================] - 64s 1s/step - loss: 0.2648 - binary_io_u_1: 0.6185 - val_loss: 0.1385 - val_binary_io_u_1: 0.8007
# Epoch 2/40
# 46/46 [==============================] - ETA: 0s - loss: 0.1527 - binary_io_u_1: 0.7839
# Epoch 2: val_loss improved from 0.13846 to 0.11925, saving model to model-UNetEp=2Model_20230330.h5
# 46/46 [==============================] - 63s 1s/step - loss: 0.1527 - binary_io_u_1: 0.7839 - val_loss: 0.1193 - val_binary_io_u_1: 0.8187
# Epoch 3/40
# 46/46 [==============================] - ETA: 0s - loss: 0.1257 - binary_io_u_1: 0.8207
# Epoch 3: val_loss improved from 0.11925 to 0.10372, saving model to model-UNetEp=2Model_20230330.h5
# 46/46 [==============================] - 62s 1s/step - loss: 0.1257 - binary_io_u_1: 0.8207 - val_loss: 0.1037 - val_binary_io_u_1: 0.8409
# Epoch 4/40
# 46/46 [==============================] - ETA: 0s - loss: 0.1146 - binary_io_u_1: 0.8347
# Epoch 4: val_loss did not improve from 0.10372
# 46/46 [==============================] - 64s 1s/step - loss: 0.1146 - binary_io_u_1: 0.8347 - val_loss: 0.1111 - val_binary_io_u_1: 0.8190
# Epoch 5/40
# 46/46 [==============================] - ETA: 0s - loss: 0.1110 - binary_io_u_1: 0.8375
# Epoch 5: val_loss improved from 0.10372 to 0.09979, saving model to model-UNetEp=2Model_20230330.h5
# 46/46 [==============================] - 62s 1s/step - loss: 0.1110 - binary_io_u_1: 0.8375 - val_loss: 0.0998 - val_binary_io_u_1: 0.8622
# Epoch 6/40
# 46/46 [==============================] - ETA: 0s - loss: 0.1025 - binary_io_u_1: 0.8495
# Epoch 6: val_loss did not improve from 0.09979
# 46/46 [==============================] - 63s 1s/step - loss: 0.1025 - binary_io_u_1: 0.8495 - val_loss: 0.1023 - val_binary_io_u_1: 0.8509
# Epoch 7/40
# 46/46 [==============================] - ETA: 0s - loss: 0.1019 - binary_io_u_1: 0.8503
# Epoch 7: val_loss improved from 0.09979 to 0.08868, saving model to model-UNetEp=2Model_20230330.h5
# 46/46 [==============================] - 64s 1s/step - loss: 0.1019 - binary_io_u_1: 0.8503 - val_loss: 0.0887 - val_binary_io_u_1: 0.8593
# Epoch 8/40
# 46/46 [==============================] - ETA: 0s - loss: 0.0970 - binary_io_u_1: 0.8558
# Epoch 8: val_loss improved from 0.08868 to 0.08483, saving model to model-UNetEp=2Model_20230330.h5
# 46/46 [==============================] - 65s 1s/step - loss: 0.0970 - binary_io_u_1: 0.8558 - val_loss: 0.0848 - val_binary_io_u_1: 0.8735
# Epoch 9/40
# 46/46 [==============================] - ETA: 0s - loss: 0.0956 - binary_io_u_1: 0.8563
# Epoch 9: val_loss did not improve from 0.08483
# 46/46 [==============================] - 64s 1s/step - loss: 0.0956 - binary_io_u_1: 0.8563 - val_loss: 0.0860 - val_binary_io_u_1: 0.8608
# Epoch 10/40
# 46/46 [==============================] - ETA: 0s - loss: 0.0926 - binary_io_u_1: 0.8595
# Epoch 10: val_loss improved from 0.08483 to 0.08378, saving model to model-UNetEp=2Model_20230330.h5
# 46/46 [==============================] - 63s 1s/step - loss: 0.0926 - binary_io_u_1: 0.8595 - val_loss: 0.0838 - val_binary_io_u_1: 0.8769
# Epoch 11/40
# 46/46 [==============================] - ETA: 0s - loss: 0.0928 - binary_io_u_1: 0.8595
# Epoch 11: val_loss did not improve from 0.08378
# 46/46 [==============================] - 64s 1s/step - loss: 0.0928 - binary_io_u_1: 0.8595 - val_loss: 0.0845 - val_binary_io_u_1: 0.8685
# Epoch 12/40
# 46/46 [==============================] - ETA: 0s - loss: 0.1016 - binary_io_u_1: 0.8493
# Epoch 12: val_loss did not improve from 0.08378
# 46/46 [==============================] - 61s 1s/step - loss: 0.1016 - binary_io_u_1: 0.8493 - val_loss: 0.0857 - val_binary_io_u_1: 0.8707
# Epoch 13/40
# 46/46 [==============================] - ETA: 0s - loss: 0.0930 - binary_io_u_1: 0.8602
# Epoch 13: val_loss did not improve from 0.08378
# 46/46 [==============================] - 63s 1s/step - loss: 0.0930 - binary_io_u_1: 0.8602 - val_loss: 0.0838 - val_binary_io_u_1: 0.8649
# Epoch 14/40
# 46/46 [==============================] - ETA: 0s - loss: 0.0985 - binary_io_u_1: 0.8544
# Epoch 14: val_loss did not improve from 0.08378
# 46/46 [==============================] - 62s 1s/step - loss: 0.0985 - binary_io_u_1: 0.8544 - val_loss: 0.0895 - val_binary_io_u_1: 0.8571
# Epoch 15/40
# 46/46 [==============================] - ETA: 0s - loss: 0.0947 - binary_io_u_1: 0.8574
# Epoch 15: val_loss did not improve from 0.08378
# 46/46 [==============================] - 62s 1s/step - loss: 0.0947 - binary_io_u_1: 0.8574 - val_loss: 0.0848 - val_binary_io_u_1: 0.8617
# Epoch 16/40
# 46/46 [==============================] - ETA: 0s - loss: 0.0882 - binary_io_u_1: 0.8636
# Epoch 16: val_loss improved from 0.08378 to 0.08114, saving model to model-UNetEp=2Model_20230330.h5
# 46/46 [==============================] - 62s 1s/step - loss: 0.0882 - binary_io_u_1: 0.8636 - val_loss: 0.0811 - val_binary_io_u_1: 0.8747
# Epoch 17/40
# 46/46 [==============================] - ETA: 0s - loss: 0.0890 - binary_io_u_1: 0.8634
# Epoch 17: val_loss did not improve from 0.08114
# 46/46 [==============================] - 62s 1s/step - loss: 0.0890 - binary_io_u_1: 0.8634 - val_loss: 0.0925 - val_binary_io_u_1: 0.8640
# Epoch 18/40
# 46/46 [==============================] - ETA: 0s - loss: 0.0873 - binary_io_u_1: 0.8664
# Epoch 18: val_loss improved from 0.08114 to 0.08109, saving model to model-UNetEp=2Model_20230330.h5
# 46/46 [==============================] - 64s 1s/step - loss: 0.0873 - binary_io_u_1: 0.8664 - val_loss: 0.0811 - val_binary_io_u_1: 0.8739
# Epoch 19/40
# 46/46 [==============================] - ETA: 0s - loss: 0.0844 - binary_io_u_1: 0.8694
# Epoch 19: val_loss improved from 0.08109 to 0.07811, saving model to model-UNetEp=2Model_20230330.h5
# 46/46 [==============================] - 62s 1s/step - loss: 0.0844 - binary_io_u_1: 0.8694 - val_loss: 0.0781 - val_binary_io_u_1: 0.8747
# Epoch 20/40
# 46/46 [==============================] - ETA: 0s - loss: 0.0835 - binary_io_u_1: 0.8703
# Epoch 20: val_loss did not improve from 0.07811
# 46/46 [==============================] - 62s 1s/step - loss: 0.0835 - binary_io_u_1: 0.8703 - val_loss: 0.0819 - val_binary_io_u_1: 0.8860
# Epoch 21/40
# 46/46 [==============================] - ETA: 0s - loss: 0.0854 - binary_io_u_1: 0.8677
# Epoch 21: val_loss did not improve from 0.07811
# 46/46 [==============================] - 62s 1s/step - loss: 0.0854 - binary_io_u_1: 0.8677 - val_loss: 0.0788 - val_binary_io_u_1: 0.8849
# Epoch 22/40
# 46/46 [==============================] - ETA: 0s - loss: 0.0841 - binary_io_u_1: 0.8708
# Epoch 22: val_loss improved from 0.07811 to 0.07758, saving model to model-UNetEp=2Model_20230330.h5
# 46/46 [==============================] - 62s 1s/step - loss: 0.0841 - binary_io_u_1: 0.8708 - val_loss: 0.0776 - val_binary_io_u_1: 0.8796
# Epoch 23/40
# 46/46 [==============================] - ETA: 0s - loss: 0.0826 - binary_io_u_1: 0.8713
# Epoch 23: val_loss improved from 0.07758 to 0.07715, saving model to model-UNetEp=2Model_20230330.h5
# 46/46 [==============================] - 63s 1s/step - loss: 0.0826 - binary_io_u_1: 0.8713 - val_loss: 0.0771 - val_binary_io_u_1: 0.8775
# Epoch 24/40
# 46/46 [==============================] - ETA: 0s - loss: 0.0813 - binary_io_u_1: 0.8732
# Epoch 24: val_loss improved from 0.07715 to 0.07574, saving model to model-UNetEp=2Model_20230330.h5
# 46/46 [==============================] - 63s 1s/step - loss: 0.0813 - binary_io_u_1: 0.8732 - val_loss: 0.0757 - val_binary_io_u_1: 0.8737
# Epoch 25/40
# 46/46 [==============================] - ETA: 0s - loss: 0.0819 - binary_io_u_1: 0.8729
# Epoch 25: val_loss did not improve from 0.07574
# 46/46 [==============================] - 62s 1s/step - loss: 0.0819 - binary_io_u_1: 0.8729 - val_loss: 0.0762 - val_binary_io_u_1: 0.8782
# Epoch 26/40
# 46/46 [==============================] - ETA: 0s - loss: 0.0806 - binary_io_u_1: 0.8736
# Epoch 26: val_loss did not improve from 0.07574
# 46/46 [==============================] - 62s 1s/step - loss: 0.0806 - binary_io_u_1: 0.8736 - val_loss: 0.0858 - val_binary_io_u_1: 0.8759
# Epoch 27/40
# 46/46 [==============================] - ETA: 0s - loss: 0.0818 - binary_io_u_1: 0.8725
# Epoch 27: val_loss did not improve from 0.07574
# 46/46 [==============================] - 64s 1s/step - loss: 0.0818 - binary_io_u_1: 0.8725 - val_loss: 0.0772 - val_binary_io_u_1: 0.8809
# Epoch 28/40
# 46/46 [==============================] - ETA: 0s - loss: 0.0819 - binary_io_u_1: 0.8729
# Epoch 28: val_loss did not improve from 0.07574
# 46/46 [==============================] - 63s 1s/step - loss: 0.0819 - binary_io_u_1: 0.8729 - val_loss: 0.0790 - val_binary_io_u_1: 0.8717
# Epoch 29/40
# 46/46 [==============================] - ETA: 0s - loss: 0.0847 - binary_io_u_1: 0.8706
# Epoch 29: val_loss did not improve from 0.07574
# 46/46 [==============================] - 61s 1s/step - loss: 0.0847 - binary_io_u_1: 0.8706 - val_loss: 0.0775 - val_binary_io_u_1: 0.8727
# Epoch 30/40
# 46/46 [==============================] - ETA: 0s - loss: 0.0809 - binary_io_u_1: 0.8729
# Epoch 30: val_loss improved from 0.07574 to 0.07382, saving model to model-UNetEp=2Model_20230330.h5
# 46/46 [==============================] - 62s 1s/step - loss: 0.0809 - binary_io_u_1: 0.8729 - val_loss: 0.0738 - val_binary_io_u_1: 0.8809
# Epoch 31/40
# 46/46 [==============================] - ETA: 0s - loss: 0.0815 - binary_io_u_1: 0.8731
# Epoch 31: val_loss did not improve from 0.07382
# 46/46 [==============================] - 63s 1s/step - loss: 0.0815 - binary_io_u_1: 0.8731 - val_loss: 0.0792 - val_binary_io_u_1: 0.8818
# Epoch 32/40
# 46/46 [==============================] - ETA: 0s - loss: 0.0804 - binary_io_u_1: 0.8741
# Epoch 32: val_loss did not improve from 0.07382
# 46/46 [==============================] - 62s 1s/step - loss: 0.0804 - binary_io_u_1: 0.8741 - val_loss: 0.0758 - val_binary_io_u_1: 0.8831
# Epoch 33/40
# 46/46 [==============================] - ETA: 0s - loss: 0.0796 - binary_io_u_1: 0.8754
# Epoch 33: val_loss did not improve from 0.07382
# 46/46 [==============================] - 64s 1s/step - loss: 0.0796 - binary_io_u_1: 0.8754 - val_loss: 0.0792 - val_binary_io_u_1: 0.8765
# Epoch 34/40
# 46/46 [==============================] - ETA: 0s - loss: 0.0801 - binary_io_u_1: 0.8746
# Epoch 34: val_loss did not improve from 0.07382
# 46/46 [==============================] - 63s 1s/step - loss: 0.0801 - binary_io_u_1: 0.8746 - val_loss: 0.0766 - val_binary_io_u_1: 0.8863
# Epoch 35/40
# 46/46 [==============================] - ETA: 0s - loss: 0.0790 - binary_io_u_1: 0.8763
# Epoch 35: val_loss did not improve from 0.07382
# 46/46 [==============================] - 62s 1s/step - loss: 0.0790 - binary_io_u_1: 0.8763 - val_loss: 0.0745 - val_binary_io_u_1: 0.8837
# Epoch 36/40
# 46/46 [==============================] - ETA: 0s - loss: 0.0788 - binary_io_u_1: 0.8761
# Epoch 36: val_loss did not improve from 0.07382
# 46/46 [==============================] - 62s 1s/step - loss: 0.0788 - binary_io_u_1: 0.8761 - val_loss: 0.0761 - val_binary_io_u_1: 0.8879
# Epoch 37/40
# 46/46 [==============================] - ETA: 0s - loss: 0.0783 - binary_io_u_1: 0.8765
# Epoch 37: val_loss improved from 0.07382 to 0.07221, saving model to model-UNetEp=2Model_20230330.h5
# 46/46 [==============================] - 62s 1s/step - loss: 0.0783 - binary_io_u_1: 0.8765 - val_loss: 0.0722 - val_binary_io_u_1: 0.8827
# Epoch 38/40
# 46/46 [==============================] - ETA: 0s - loss: 0.0768 - binary_io_u_1: 0.8777
# Epoch 38: val_loss did not improve from 0.07221
# 46/46 [==============================] - 62s 1s/step - loss: 0.0768 - binary_io_u_1: 0.8777 - val_loss: 0.0739 - val_binary_io_u_1: 0.8855
# Epoch 39/40
# 46/46 [==============================] - ETA: 0s - loss: 0.0768 - binary_io_u_1: 0.8777
# Epoch 39: val_loss did not improve from 0.07221
# 46/46 [==============================] - 62s 1s/step - loss: 0.0768 - binary_io_u_1: 0.8777 - val_loss: 0.0725 - val_binary_io_u_1: 0.8885
# Epoch 40/40
# 46/46 [==============================] - ETA: 0s - loss: 0.0781 - binary_io_u_1: 0.8768
# Epoch 40: val_loss did not improve from 0.07221
# 46/46 [==============================] - 65s 1s/step - loss: 0.0781 - binary_io_u_1: 0.8768 - val_loss: 0.0742 - val_binary_io_u_1: 0.8790

# %%
# ALTER THE NAMING CONVENTIONS..
def plot_training(hist):
    '''
    This function take training model and plot history of accuracy and losses with the best epoch in both of them.
    '''

    # Define needed variables--> these two need to be diff
    tr_acc = hist.history['binary_io_u_1']
    tr_loss = hist.history['loss']
    val_acc = hist.history['val_binary_io_u_1']
    val_loss = hist.history['val_loss']
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]
    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'

    # Plot training history
    plt.figure(figsize= (20, 8))
    plt.style.use('fivethirtyeight')

    plt.subplot(1, 2, 1)
    plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
    plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
    plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training and Validation Binary IOU')
    plt.xlabel('Epochs')
    plt.ylabel('Binary IOU')
    plt.legend()

    # change the title!!
    plt.suptitle("Unet trained with Ep =2", fontsize=30)
    plt.tight_layout
    plt.savefig('model-UNetEp=2Model_20230330.png')
    plt.show()

# %%
# results.history
plot_training(result)

# %%
# we could stop here...
