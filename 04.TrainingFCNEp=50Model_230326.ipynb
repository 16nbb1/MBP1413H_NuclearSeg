# %%
import os
import sys
import glob
import random
import warnings
import shutil
from distutils.dir_util import copy_tree


import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
# from keras.layers.merge import concatenate
from keras.layers import concatenate

from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

import tensorflow as tf
from tensorflow.keras.metrics import Metric

import skimage.io

# %%
# Set some parameters
IMG_WIDTH = 128
IMG_HEIGHT = 128
# IMG_CHANNELS = 3
IMG_CHANNELS = 1

# %%
# the small set for experimentation!
TRAIN_PATH = './FORmodels/trainset_raw/'

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
seed = 42
random.seed = seed
np.random.seed = seed

# Get train and test IDs
train_ids = next(os.walk(TRAIN_PATH))[1]
len(train_ids)
# Out:
# 1809

# %%
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH), dtype=np.bool)
Y_train.shape
# Out:
# /var/folders/qr/np1v1r_53zqc4t2j9qztcrxh0000gn/T/ipykernel_72446/187304916.py:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH), dtype=np.bool)
# (1809, 128, 128)

# %%
# Get and resize train images and masks
X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH), dtype=np.uint8)
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
print('Getting and resizing train images and masks ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    pather = TRAIN_PATH + id_    
    img = imread(pather + '/images/' + id_ + '.png')
    X_train[n] = img
    
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
        
    pattern = pather+'/masks/*'
    for fname in glob.glob(pattern, recursive=True):

        mask_ = imread(fname)     
        mask_ = resize(mask_,(IMG_HEIGHT, IMG_WIDTH, 1))
#         mask_ = np.expand_dims(mask_, axis=1)        
        mask = np.maximum(mask, mask_)
        
    Y_train[n] = mask
# Out:
# Getting and resizing train images and masks ...
# /var/folders/qr/np1v1r_53zqc4t2j9qztcrxh0000gn/T/ipykernel_72446/431872359.py:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
#   0%|                                                  | 0/1809 [00:00<?, ?it/s]/var/folders/qr/np1v1r_53zqc4t2j9qztcrxh0000gn/T/ipykernel_72446/431872359.py:11: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
# 100%|███████████████████████████████████████| 1809/1809 [02:43<00:00, 11.06it/s]

# %%
# Check if training data looks all right
# DOUBLE CHECK MASKS!!
ix = random.randint(0, len(train_ids))

print(ix, train_ids[ix])
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()
# Out:
# 108 2e2d29fc44444a85049b162eb359a523dec108ccd5bd75022b25547491abf0c7_mirror

# %%
# allowing for hyperparam tuning
import keras_tuner as kt
hp = kt.HyperParameters()

# %%
def model_builder(hp):

    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))

    output_1 = Dense(64, activation='relu')(inputs)
    output_2 = Dense(64, activation='relu')(output_1)
    outputs = Dense(1, activation='sigmoid')(output_2)

    model = Model(inputs=[inputs], outputs=[outputs])

    # here we're using the hyperparam for learning rate!
    model.compile(tf.keras.optimizers.Adam(hp.Float('learning_rate', 1e-4, 1e-2, sampling='log'), amsgrad= True), loss='binary_crossentropy', metrics=tf.keras.metrics.BinaryIoU(target_class_ids=[0, 1], threshold=0.3))

#     model.summary()
    
    return model

# %%
tuner = kt.RandomSearch(
    model_builder,
    objective = kt.Objective("mean_io_u", direction="max"),
    max_trials=5)
# Out:
# INFO:tensorflow:Reloading Tuner from ./untitled_project/tuner0.json

# %%
# TURNING OFF STOP EARLY
tuner.search(X_train, Y_train, epochs=5, validation_split=0.2)

best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"""
The hyperparameter search is complete. The optimal number of units in the first densely-connected
layer is ... and the optimal learning rate for the optimizer
is {best_hps.get('learning_rate')}.
""")
# Out:
# INFO:tensorflow:Oracle triggered exit
#
# The hyperparameter search is complete. The optimal number of units in the first densely-connected
# layer is ... and the optimal learning rate for the optimizer
# is 0.0008259900546842376.

# %%
model = tuner.hypermodel.build(best_hps)
# Out:
# 2023-03-30 11:59:06.487134: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
## ADDING ADVERSARIAL ATTACK...
loss_object = tf.keras.losses.BinaryCrossentropy()

def create_adversarial_pattern(input_image, input_label):
    input_image = tf.convert_to_tensor(np.reshape(input_image, (-1, 128, 128, 1)), dtype=tf.float32)
    input_label = np.reshape(input_label, (-1, 128, 128, 1))

#     Record operations for automatic differentiation??
    with tf.GradientTape() as tape:

        tape.watch(input_image)
        prediction = model(input_image)
        
        loss = loss_object(input_label, prediction)

#   # Get the gradients of the loss w.r.t to the input image.
    gradient = tape.gradient(loss, input_image)

    # Get the sign of the gradients to create the perturbation
    signed_grad = tf.sign(gradient)
    
    return signed_grad

# %%
# Get the input label of the image. -->  THIS NEEDS TO BE A LOOP THROUGH THE IMAGES!!
# WE CAN RANDOMIZE HOW MANY GET A PERTURBATION!!

pert = []

for i in range(len(X_train)):
    pert.append(create_adversarial_pattern(X_train[i],Y_train[i]))

# %%
# making a function for adding peterubation!!!!!
def addingep (ep):
    newtrain = []

    for i in range(len(X_train)): 
        pert[i] = tf.reshape(pert[i], [1, 128, 128])
        new = X_train[i] + ep* pert[i] * 0.5 + 0.5
        newtrain.append(np.squeeze(new.numpy()))

    newtrain = np.asarray(newtrain)
    newtrain = np.squeeze(newtrain)
    
    return newtrain

# %%
# Generates a new X_train
newtrain_50 = addingep(50)

# %%
X_train.shape
# Out:
# (1809, 128, 128)

# %%
newtrain_50.shape
# Out:
# (1809, 128, 128)

# %%
# Let's visualize what we've done here...
# Perform a sanity check on some random training samples
ix = random.randint(0, len(newtrain_50))
print(ix)
imshow(X_train[ix])
plt.title('Raw Image')
plt.show()
imshow(newtrain_50[ix].astype('uint8'))
plt.title('Epsilon=0 Image')
plt.show()
imshow(np.squeeze(pert[ix]))
plt.title('Ep=2 Perturbation')
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.title('Mask')
plt.show()
# Out:
# 990

# %%
# increasing epoch val to 50!!
history = model.fit(newtrain_50, Y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 46/46 [==============================] - 7s 143ms/step - loss: 0.5971 - binary_io_u: 0.4298 - val_loss: 0.2980 - val_binary_io_u: 0.5079
# Epoch 2/50
# 46/46 [==============================] - 6s 136ms/step - loss: 0.3237 - binary_io_u: 0.4842 - val_loss: 0.3348 - val_binary_io_u: 0.5116
# Epoch 3/50
# 46/46 [==============================] - 6s 139ms/step - loss: 0.3202 - binary_io_u: 0.4886 - val_loss: 0.2856 - val_binary_io_u: 0.5116
# Epoch 4/50
# 46/46 [==============================] - 7s 144ms/step - loss: 0.3063 - binary_io_u: 0.4926 - val_loss: 0.3478 - val_binary_io_u: 0.3597
# Epoch 5/50
# 46/46 [==============================] - 6s 134ms/step - loss: 0.3919 - binary_io_u: 0.4680 - val_loss: 0.2811 - val_binary_io_u: 0.5180
# Epoch 6/50
# 46/46 [==============================] - 6s 131ms/step - loss: 0.2776 - binary_io_u: 0.5873 - val_loss: 0.2516 - val_binary_io_u: 0.6418
# Epoch 7/50
# 46/46 [==============================] - 6s 132ms/step - loss: 0.2712 - binary_io_u: 0.6053 - val_loss: 0.2462 - val_binary_io_u: 0.6611
# Epoch 8/50
# 46/46 [==============================] - 6s 133ms/step - loss: 0.2476 - binary_io_u: 0.6568 - val_loss: 0.3013 - val_binary_io_u: 0.6756
# Epoch 9/50
# 46/46 [==============================] - 6s 133ms/step - loss: 0.2496 - binary_io_u: 0.6435 - val_loss: 0.2719 - val_binary_io_u: 0.4949
# Epoch 10/50
# 46/46 [==============================] - 6s 134ms/step - loss: 0.2776 - binary_io_u: 0.6232 - val_loss: 0.3314 - val_binary_io_u: 0.4239
# Epoch 11/50
# 46/46 [==============================] - 6s 134ms/step - loss: 0.2557 - binary_io_u: 0.6430 - val_loss: 0.2169 - val_binary_io_u: 0.7604
# Epoch 12/50
# 46/46 [==============================] - 6s 131ms/step - loss: 0.2185 - binary_io_u: 0.6740 - val_loss: 0.2006 - val_binary_io_u: 0.6858
# Epoch 13/50
# 46/46 [==============================] - 6s 135ms/step - loss: 0.2222 - binary_io_u: 0.6828 - val_loss: 0.1939 - val_binary_io_u: 0.6852
# Epoch 14/50
# 46/46 [==============================] - 6s 133ms/step - loss: 0.2096 - binary_io_u: 0.6908 - val_loss: 0.1916 - val_binary_io_u: 0.6861
# Epoch 15/50
# 46/46 [==============================] - 6s 136ms/step - loss: 0.2123 - binary_io_u: 0.7053 - val_loss: 0.1823 - val_binary_io_u: 0.6865
# Epoch 16/50
# 46/46 [==============================] - 6s 134ms/step - loss: 0.1944 - binary_io_u: 0.6947 - val_loss: 0.1929 - val_binary_io_u: 0.7957
# Epoch 17/50
# 46/46 [==============================] - 6s 135ms/step - loss: 0.1932 - binary_io_u: 0.7056 - val_loss: 0.1865 - val_binary_io_u: 0.6865
# Epoch 18/50
# 46/46 [==============================] - 6s 139ms/step - loss: 0.2048 - binary_io_u: 0.7016 - val_loss: 0.1729 - val_binary_io_u: 0.6856
# Epoch 19/50
# 46/46 [==============================] - 6s 134ms/step - loss: 0.1968 - binary_io_u: 0.7037 - val_loss: 0.2072 - val_binary_io_u: 0.7359
# Epoch 20/50
# 46/46 [==============================] - 6s 137ms/step - loss: 0.2014 - binary_io_u: 0.6889 - val_loss: 0.1666 - val_binary_io_u: 0.6851
# Epoch 21/50
# 46/46 [==============================] - 6s 134ms/step - loss: 0.1989 - binary_io_u: 0.6913 - val_loss: 0.1776 - val_binary_io_u: 0.6862
# Epoch 22/50
# 46/46 [==============================] - 6s 134ms/step - loss: 0.1826 - binary_io_u: 0.7092 - val_loss: 0.1764 - val_binary_io_u: 0.6858
# Epoch 23/50
# 46/46 [==============================] - 6s 134ms/step - loss: 0.1799 - binary_io_u: 0.7154 - val_loss: 0.1606 - val_binary_io_u: 0.8078
# Epoch 24/50
# 46/46 [==============================] - 6s 136ms/step - loss: 0.1757 - binary_io_u: 0.7221 - val_loss: 0.1579 - val_binary_io_u: 0.6805
# Epoch 25/50
# 46/46 [==============================] - 6s 138ms/step - loss: 0.1755 - binary_io_u: 0.7161 - val_loss: 0.1559 - val_binary_io_u: 0.7469
# Epoch 26/50
# 46/46 [==============================] - 7s 146ms/step - loss: 0.1767 - binary_io_u: 0.7206 - val_loss: 0.1742 - val_binary_io_u: 0.7928
# Epoch 27/50
# 46/46 [==============================] - 6s 141ms/step - loss: 0.1732 - binary_io_u: 0.7288 - val_loss: 0.1526 - val_binary_io_u: 0.7621
# Epoch 28/50
# 46/46 [==============================] - 7s 146ms/step - loss: 0.1731 - binary_io_u: 0.7144 - val_loss: 0.1722 - val_binary_io_u: 0.7943
# Epoch 29/50
# 46/46 [==============================] - 6s 138ms/step - loss: 0.1782 - binary_io_u: 0.7160 - val_loss: 0.1751 - val_binary_io_u: 0.7863
# Epoch 30/50
# 46/46 [==============================] - 7s 142ms/step - loss: 0.1845 - binary_io_u: 0.7137 - val_loss: 0.1771 - val_binary_io_u: 0.7828
# Epoch 31/50
# 46/46 [==============================] - 6s 137ms/step - loss: 0.1711 - binary_io_u: 0.7268 - val_loss: 0.1506 - val_binary_io_u: 0.6808
# Epoch 32/50
# 46/46 [==============================] - 6s 134ms/step - loss: 0.1663 - binary_io_u: 0.7339 - val_loss: 0.1654 - val_binary_io_u: 0.8017
# Epoch 33/50
# 46/46 [==============================] - 6s 138ms/step - loss: 0.1723 - binary_io_u: 0.7327 - val_loss: 0.1620 - val_binary_io_u: 0.6865
# Epoch 34/50
# 46/46 [==============================] - 6s 133ms/step - loss: 0.1674 - binary_io_u: 0.7365 - val_loss: 0.1656 - val_binary_io_u: 0.6862
# Epoch 35/50
# 46/46 [==============================] - 6s 132ms/step - loss: 0.1818 - binary_io_u: 0.7158 - val_loss: 0.2449 - val_binary_io_u: 0.6852
# Epoch 36/50
# 46/46 [==============================] - 6s 139ms/step - loss: 0.2139 - binary_io_u: 0.6982 - val_loss: 0.1620 - val_binary_io_u: 0.8009
# Epoch 37/50
# 46/46 [==============================] - 6s 135ms/step - loss: 0.1997 - binary_io_u: 0.7072 - val_loss: 0.1719 - val_binary_io_u: 0.7863
# Epoch 38/50
# 46/46 [==============================] - 6s 136ms/step - loss: 0.1606 - binary_io_u: 0.7570 - val_loss: 0.1594 - val_binary_io_u: 0.8050
# Epoch 39/50
# 46/46 [==============================] - 6s 134ms/step - loss: 0.1608 - binary_io_u: 0.7485 - val_loss: 0.1576 - val_binary_io_u: 0.8048
# Epoch 40/50
# 46/46 [==============================] - 6s 137ms/step - loss: 0.1623 - binary_io_u: 0.7501 - val_loss: 0.1446 - val_binary_io_u: 0.6780
# Epoch 41/50
# 46/46 [==============================] - 6s 137ms/step - loss: 0.1561 - binary_io_u: 0.7649 - val_loss: 0.1478 - val_binary_io_u: 0.8190
# Epoch 42/50
# 46/46 [==============================] - 6s 135ms/step - loss: 0.1613 - binary_io_u: 0.7492 - val_loss: 0.1438 - val_binary_io_u: 0.6777
# Epoch 43/50
# 46/46 [==============================] - 6s 135ms/step - loss: 0.1823 - binary_io_u: 0.7267 - val_loss: 0.1396 - val_binary_io_u: 0.7565
# Epoch 44/50
# 46/46 [==============================] - 6s 133ms/step - loss: 0.1546 - binary_io_u: 0.7577 - val_loss: 0.1485 - val_binary_io_u: 0.6823
# Epoch 45/50
# 46/46 [==============================] - 6s 138ms/step - loss: 0.1575 - binary_io_u: 0.7525 - val_loss: 0.1932 - val_binary_io_u: 0.7606
# Epoch 46/50
# 46/46 [==============================] - 6s 133ms/step - loss: 0.1674 - binary_io_u: 0.7351 - val_loss: 0.1382 - val_binary_io_u: 0.7828
# Epoch 47/50
# 46/46 [==============================] - 6s 132ms/step - loss: 0.1585 - binary_io_u: 0.7534 - val_loss: 0.1388 - val_binary_io_u: 0.8236
# Epoch 48/50
# 46/46 [==============================] - 6s 137ms/step - loss: 0.1675 - binary_io_u: 0.7320 - val_loss: 0.1403 - val_binary_io_u: 0.8254
# Epoch 49/50
# 46/46 [==============================] - 6s 139ms/step - loss: 0.1682 - binary_io_u: 0.7430 - val_loss: 0.1405 - val_binary_io_u: 0.6951
# Epoch 50/50
# 46/46 [==============================] - 6s 136ms/step - loss: 0.1538 - binary_io_u: 0.7643 - val_loss: 0.1560 - val_binary_io_u: 0.6844

# %%
val_acc_per_epoch = history.history['val_binary_io_u']
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Best epoch: 48

# %%
# use the best number of epochs
hypermodel = tuner.hypermodel.build(best_hps)

# FROM = 2023/03/30
# # REMEMBER TO CHANGE THE NAME OF THE MODEL!!
checkpointer = ModelCheckpoint('model-FCNEp=50Model_20230330.h5', verbose=1, save_best_only=True)
# Retrain the model--> USE THE NEW_TRAIN
result = hypermodel.fit(newtrain_50, Y_train, epochs=best_epoch, validation_split=0.2, callbacks=[checkpointer])
# Out:
# Epoch 1/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.3481 - binary_io_u_1: 0.5010
# Epoch 1: val_loss improved from inf to 0.29570, saving model to model-FCNEp=50Model_20230330.h5
# 46/46 [==============================] - 7s 137ms/step - loss: 0.3481 - binary_io_u_1: 0.5010 - val_loss: 0.2957 - val_binary_io_u_1: 0.5100
# Epoch 2/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.3019 - binary_io_u_1: 0.5163
# Epoch 2: val_loss improved from 0.29570 to 0.28960, saving model to model-FCNEp=50Model_20230330.h5
# 46/46 [==============================] - 6s 133ms/step - loss: 0.3018 - binary_io_u_1: 0.5163 - val_loss: 0.2896 - val_binary_io_u_1: 0.5116
# Epoch 3/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.2929 - binary_io_u_1: 0.5038
# Epoch 3: val_loss improved from 0.28960 to 0.26802, saving model to model-FCNEp=50Model_20230330.h5
# 46/46 [==============================] - 6s 137ms/step - loss: 0.2930 - binary_io_u_1: 0.5047 - val_loss: 0.2680 - val_binary_io_u_1: 0.5143
# Epoch 4/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.2836 - binary_io_u_1: 0.5669
# Epoch 4: val_loss did not improve from 0.26802
# 46/46 [==============================] - 6s 141ms/step - loss: 0.2830 - binary_io_u_1: 0.5671 - val_loss: 0.3031 - val_binary_io_u_1: 0.4460
# Epoch 5/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.2850 - binary_io_u_1: 0.6171
# Epoch 5: val_loss improved from 0.26802 to 0.23135, saving model to model-FCNEp=50Model_20230330.h5
# 46/46 [==============================] - 6s 137ms/step - loss: 0.2853 - binary_io_u_1: 0.6157 - val_loss: 0.2314 - val_binary_io_u_1: 0.7640
# Epoch 6/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.2453 - binary_io_u_1: 0.6627
# Epoch 6: val_loss improved from 0.23135 to 0.21306, saving model to model-FCNEp=50Model_20230330.h5
# 46/46 [==============================] - 6s 134ms/step - loss: 0.2452 - binary_io_u_1: 0.6625 - val_loss: 0.2131 - val_binary_io_u_1: 0.6869
# Epoch 7/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.2456 - binary_io_u_1: 0.6530
# Epoch 7: val_loss improved from 0.21306 to 0.20565, saving model to model-FCNEp=50Model_20230330.h5
# 46/46 [==============================] - 6s 134ms/step - loss: 0.2458 - binary_io_u_1: 0.6531 - val_loss: 0.2056 - val_binary_io_u_1: 0.6854
# Epoch 8/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.2291 - binary_io_u_1: 0.6576
# Epoch 8: val_loss improved from 0.20565 to 0.20012, saving model to model-FCNEp=50Model_20230330.h5
# 46/46 [==============================] - 6s 137ms/step - loss: 0.2285 - binary_io_u_1: 0.6585 - val_loss: 0.2001 - val_binary_io_u_1: 0.6870
# Epoch 9/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.2284 - binary_io_u_1: 0.6633
# Epoch 9: val_loss did not improve from 0.20012
# 46/46 [==============================] - 6s 134ms/step - loss: 0.2286 - binary_io_u_1: 0.6642 - val_loss: 0.2023 - val_binary_io_u_1: 0.6858
# Epoch 10/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.2164 - binary_io_u_1: 0.6734
# Epoch 10: val_loss did not improve from 0.20012
# 46/46 [==============================] - 6s 134ms/step - loss: 0.2166 - binary_io_u_1: 0.6734 - val_loss: 0.2834 - val_binary_io_u_1: 0.5368
# Epoch 11/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.2310 - binary_io_u_1: 0.6619
# Epoch 11: val_loss did not improve from 0.20012
# 46/46 [==============================] - 6s 140ms/step - loss: 0.2304 - binary_io_u_1: 0.6629 - val_loss: 0.2043 - val_binary_io_u_1: 0.6865
# Epoch 12/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.2006 - binary_io_u_1: 0.6867
# Epoch 12: val_loss improved from 0.20012 to 0.17981, saving model to model-FCNEp=50Model_20230330.h5
# 46/46 [==============================] - 6s 139ms/step - loss: 0.2009 - binary_io_u_1: 0.6862 - val_loss: 0.1798 - val_binary_io_u_1: 0.6862
# Epoch 13/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.1989 - binary_io_u_1: 0.6936
# Epoch 13: val_loss improved from 0.17981 to 0.17952, saving model to model-FCNEp=50Model_20230330.h5
# 46/46 [==============================] - 6s 135ms/step - loss: 0.1987 - binary_io_u_1: 0.6935 - val_loss: 0.1795 - val_binary_io_u_1: 0.8102
# Epoch 14/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.1980 - binary_io_u_1: 0.6999
# Epoch 14: val_loss did not improve from 0.17952
# 46/46 [==============================] - 6s 135ms/step - loss: 0.1980 - binary_io_u_1: 0.7000 - val_loss: 0.1838 - val_binary_io_u_1: 0.8109
# Epoch 15/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.2058 - binary_io_u_1: 0.6995
# Epoch 15: val_loss improved from 0.17952 to 0.17652, saving model to model-FCNEp=50Model_20230330.h5
# 46/46 [==============================] - 6s 135ms/step - loss: 0.2059 - binary_io_u_1: 0.6997 - val_loss: 0.1765 - val_binary_io_u_1: 0.8249
# Epoch 16/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.1994 - binary_io_u_1: 0.7074
# Epoch 16: val_loss improved from 0.17652 to 0.16813, saving model to model-FCNEp=50Model_20230330.h5
# 46/46 [==============================] - 6s 138ms/step - loss: 0.1996 - binary_io_u_1: 0.7077 - val_loss: 0.1681 - val_binary_io_u_1: 0.7418
# Epoch 17/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.1903 - binary_io_u_1: 0.7060
# Epoch 17: val_loss did not improve from 0.16813
# 46/46 [==============================] - 6s 135ms/step - loss: 0.1904 - binary_io_u_1: 0.7051 - val_loss: 0.1723 - val_binary_io_u_1: 0.8202
# Epoch 18/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.1839 - binary_io_u_1: 0.7212
# Epoch 18: val_loss improved from 0.16813 to 0.16233, saving model to model-FCNEp=50Model_20230330.h5
# 46/46 [==============================] - 6s 130ms/step - loss: 0.1841 - binary_io_u_1: 0.7203 - val_loss: 0.1623 - val_binary_io_u_1: 0.6808
# Epoch 19/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.1857 - binary_io_u_1: 0.7166
# Epoch 19: val_loss did not improve from 0.16233
# 46/46 [==============================] - 6s 134ms/step - loss: 0.1851 - binary_io_u_1: 0.7173 - val_loss: 0.1804 - val_binary_io_u_1: 0.6858
# Epoch 20/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.1749 - binary_io_u_1: 0.7321
# Epoch 20: val_loss improved from 0.16233 to 0.15816, saving model to model-FCNEp=50Model_20230330.h5
# 46/46 [==============================] - 6s 134ms/step - loss: 0.1753 - binary_io_u_1: 0.7307 - val_loss: 0.1582 - val_binary_io_u_1: 0.7890
# Epoch 21/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.1762 - binary_io_u_1: 0.7226
# Epoch 21: val_loss did not improve from 0.15816
# 46/46 [==============================] - 6s 135ms/step - loss: 0.1761 - binary_io_u_1: 0.7229 - val_loss: 0.2224 - val_binary_io_u_1: 0.7075
# Epoch 22/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.1864 - binary_io_u_1: 0.7117
# Epoch 22: val_loss improved from 0.15816 to 0.15683, saving model to model-FCNEp=50Model_20230330.h5
# 46/46 [==============================] - 6s 133ms/step - loss: 0.1861 - binary_io_u_1: 0.7121 - val_loss: 0.1568 - val_binary_io_u_1: 0.8256
# Epoch 23/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.1881 - binary_io_u_1: 0.7114
# Epoch 23: val_loss did not improve from 0.15683
# 46/46 [==============================] - 6s 138ms/step - loss: 0.1883 - binary_io_u_1: 0.7108 - val_loss: 0.1623 - val_binary_io_u_1: 0.6861
# Epoch 24/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.1773 - binary_io_u_1: 0.7195
# Epoch 24: val_loss improved from 0.15683 to 0.15150, saving model to model-FCNEp=50Model_20230330.h5
# 46/46 [==============================] - 6s 131ms/step - loss: 0.1772 - binary_io_u_1: 0.7198 - val_loss: 0.1515 - val_binary_io_u_1: 0.8226
# Epoch 25/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.1674 - binary_io_u_1: 0.7347
# Epoch 25: val_loss did not improve from 0.15150
# 46/46 [==============================] - 6s 132ms/step - loss: 0.1677 - binary_io_u_1: 0.7347 - val_loss: 0.1583 - val_binary_io_u_1: 0.8161
# Epoch 26/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.1845 - binary_io_u_1: 0.7047
# Epoch 26: val_loss did not improve from 0.15150
# 46/46 [==============================] - 6s 136ms/step - loss: 0.1842 - binary_io_u_1: 0.7051 - val_loss: 0.2079 - val_binary_io_u_1: 0.7384
# Epoch 27/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.1886 - binary_io_u_1: 0.7172
# Epoch 27: val_loss improved from 0.15150 to 0.14963, saving model to model-FCNEp=50Model_20230330.h5
# 46/46 [==============================] - 6s 135ms/step - loss: 0.1884 - binary_io_u_1: 0.7175 - val_loss: 0.1496 - val_binary_io_u_1: 0.6804
# Epoch 28/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.1678 - binary_io_u_1: 0.7229
# Epoch 28: val_loss improved from 0.14963 to 0.14613, saving model to model-FCNEp=50Model_20230330.h5
# 46/46 [==============================] - 6s 134ms/step - loss: 0.1679 - binary_io_u_1: 0.7235 - val_loss: 0.1461 - val_binary_io_u_1: 0.8194
# Epoch 29/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.1682 - binary_io_u_1: 0.7254
# Epoch 29: val_loss improved from 0.14613 to 0.14450, saving model to model-FCNEp=50Model_20230330.h5
# 46/46 [==============================] - 6s 131ms/step - loss: 0.1692 - binary_io_u_1: 0.7237 - val_loss: 0.1445 - val_binary_io_u_1: 0.8245
# Epoch 30/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.1803 - binary_io_u_1: 0.7184
# Epoch 30: val_loss did not improve from 0.14450
# 46/46 [==============================] - 6s 139ms/step - loss: 0.1800 - binary_io_u_1: 0.7193 - val_loss: 0.1520 - val_binary_io_u_1: 0.8167
# Epoch 31/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.1601 - binary_io_u_1: 0.7537
# Epoch 31: val_loss improved from 0.14450 to 0.14179, saving model to model-FCNEp=50Model_20230330.h5
# 46/46 [==============================] - 7s 159ms/step - loss: 0.1602 - binary_io_u_1: 0.7544 - val_loss: 0.1418 - val_binary_io_u_1: 0.8221
# Epoch 32/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.1575 - binary_io_u_1: 0.7643
# Epoch 32: val_loss did not improve from 0.14179
# 46/46 [==============================] - 7s 147ms/step - loss: 0.1577 - binary_io_u_1: 0.7645 - val_loss: 0.1545 - val_binary_io_u_1: 0.8116
# Epoch 33/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.1682 - binary_io_u_1: 0.7312
# Epoch 33: val_loss did not improve from 0.14179
# 46/46 [==============================] - 7s 142ms/step - loss: 0.1677 - binary_io_u_1: 0.7318 - val_loss: 0.1554 - val_binary_io_u_1: 0.6841
# Epoch 34/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.1659 - binary_io_u_1: 0.7501
# Epoch 34: val_loss did not improve from 0.14179
# 46/46 [==============================] - 6s 133ms/step - loss: 0.1660 - binary_io_u_1: 0.7503 - val_loss: 0.1447 - val_binary_io_u_1: 0.6784
# Epoch 35/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.1663 - binary_io_u_1: 0.7340
# Epoch 35: val_loss improved from 0.14179 to 0.13917, saving model to model-FCNEp=50Model_20230330.h5
# 46/46 [==============================] - 6s 133ms/step - loss: 0.1662 - binary_io_u_1: 0.7343 - val_loss: 0.1392 - val_binary_io_u_1: 0.8015
# Epoch 36/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.1582 - binary_io_u_1: 0.7557
# Epoch 36: val_loss did not improve from 0.13917
# 46/46 [==============================] - 6s 136ms/step - loss: 0.1579 - binary_io_u_1: 0.7559 - val_loss: 0.1749 - val_binary_io_u_1: 0.7785
# Epoch 37/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.1601 - binary_io_u_1: 0.7537
# Epoch 37: val_loss did not improve from 0.13917
# 46/46 [==============================] - 6s 131ms/step - loss: 0.1596 - binary_io_u_1: 0.7544 - val_loss: 0.1461 - val_binary_io_u_1: 0.6808
# Epoch 38/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.1613 - binary_io_u_1: 0.7436
# Epoch 38: val_loss did not improve from 0.13917
# 46/46 [==============================] - 6s 132ms/step - loss: 0.1611 - binary_io_u_1: 0.7438 - val_loss: 0.1661 - val_binary_io_u_1: 0.7915
# Epoch 39/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.1535 - binary_io_u_1: 0.7749
# Epoch 39: val_loss did not improve from 0.13917
# 46/46 [==============================] - 6s 137ms/step - loss: 0.1535 - binary_io_u_1: 0.7747 - val_loss: 0.1434 - val_binary_io_u_1: 0.8195
# Epoch 40/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.1592 - binary_io_u_1: 0.7542
# Epoch 40: val_loss did not improve from 0.13917
# 46/46 [==============================] - 6s 132ms/step - loss: 0.1595 - binary_io_u_1: 0.7536 - val_loss: 0.1496 - val_binary_io_u_1: 0.6822
# Epoch 41/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.1613 - binary_io_u_1: 0.7487
# Epoch 41: val_loss improved from 0.13917 to 0.13655, saving model to model-FCNEp=50Model_20230330.h5
# 46/46 [==============================] - 6s 132ms/step - loss: 0.1608 - binary_io_u_1: 0.7493 - val_loss: 0.1365 - val_binary_io_u_1: 0.8241
# Epoch 42/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.1667 - binary_io_u_1: 0.7312
# Epoch 42: val_loss did not improve from 0.13655
# 46/46 [==============================] - 6s 132ms/step - loss: 0.1672 - binary_io_u_1: 0.7307 - val_loss: 0.1629 - val_binary_io_u_1: 0.7970
# Epoch 43/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.1800 - binary_io_u_1: 0.7425
# Epoch 43: val_loss did not improve from 0.13655
# 46/46 [==============================] - 6s 131ms/step - loss: 0.1795 - binary_io_u_1: 0.7434 - val_loss: 0.2536 - val_binary_io_u_1: 0.6822
# Epoch 44/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.1706 - binary_io_u_1: 0.7404
# Epoch 44: val_loss improved from 0.13655 to 0.13555, saving model to model-FCNEp=50Model_20230330.h5
# 46/46 [==============================] - 6s 134ms/step - loss: 0.1706 - binary_io_u_1: 0.7405 - val_loss: 0.1356 - val_binary_io_u_1: 0.8251
# Epoch 45/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.1723 - binary_io_u_1: 0.7237
# Epoch 45: val_loss did not improve from 0.13555
# 46/46 [==============================] - 6s 134ms/step - loss: 0.1720 - binary_io_u_1: 0.7245 - val_loss: 0.1419 - val_binary_io_u_1: 0.8221
# Epoch 46/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.1766 - binary_io_u_1: 0.7227
# Epoch 46: val_loss did not improve from 0.13555
# 46/46 [==============================] - 6s 135ms/step - loss: 0.1760 - binary_io_u_1: 0.7230 - val_loss: 0.2257 - val_binary_io_u_1: 0.7302
# Epoch 47/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.1702 - binary_io_u_1: 0.7338
# Epoch 47: val_loss did not improve from 0.13555
# 46/46 [==============================] - 6s 131ms/step - loss: 0.1698 - binary_io_u_1: 0.7340 - val_loss: 0.1551 - val_binary_io_u_1: 0.8030
# Epoch 48/48
# 45/46 [============================>.] - ETA: 0s - loss: 0.1540 - binary_io_u_1: 0.7652
# Epoch 48: val_loss did not improve from 0.13555
# 46/46 [==============================] - 6s 132ms/step - loss: 0.1543 - binary_io_u_1: 0.7651 - val_loss: 0.1391 - val_binary_io_u_1: 0.8229

# %%
# ALTER THE NAMING CONVENTIONS..
def plot_training(hist):
    '''
    This function take training model and plot history of accuracy and losses with the best epoch in both of them.
    '''

    # Define needed variables--> these two need to be diff
    tr_acc = hist.history['binary_io_u_1']
    tr_loss = hist.history['loss']
    val_acc = hist.history['val_binary_io_u_1']
    val_loss = hist.history['val_loss']
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]
    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'

    # Plot training history
    plt.figure(figsize= (20, 8))
    plt.style.use('fivethirtyeight')

    plt.subplot(1, 2, 1)
    plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
    plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
    plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training and Validation Binary IOU')
    plt.xlabel('Epochs')
    plt.ylabel('Binary IOU')
    plt.legend()

    # change the title!!
    plt.suptitle("FCN trained with Ep = 50", fontsize=30)
    plt.tight_layout
    plt.savefig('model-FCNEp=50Model_20230330.png')
    plt.show()

# %%
# results.history
plot_training(result)

# %%
# we could stop here...
