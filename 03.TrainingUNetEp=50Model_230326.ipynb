# %%
import os
import sys
import glob
import random
import warnings
import shutil
from distutils.dir_util import copy_tree


import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

from keras.models import Model, load_model
from keras.layers import Input
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
# from keras.layers.merge import concatenate
from keras.layers import concatenate

from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

import tensorflow as tf
from tensorflow.keras.metrics import Metric

import skimage.io

# %%
# Set some parameters
IMG_WIDTH = 128
IMG_HEIGHT = 128
# IMG_CHANNELS = 3
IMG_CHANNELS = 1

# %%
# the small set for experimentation!
TRAIN_PATH = './FORmodels/trainset_raw/'

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
seed = 42
random.seed = seed
np.random.seed = seed

# Get train and test IDs
train_ids = next(os.walk(TRAIN_PATH))[1]
len(train_ids)
# Out:
# 1809

# %%
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH), dtype=np.bool)
Y_train.shape
# Out:
# /var/folders/qr/np1v1r_53zqc4t2j9qztcrxh0000gn/T/ipykernel_37440/187304916.py:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH), dtype=np.bool)
# (1809, 128, 128)

# %%
# Get and resize train images and masks
X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH), dtype=np.uint8)
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
print('Getting and resizing train images and masks ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    pather = TRAIN_PATH + id_    
    img = imread(pather + '/images/' + id_ + '.png')
    X_train[n] = img
    
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
        
    pattern = pather+'/masks/*'
    for fname in glob.glob(pattern, recursive=True):

        mask_ = imread(fname)     
        mask_ = resize(mask_,(IMG_HEIGHT, IMG_WIDTH, 1))
#         mask_ = np.expand_dims(mask_, axis=1)        
        mask = np.maximum(mask, mask_)
        
    Y_train[n] = mask
# Out:
# Getting and resizing train images and masks ...
# /var/folders/qr/np1v1r_53zqc4t2j9qztcrxh0000gn/T/ipykernel_37440/431872359.py:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
#   0%|                                                  | 0/1809 [00:00<?, ?it/s]/var/folders/qr/np1v1r_53zqc4t2j9qztcrxh0000gn/T/ipykernel_37440/431872359.py:11: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
# 100%|███████████████████████████████████████| 1809/1809 [02:48<00:00, 10.73it/s]

# %%
# Check if training data looks all right
# DOUBLE CHECK MASKS!!
ix = random.randint(0, len(train_ids))

print(ix, train_ids[ix])
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()
# Out:
# 1563 150b0ffa318c87b31d78af0e87d60390dbcd84b5f228a8c1fb3225cbe5df3e3f_mirror

# %%
# allowing for hyperparam tuning
import keras_tuner as kt
hp = kt.HyperParameters()

# %%
def model_builder(hp):

    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    s = Lambda(lambda x: x / 255) (inputs)

    c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (s)
    c1 = Dropout(0.1) (c1)
    c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c1)
    p1 = MaxPooling2D((2, 2)) (c1)

    c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p1)
    c2 = Dropout(0.1) (c2)
    c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c2)
    p2 = MaxPooling2D((2, 2)) (c2)

    c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p2)
    c3 = Dropout(0.2) (c3)
    c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c3)
    p3 = MaxPooling2D((2, 2)) (c3)

    c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p3)
    c4 = Dropout(0.2) (c4)
    c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c4)
    p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

    c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p4)
    c5 = Dropout(0.3) (c5)
    c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c5)

    u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c5)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u6)
    c6 = Dropout(0.2) (c6)
    c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c6)

    u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u7)
    c7 = Dropout(0.2) (c7)
    c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c7)

    u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u8)
    c8 = Dropout(0.1) (c8)
    c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c8)

    u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u9)
    c9 = Dropout(0.1) (c9)
    c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c9)

    outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)

    model = Model(inputs=[inputs], outputs=[outputs])

    # here we're using the hyperparam for learning rate!
    model.compile(tf.keras.optimizers.Adam(hp.Float('learning_rate', 1e-4, 1e-2, sampling='log'), amsgrad= True), loss='binary_crossentropy', metrics=tf.keras.metrics.BinaryIoU(target_class_ids=[0, 1], threshold=0.3))

#     model.summary()
    
    return model

# %%
tuner = kt.RandomSearch(
    model_builder,
    objective = kt.Objective("mean_io_u", direction="max"),
    max_trials=5)
# Out:
# INFO:tensorflow:Reloading Tuner from ./untitled_project/tuner0.json

# %%
# TURNING OFF STOP EARLY
tuner.search(X_train, Y_train, epochs=5, validation_split=0.2)

best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"""
The hyperparameter search is complete. The optimal number of units in the first densely-connected
layer is ... and the optimal learning rate for the optimizer
is {best_hps.get('learning_rate')}.
""")
# Out:
# INFO:tensorflow:Oracle triggered exit
#
# The hyperparameter search is complete. The optimal number of units in the first densely-connected
# layer is ... and the optimal learning rate for the optimizer
# is 0.0008259900546842376.

# %%
model = tuner.hypermodel.build(best_hps)
# Out:
# 2023-04-01 16:14:16.380938: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
## ADDING ADVERSARIAL ATTACK...
loss_object = tf.keras.losses.BinaryCrossentropy()

def create_adversarial_pattern(input_image, input_label):
    input_image = tf.convert_to_tensor(np.reshape(input_image, (-1, 128, 128, 1)), dtype=tf.float32)
    input_label = np.reshape(input_label, (-1, 128, 128, 1))

#     Record operations for automatic differentiation??
    with tf.GradientTape() as tape:

        tape.watch(input_image)
        prediction = model(input_image)
        
        loss = loss_object(input_label, prediction)

#   # Get the gradients of the loss w.r.t to the input image.
    gradient = tape.gradient(loss, input_image)

    # Get the sign of the gradients to create the perturbation
    signed_grad = tf.sign(gradient)
    
    return signed_grad

# %%
# Get the input label of the image. -->  THIS NEEDS TO BE A LOOP THROUGH THE IMAGES!!
# WE CAN RANDOMIZE HOW MANY GET A PERTURBATION!!

pert = []

for i in range(len(X_train)):
    pert.append(create_adversarial_pattern(X_train[i],Y_train[i]))

# %%
# making a function for adding peterubation!!!!!
def addingep (ep):
    newtrain = []

    for i in range(len(X_train)): 
        pert[i] = tf.reshape(pert[i], [1, 128, 128])
        new = X_train[i] + ep* pert[i] * 0.5 + 0.5
        newtrain.append(np.squeeze(new.numpy()))

    newtrain = np.asarray(newtrain)
    newtrain = np.squeeze(newtrain)
    
    return newtrain

# %%
# Generates a new X_train
newtrain_50 = addingep(50)

# %%
X_train.shape
# Out:
# (1809, 128, 128)

# %%
newtrain_50.shape
# Out:
# (1809, 128, 128)

# %%
# Let's visualize what we've done here...
# Perform a sanity check on some random training samples
ix = random.randint(0, len(newtrain_50))
print(ix)
imshow(X_train[ix])
plt.title('Raw Image')
plt.ylabel('Pixel')
plt.xlabel('Pixel')
plt.show()
imshow(newtrain_50[ix].astype('uint8'))
plt.title('Epsilon=50 Image')
plt.ylabel('Pixel')
plt.xlabel('Pixel')
plt.show()
imshow(np.squeeze(pert[ix]))
plt.title('Perturbation')
plt.ylabel('Pixel')
plt.xlabel('Pixel')
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.title('Mask')
plt.ylabel('Pixel')
plt.xlabel('Pixel')
plt.show()
# Out:
# 1444

# %%
# increasing epoch val to 50!!
# tf.config.run_functions_eagerly(True)
history = model.fit(newtrain_50, Y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.2604 - binary_io_u: 0.6288 - val_loss: 0.3012 - val_binary_io_u: 0.6096
# Epoch 2/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.1553 - binary_io_u: 0.7752 - val_loss: 0.1264 - val_binary_io_u: 0.8028
# Epoch 3/50
# 46/46 [==============================] - 63s 1s/step - loss: 0.1257 - binary_io_u: 0.8162 - val_loss: 0.1212 - val_binary_io_u: 0.8037
# Epoch 4/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.1140 - binary_io_u: 0.8312 - val_loss: 0.1049 - val_binary_io_u: 0.8261
# Epoch 5/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.1102 - binary_io_u: 0.8366 - val_loss: 0.1058 - val_binary_io_u: 0.8323
# Epoch 6/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.1039 - binary_io_u: 0.8441 - val_loss: 0.1092 - val_binary_io_u: 0.8234
# Epoch 7/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.1019 - binary_io_u: 0.8468 - val_loss: 0.1106 - val_binary_io_u: 0.8133
# Epoch 8/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.0994 - binary_io_u: 0.8488 - val_loss: 0.0955 - val_binary_io_u: 0.8399
# Epoch 9/50
# 46/46 [==============================] - 63s 1s/step - loss: 0.0965 - binary_io_u: 0.8526 - val_loss: 0.0939 - val_binary_io_u: 0.8566
# Epoch 10/50
# 46/46 [==============================] - 63s 1s/step - loss: 0.0930 - binary_io_u: 0.8580 - val_loss: 0.0917 - val_binary_io_u: 0.8542
# Epoch 11/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0934 - binary_io_u: 0.8578 - val_loss: 0.0842 - val_binary_io_u: 0.8704
# Epoch 12/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0887 - binary_io_u: 0.8636 - val_loss: 0.0936 - val_binary_io_u: 0.8413
# Epoch 13/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0859 - binary_io_u: 0.8659 - val_loss: 0.0813 - val_binary_io_u: 0.8698
# Epoch 14/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.0837 - binary_io_u: 0.8694 - val_loss: 0.0813 - val_binary_io_u: 0.8728
# Epoch 15/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0849 - binary_io_u: 0.8695 - val_loss: 0.0853 - val_binary_io_u: 0.8600
# Epoch 16/50
# 46/46 [==============================] - 60s 1s/step - loss: 0.0837 - binary_io_u: 0.8713 - val_loss: 0.0856 - val_binary_io_u: 0.8655
# Epoch 17/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.0797 - binary_io_u: 0.8764 - val_loss: 0.0785 - val_binary_io_u: 0.8755
# Epoch 18/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0770 - binary_io_u: 0.8802 - val_loss: 0.0754 - val_binary_io_u: 0.8800
# Epoch 19/50
# 46/46 [==============================] - 63s 1s/step - loss: 0.0751 - binary_io_u: 0.8837 - val_loss: 0.0725 - val_binary_io_u: 0.8782
# Epoch 20/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0757 - binary_io_u: 0.8824 - val_loss: 0.0684 - val_binary_io_u: 0.8904
# Epoch 21/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0758 - binary_io_u: 0.8820 - val_loss: 0.0727 - val_binary_io_u: 0.8807
# Epoch 22/50
# 46/46 [==============================] - 65s 1s/step - loss: 0.0732 - binary_io_u: 0.8864 - val_loss: 0.0688 - val_binary_io_u: 0.8858
# Epoch 23/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0712 - binary_io_u: 0.8885 - val_loss: 0.0702 - val_binary_io_u: 0.8895
# Epoch 24/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0716 - binary_io_u: 0.8889 - val_loss: 0.0682 - val_binary_io_u: 0.8854
# Epoch 25/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0699 - binary_io_u: 0.8911 - val_loss: 0.0647 - val_binary_io_u: 0.8965
# Epoch 26/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0704 - binary_io_u: 0.8906 - val_loss: 0.0645 - val_binary_io_u: 0.9014
# Epoch 27/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.0702 - binary_io_u: 0.8911 - val_loss: 0.0713 - val_binary_io_u: 0.8811
# Epoch 28/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.0684 - binary_io_u: 0.8932 - val_loss: 0.0724 - val_binary_io_u: 0.8813
# Epoch 29/50
# 46/46 [==============================] - 63s 1s/step - loss: 0.0675 - binary_io_u: 0.8944 - val_loss: 0.0645 - val_binary_io_u: 0.9020
# Epoch 30/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.0673 - binary_io_u: 0.8945 - val_loss: 0.0619 - val_binary_io_u: 0.9076
# Epoch 31/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0683 - binary_io_u: 0.8946 - val_loss: 0.0650 - val_binary_io_u: 0.8911
# Epoch 32/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.0655 - binary_io_u: 0.8973 - val_loss: 0.0691 - val_binary_io_u: 0.8853
# Epoch 33/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.0650 - binary_io_u: 0.8982 - val_loss: 0.0669 - val_binary_io_u: 0.8907
# Epoch 34/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.0651 - binary_io_u: 0.8982 - val_loss: 0.0723 - val_binary_io_u: 0.8821
# Epoch 35/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.0649 - binary_io_u: 0.8990 - val_loss: 0.0655 - val_binary_io_u: 0.8903
# Epoch 36/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0630 - binary_io_u: 0.9008 - val_loss: 0.0589 - val_binary_io_u: 0.9046
# Epoch 37/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0630 - binary_io_u: 0.9010 - val_loss: 0.0602 - val_binary_io_u: 0.9058
# Epoch 38/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.0624 - binary_io_u: 0.9019 - val_loss: 0.0581 - val_binary_io_u: 0.9061
# Epoch 39/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0615 - binary_io_u: 0.9033 - val_loss: 0.0601 - val_binary_io_u: 0.8994
# Epoch 40/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0614 - binary_io_u: 0.9031 - val_loss: 0.0577 - val_binary_io_u: 0.9051
# Epoch 41/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.0611 - binary_io_u: 0.9039 - val_loss: 0.0620 - val_binary_io_u: 0.9027
# Epoch 42/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.0607 - binary_io_u: 0.9046 - val_loss: 0.0574 - val_binary_io_u: 0.9061
# Epoch 43/50
# 46/46 [==============================] - 63s 1s/step - loss: 0.0593 - binary_io_u: 0.9064 - val_loss: 0.0573 - val_binary_io_u: 0.9071
# Epoch 44/50
# 46/46 [==============================] - 63s 1s/step - loss: 0.0583 - binary_io_u: 0.9080 - val_loss: 0.0592 - val_binary_io_u: 0.8995
# Epoch 45/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.0590 - binary_io_u: 0.9070 - val_loss: 0.0584 - val_binary_io_u: 0.9028
# Epoch 46/50
# 46/46 [==============================] - 59s 1s/step - loss: 0.0623 - binary_io_u: 0.9024 - val_loss: 0.0621 - val_binary_io_u: 0.8995
# Epoch 47/50
# 46/46 [==============================] - 60s 1s/step - loss: 0.0608 - binary_io_u: 0.9044 - val_loss: 0.0566 - val_binary_io_u: 0.9080
# Epoch 48/50
# 46/46 [==============================] - 59s 1s/step - loss: 0.0587 - binary_io_u: 0.9072 - val_loss: 0.0554 - val_binary_io_u: 0.9150
# Epoch 49/50
# 46/46 [==============================] - 59s 1s/step - loss: 0.0577 - binary_io_u: 0.9088 - val_loss: 0.0583 - val_binary_io_u: 0.9056
# Epoch 50/50
# 46/46 [==============================] - 59s 1s/step - loss: 0.0573 - binary_io_u: 0.9096 - val_loss: 0.0556 - val_binary_io_u: 0.9084

# %%
val_acc_per_epoch = history.history['val_binary_io_u']
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Best epoch: 48

# %%
# use the best number of epochs
hypermodel = tuner.hypermodel.build(best_hps)

# FROM = 2023/03/30
# # REMEMBER TO CHANGE THE NAME OF THE MODEL!!
checkpointer = ModelCheckpoint('model-UNetEp=50Model_20230330.h5', verbose=1, save_best_only=True)
# Retrain the model--> USE THE NEW_TRAIN
result = hypermodel.fit(newtrain_50, Y_train, epochs=best_epoch, validation_split=0.2, callbacks=[checkpointer])
# Out:
# Epoch 1/48
# 46/46 [==============================] - ETA: 0s - loss: 0.2819 - binary_io_u_2: 0.5952
# Epoch 1: val_loss improved from inf to 0.19660, saving model to model-UNetEp=50Model_20230330.h5
# 46/46 [==============================] - 62s 1s/step - loss: 0.2819 - binary_io_u_2: 0.5952 - val_loss: 0.1966 - val_binary_io_u_2: 0.6695
# Epoch 2/48
# 46/46 [==============================] - ETA: 0s - loss: 0.1486 - binary_io_u_2: 0.7845
# Epoch 2: val_loss improved from 0.19660 to 0.12467, saving model to model-UNetEp=50Model_20230330.h5
# 46/46 [==============================] - 60s 1s/step - loss: 0.1486 - binary_io_u_2: 0.7845 - val_loss: 0.1247 - val_binary_io_u_2: 0.8061
# Epoch 3/48
# 46/46 [==============================] - ETA: 0s - loss: 0.1256 - binary_io_u_2: 0.8176
# Epoch 3: val_loss improved from 0.12467 to 0.11967, saving model to model-UNetEp=50Model_20230330.h5
# 46/46 [==============================] - 59s 1s/step - loss: 0.1256 - binary_io_u_2: 0.8176 - val_loss: 0.1197 - val_binary_io_u_2: 0.8162
# Epoch 4/48
# 46/46 [==============================] - ETA: 0s - loss: 0.1125 - binary_io_u_2: 0.8345
# Epoch 4: val_loss did not improve from 0.11967
# 46/46 [==============================] - 59s 1s/step - loss: 0.1125 - binary_io_u_2: 0.8345 - val_loss: 0.1416 - val_binary_io_u_2: 0.8096
# Epoch 5/48
# 46/46 [==============================] - ETA: 0s - loss: 0.1125 - binary_io_u_2: 0.8339
# Epoch 5: val_loss improved from 0.11967 to 0.09945, saving model to model-UNetEp=50Model_20230330.h5
# 46/46 [==============================] - 59s 1s/step - loss: 0.1125 - binary_io_u_2: 0.8339 - val_loss: 0.0995 - val_binary_io_u_2: 0.8482
# Epoch 6/48
# 46/46 [==============================] - ETA: 0s - loss: 0.1017 - binary_io_u_2: 0.8472
# Epoch 6: val_loss improved from 0.09945 to 0.09484, saving model to model-UNetEp=50Model_20230330.h5
# 46/46 [==============================] - 59s 1s/step - loss: 0.1017 - binary_io_u_2: 0.8472 - val_loss: 0.0948 - val_binary_io_u_2: 0.8564
# Epoch 7/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0987 - binary_io_u_2: 0.8509
# Epoch 7: val_loss improved from 0.09484 to 0.09067, saving model to model-UNetEp=50Model_20230330.h5
# 46/46 [==============================] - 59s 1s/step - loss: 0.0987 - binary_io_u_2: 0.8509 - val_loss: 0.0907 - val_binary_io_u_2: 0.8475
# Epoch 8/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0943 - binary_io_u_2: 0.8552
# Epoch 8: val_loss improved from 0.09067 to 0.08658, saving model to model-UNetEp=50Model_20230330.h5
# 46/46 [==============================] - 59s 1s/step - loss: 0.0943 - binary_io_u_2: 0.8552 - val_loss: 0.0866 - val_binary_io_u_2: 0.8622
# Epoch 9/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0899 - binary_io_u_2: 0.8619
# Epoch 9: val_loss improved from 0.08658 to 0.08497, saving model to model-UNetEp=50Model_20230330.h5
# 46/46 [==============================] - 59s 1s/step - loss: 0.0899 - binary_io_u_2: 0.8619 - val_loss: 0.0850 - val_binary_io_u_2: 0.8639
# Epoch 10/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0869 - binary_io_u_2: 0.8663
# Epoch 10: val_loss improved from 0.08497 to 0.08439, saving model to model-UNetEp=50Model_20230330.h5
# 46/46 [==============================] - 60s 1s/step - loss: 0.0869 - binary_io_u_2: 0.8663 - val_loss: 0.0844 - val_binary_io_u_2: 0.8697
# Epoch 11/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0868 - binary_io_u_2: 0.8672
# Epoch 11: val_loss improved from 0.08439 to 0.08383, saving model to model-UNetEp=50Model_20230330.h5
# 46/46 [==============================] - 59s 1s/step - loss: 0.0868 - binary_io_u_2: 0.8672 - val_loss: 0.0838 - val_binary_io_u_2: 0.8639
# Epoch 12/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0830 - binary_io_u_2: 0.8727
# Epoch 12: val_loss improved from 0.08383 to 0.07874, saving model to model-UNetEp=50Model_20230330.h5
# 46/46 [==============================] - 59s 1s/step - loss: 0.0830 - binary_io_u_2: 0.8727 - val_loss: 0.0787 - val_binary_io_u_2: 0.8713
# Epoch 13/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0799 - binary_io_u_2: 0.8768
# Epoch 13: val_loss improved from 0.07874 to 0.07590, saving model to model-UNetEp=50Model_20230330.h5
# 46/46 [==============================] - 60s 1s/step - loss: 0.0799 - binary_io_u_2: 0.8768 - val_loss: 0.0759 - val_binary_io_u_2: 0.8759
# Epoch 14/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0800 - binary_io_u_2: 0.8775
# Epoch 14: val_loss improved from 0.07590 to 0.07404, saving model to model-UNetEp=50Model_20230330.h5
# 46/46 [==============================] - 59s 1s/step - loss: 0.0800 - binary_io_u_2: 0.8775 - val_loss: 0.0740 - val_binary_io_u_2: 0.8767
# Epoch 15/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0798 - binary_io_u_2: 0.8775
# Epoch 15: val_loss did not improve from 0.07404
# 46/46 [==============================] - 59s 1s/step - loss: 0.0798 - binary_io_u_2: 0.8775 - val_loss: 0.0748 - val_binary_io_u_2: 0.8828
# Epoch 16/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0762 - binary_io_u_2: 0.8830
# Epoch 16: val_loss improved from 0.07404 to 0.07331, saving model to model-UNetEp=50Model_20230330.h5
# 46/46 [==============================] - 59s 1s/step - loss: 0.0762 - binary_io_u_2: 0.8830 - val_loss: 0.0733 - val_binary_io_u_2: 0.8822
# Epoch 17/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0742 - binary_io_u_2: 0.8856
# Epoch 17: val_loss improved from 0.07331 to 0.06788, saving model to model-UNetEp=50Model_20230330.h5
# 46/46 [==============================] - 59s 1s/step - loss: 0.0742 - binary_io_u_2: 0.8856 - val_loss: 0.0679 - val_binary_io_u_2: 0.8919
# Epoch 18/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0727 - binary_io_u_2: 0.8877
# Epoch 18: val_loss did not improve from 0.06788
# 46/46 [==============================] - 59s 1s/step - loss: 0.0727 - binary_io_u_2: 0.8877 - val_loss: 0.0685 - val_binary_io_u_2: 0.8973
# Epoch 19/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0762 - binary_io_u_2: 0.8837
# Epoch 19: val_loss did not improve from 0.06788
# 46/46 [==============================] - 59s 1s/step - loss: 0.0762 - binary_io_u_2: 0.8837 - val_loss: 0.0711 - val_binary_io_u_2: 0.8798
# Epoch 20/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0744 - binary_io_u_2: 0.8854
# Epoch 20: val_loss improved from 0.06788 to 0.06634, saving model to model-UNetEp=50Model_20230330.h5
# 46/46 [==============================] - 59s 1s/step - loss: 0.0744 - binary_io_u_2: 0.8854 - val_loss: 0.0663 - val_binary_io_u_2: 0.8962
# Epoch 21/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0705 - binary_io_u_2: 0.8908
# Epoch 21: val_loss improved from 0.06634 to 0.06499, saving model to model-UNetEp=50Model_20230330.h5
# 46/46 [==============================] - 60s 1s/step - loss: 0.0705 - binary_io_u_2: 0.8908 - val_loss: 0.0650 - val_binary_io_u_2: 0.8960
# Epoch 22/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0688 - binary_io_u_2: 0.8934
# Epoch 22: val_loss improved from 0.06499 to 0.06460, saving model to model-UNetEp=50Model_20230330.h5
# 46/46 [==============================] - 61s 1s/step - loss: 0.0688 - binary_io_u_2: 0.8934 - val_loss: 0.0646 - val_binary_io_u_2: 0.8945
# Epoch 23/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0681 - binary_io_u_2: 0.8943
# Epoch 23: val_loss improved from 0.06460 to 0.06421, saving model to model-UNetEp=50Model_20230330.h5
# 46/46 [==============================] - 59s 1s/step - loss: 0.0681 - binary_io_u_2: 0.8943 - val_loss: 0.0642 - val_binary_io_u_2: 0.8985
# Epoch 24/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0674 - binary_io_u_2: 0.8954
# Epoch 24: val_loss did not improve from 0.06421
# 46/46 [==============================] - 61s 1s/step - loss: 0.0674 - binary_io_u_2: 0.8954 - val_loss: 0.0643 - val_binary_io_u_2: 0.8906
# Epoch 25/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0679 - binary_io_u_2: 0.8950
# Epoch 25: val_loss did not improve from 0.06421
# 46/46 [==============================] - 59s 1s/step - loss: 0.0679 - binary_io_u_2: 0.8950 - val_loss: 0.0814 - val_binary_io_u_2: 0.8853
# Epoch 26/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0824 - binary_io_u_2: 0.8773
# Epoch 26: val_loss did not improve from 0.06421
# 46/46 [==============================] - 59s 1s/step - loss: 0.0824 - binary_io_u_2: 0.8773 - val_loss: 0.0659 - val_binary_io_u_2: 0.8947
# Epoch 27/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0708 - binary_io_u_2: 0.8912
# Epoch 27: val_loss did not improve from 0.06421
# 46/46 [==============================] - 60s 1s/step - loss: 0.0708 - binary_io_u_2: 0.8912 - val_loss: 0.0645 - val_binary_io_u_2: 0.8988
# Epoch 28/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0695 - binary_io_u_2: 0.8930
# Epoch 28: val_loss improved from 0.06421 to 0.06363, saving model to model-UNetEp=50Model_20230330.h5
# 46/46 [==============================] - 60s 1s/step - loss: 0.0695 - binary_io_u_2: 0.8930 - val_loss: 0.0636 - val_binary_io_u_2: 0.8931
# Epoch 29/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0677 - binary_io_u_2: 0.8952
# Epoch 29: val_loss improved from 0.06363 to 0.06254, saving model to model-UNetEp=50Model_20230330.h5
# 46/46 [==============================] - 59s 1s/step - loss: 0.0677 - binary_io_u_2: 0.8952 - val_loss: 0.0625 - val_binary_io_u_2: 0.8959
# Epoch 30/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0667 - binary_io_u_2: 0.8964
# Epoch 30: val_loss did not improve from 0.06254
# 46/46 [==============================] - 60s 1s/step - loss: 0.0667 - binary_io_u_2: 0.8964 - val_loss: 0.0626 - val_binary_io_u_2: 0.8944
# Epoch 31/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0656 - binary_io_u_2: 0.8983
# Epoch 31: val_loss improved from 0.06254 to 0.05971, saving model to model-UNetEp=50Model_20230330.h5
# 46/46 [==============================] - 60s 1s/step - loss: 0.0656 - binary_io_u_2: 0.8983 - val_loss: 0.0597 - val_binary_io_u_2: 0.9012
# Epoch 32/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0645 - binary_io_u_2: 0.8996
# Epoch 32: val_loss did not improve from 0.05971
# 46/46 [==============================] - 59s 1s/step - loss: 0.0645 - binary_io_u_2: 0.8996 - val_loss: 0.0598 - val_binary_io_u_2: 0.8995
# Epoch 33/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0640 - binary_io_u_2: 0.9007
# Epoch 33: val_loss did not improve from 0.05971
# 46/46 [==============================] - 59s 1s/step - loss: 0.0640 - binary_io_u_2: 0.9007 - val_loss: 0.0604 - val_binary_io_u_2: 0.8975
# Epoch 34/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0628 - binary_io_u_2: 0.9020
# Epoch 34: val_loss did not improve from 0.05971
# 46/46 [==============================] - 59s 1s/step - loss: 0.0628 - binary_io_u_2: 0.9020 - val_loss: 0.0607 - val_binary_io_u_2: 0.8970
# Epoch 35/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0626 - binary_io_u_2: 0.9023
# Epoch 35: val_loss improved from 0.05971 to 0.05774, saving model to model-UNetEp=50Model_20230330.h5
# 46/46 [==============================] - 59s 1s/step - loss: 0.0626 - binary_io_u_2: 0.9023 - val_loss: 0.0577 - val_binary_io_u_2: 0.9074
# Epoch 36/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0632 - binary_io_u_2: 0.9011
# Epoch 36: val_loss did not improve from 0.05774
# 46/46 [==============================] - 59s 1s/step - loss: 0.0632 - binary_io_u_2: 0.9011 - val_loss: 0.0577 - val_binary_io_u_2: 0.9081
# Epoch 37/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0622 - binary_io_u_2: 0.9031
# Epoch 37: val_loss improved from 0.05774 to 0.05736, saving model to model-UNetEp=50Model_20230330.h5
# 46/46 [==============================] - 58s 1s/step - loss: 0.0622 - binary_io_u_2: 0.9031 - val_loss: 0.0574 - val_binary_io_u_2: 0.9082
# Epoch 38/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0611 - binary_io_u_2: 0.9045
# Epoch 38: val_loss did not improve from 0.05736
# 46/46 [==============================] - 58s 1s/step - loss: 0.0611 - binary_io_u_2: 0.9045 - val_loss: 0.0577 - val_binary_io_u_2: 0.9053
# Epoch 39/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0615 - binary_io_u_2: 0.9036
# Epoch 39: val_loss improved from 0.05736 to 0.05690, saving model to model-UNetEp=50Model_20230330.h5
# 46/46 [==============================] - 59s 1s/step - loss: 0.0615 - binary_io_u_2: 0.9036 - val_loss: 0.0569 - val_binary_io_u_2: 0.9111
# Epoch 40/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0609 - binary_io_u_2: 0.9048
# Epoch 40: val_loss improved from 0.05690 to 0.05528, saving model to model-UNetEp=50Model_20230330.h5
# 46/46 [==============================] - 58s 1s/step - loss: 0.0609 - binary_io_u_2: 0.9048 - val_loss: 0.0553 - val_binary_io_u_2: 0.9107
# Epoch 41/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0603 - binary_io_u_2: 0.9056
# Epoch 41: val_loss did not improve from 0.05528
# 46/46 [==============================] - 58s 1s/step - loss: 0.0603 - binary_io_u_2: 0.9056 - val_loss: 0.0553 - val_binary_io_u_2: 0.9121
# Epoch 42/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0592 - binary_io_u_2: 0.9071
# Epoch 42: val_loss improved from 0.05528 to 0.05458, saving model to model-UNetEp=50Model_20230330.h5
# 46/46 [==============================] - 58s 1s/step - loss: 0.0592 - binary_io_u_2: 0.9071 - val_loss: 0.0546 - val_binary_io_u_2: 0.9143
# Epoch 43/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0588 - binary_io_u_2: 0.9078
# Epoch 43: val_loss did not improve from 0.05458
# 46/46 [==============================] - 59s 1s/step - loss: 0.0588 - binary_io_u_2: 0.9078 - val_loss: 0.0551 - val_binary_io_u_2: 0.9087
# Epoch 44/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0591 - binary_io_u_2: 0.9073
# Epoch 44: val_loss did not improve from 0.05458
# 46/46 [==============================] - 58s 1s/step - loss: 0.0591 - binary_io_u_2: 0.9073 - val_loss: 0.0571 - val_binary_io_u_2: 0.9047
# Epoch 45/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0587 - binary_io_u_2: 0.9078
# Epoch 45: val_loss did not improve from 0.05458
# 46/46 [==============================] - 59s 1s/step - loss: 0.0587 - binary_io_u_2: 0.9078 - val_loss: 0.0550 - val_binary_io_u_2: 0.9076
# Epoch 46/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0584 - binary_io_u_2: 0.9076
# Epoch 46: val_loss improved from 0.05458 to 0.05340, saving model to model-UNetEp=50Model_20230330.h5
# 46/46 [==============================] - 58s 1s/step - loss: 0.0584 - binary_io_u_2: 0.9076 - val_loss: 0.0534 - val_binary_io_u_2: 0.9144
# Epoch 47/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0587 - binary_io_u_2: 0.9079
# Epoch 47: val_loss did not improve from 0.05340
# 46/46 [==============================] - 58s 1s/step - loss: 0.0587 - binary_io_u_2: 0.9079 - val_loss: 0.0540 - val_binary_io_u_2: 0.9120
# Epoch 48/48
# 46/46 [==============================] - ETA: 0s - loss: 0.0575 - binary_io_u_2: 0.9091
# Epoch 48: val_loss did not improve from 0.05340
# 46/46 [==============================] - 58s 1s/step - loss: 0.0575 - binary_io_u_2: 0.9091 - val_loss: 0.0536 - val_binary_io_u_2: 0.9112

# %%
# ALTER THE NAMING CONVENTIONS..
def plot_training(hist):
    '''
    This function take training model and plot history of accuracy and losses with the best epoch in both of them.
    '''

    # Define needed variables--> these two need to be diff
    tr_acc = hist.history['binary_io_u_2']
    tr_loss = hist.history['loss']
    val_acc = hist.history['val_binary_io_u_2']
    val_loss = hist.history['val_loss']
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]
    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'

    # Plot training history
    plt.figure(figsize= (20, 8))
    plt.style.use('fivethirtyeight')

    plt.subplot(1, 2, 1)
    plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
    plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
    plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training and Validation Binary IOU')
    plt.xlabel('Epochs')
    plt.ylabel('Binary IOU')
    plt.legend()

    # change the title!!
    plt.suptitle("Unet trained with Ep = 50", fontsize=30)
    plt.tight_layout
    plt.savefig('model-UNetEp=50Model_20230330.png')

    plt.show()

# %%
# results.history
plot_training(result)

# %%
# we could stop here...
