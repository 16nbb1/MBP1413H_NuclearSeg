# %%
import os
import sys
import glob
import random
import warnings
import shutil
from distutils.dir_util import copy_tree


import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
# from keras.layers.merge import concatenate
from keras.layers import concatenate

from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

import tensorflow as tf
from tensorflow.keras.metrics import Metric

import skimage.io

# %%
# Set some parameters
IMG_WIDTH = 128
IMG_HEIGHT = 128
# IMG_CHANNELS = 3
IMG_CHANNELS = 1

# %%
# the small set for experimentation!
TRAIN_PATH = './FORmodels/trainset_raw/'

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
seed = 42
random.seed = seed
np.random.seed = seed

# Get train and test IDs
train_ids = next(os.walk(TRAIN_PATH))[1]
len(train_ids)
# Out:
# 1809

# %%
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH), dtype=np.bool)
Y_train.shape
# Out:
# /var/folders/qr/np1v1r_53zqc4t2j9qztcrxh0000gn/T/ipykernel_85510/187304916.py:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH), dtype=np.bool)
# (1809, 128, 128)

# %%
# Get and resize train images and masks
X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH), dtype=np.uint8)
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
print('Getting and resizing train images and masks ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    pather = TRAIN_PATH + id_    
    img = imread(pather + '/images/' + id_ + '.png')
    X_train[n] = img
    
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
        
    pattern = pather+'/masks/*'
    for fname in glob.glob(pattern, recursive=True):

        mask_ = imread(fname)     
        mask_ = resize(mask_,(IMG_HEIGHT, IMG_WIDTH, 1))
#         mask_ = np.expand_dims(mask_, axis=1)        
        mask = np.maximum(mask, mask_)
        
    Y_train[n] = mask
# Out:
# Getting and resizing train images and masks ...
# /var/folders/qr/np1v1r_53zqc4t2j9qztcrxh0000gn/T/ipykernel_85510/431872359.py:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
#   0%|                                                  | 0/1809 [00:00<?, ?it/s]/var/folders/qr/np1v1r_53zqc4t2j9qztcrxh0000gn/T/ipykernel_85510/431872359.py:11: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
#  65%|█████████████████████████▌             | 1184/1809 [01:48<00:54, 11.49it/s]

# %%
# Check if training data looks all right
# DOUBLE CHECK MASKS!!
ix = random.randint(0, len(train_ids))

print(ix, train_ids[ix])
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()
# Out:
# 1708 351771edfc5db5665ded8aa4940257276b6526663c76e3b60b92a52584d8943c

# %%
# allowing for hyperparam tuning
import keras_tuner as kt
hp = kt.HyperParameters()

# %%
def model_builder(hp):

    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))

    output_1 = Dense(64, activation='relu')(inputs)
    output_2 = Dense(64, activation='relu')(output_1)
    outputs = Dense(1, activation='sigmoid')(output_2)

    model = Model(inputs=[inputs], outputs=[outputs])

    # here we're using the hyperparam for learning rate!
    model.compile(tf.keras.optimizers.Adam(hp.Float('learning_rate', 1e-4, 1e-2, sampling='log'), amsgrad= True), loss='binary_crossentropy', metrics=tf.keras.metrics.BinaryIoU(target_class_ids=[0, 1], threshold=0.3))

#     model.summary()
    
    return model

# %%
tuner = kt.RandomSearch(
    model_builder,
    objective = kt.Objective("mean_io_u", direction="max"),
    max_trials=5)
# Out:
# INFO:tensorflow:Reloading Tuner from ./untitled_project/tuner0.json

# %%
# TURNING OFF STOP EARLY
tuner.search(X_train, Y_train, epochs=5, validation_split=0.2)

best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"""
The hyperparameter search is complete. The optimal number of units in the first densely-connected
layer is ... and the optimal learning rate for the optimizer
is {best_hps.get('learning_rate')}.
""")
# Out:
# INFO:tensorflow:Oracle triggered exit
#
# The hyperparameter search is complete. The optimal number of units in the first densely-connected
# layer is ... and the optimal learning rate for the optimizer
# is 0.0017991073735913667.

# %%
model = tuner.hypermodel.build(best_hps)
# Out:
# 2023-03-30 11:23:27.451712: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
## ADDING ADVERSARIAL ATTACK...
loss_object = tf.keras.losses.BinaryCrossentropy()

def create_adversarial_pattern(input_image, input_label):
    input_image = tf.convert_to_tensor(np.reshape(input_image, (-1, 128, 128, 1)), dtype=tf.float32)
    input_label = np.reshape(input_label, (-1, 128, 128, 1))

#     Record operations for automatic differentiation??
    with tf.GradientTape() as tape:

        tape.watch(input_image)
        prediction = model(input_image)
        
        loss = loss_object(input_label, prediction)

#   # Get the gradients of the loss w.r.t to the input image.
    gradient = tape.gradient(loss, input_image)

    # Get the sign of the gradients to create the perturbation
    signed_grad = tf.sign(gradient)
    
    return signed_grad

# %%
# Get the input label of the image. -->  THIS NEEDS TO BE A LOOP THROUGH THE IMAGES!!
# WE CAN RANDOMIZE HOW MANY GET A PERTURBATION!!

pert = []

for i in range(len(X_train)):
    pert.append(create_adversarial_pattern(X_train[i],Y_train[i]))

# %%
# making a function for adding peterubation!!!!!
def addingep (ep):
    newtrain = []

    for i in range(len(X_train)): 
        pert[i] = tf.reshape(pert[i], [1, 128, 128])
        new = X_train[i] + ep* pert[i] * 0.5 + 0.5
        newtrain.append(np.squeeze(new.numpy()))

    newtrain = np.asarray(newtrain)
    newtrain = np.squeeze(newtrain)
    
    return newtrain

# %%
# Generates a new X_train
newtrain_0 = addingep(0)

# %%
X_train.shape
# Out:
# (1809, 128, 128)

# %%
newtrain_0.shape
# Out:
# (1809, 128, 128)

# %%
# Let's visualize what we've done here...
# Perform a sanity check on some random training samples
ix = random.randint(0, len(newtrain_0))
print(ix)
imshow(X_train[ix])
plt.title('Raw Image')
plt.show()
imshow(newtrain_0[ix].astype('uint8'))
plt.title('Epsilon=0 Image')
plt.show()
imshow(np.squeeze(pert[ix]))
plt.title('Ep=2 Perturbation')
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.title('Mask')
plt.show()
# Out:
# 388

# %%
# increasing epoch val to 50!!
history = model.fit(newtrain_0, Y_train, epochs=50, batch_size= 32, validation_split=0.2)
# Out:
# Epoch 1/50
# 46/46 [==============================] - 7s 133ms/step - loss: 1.5284 - binary_io_u: 0.1292 - val_loss: 0.6099 - val_binary_io_u: 0.0867
# Epoch 2/50
# 46/46 [==============================] - 6s 129ms/step - loss: 0.5477 - binary_io_u: 0.1007 - val_loss: 0.5046 - val_binary_io_u: 0.1091
# Epoch 3/50
# 46/46 [==============================] - 6s 128ms/step - loss: 0.4652 - binary_io_u: 0.3846 - val_loss: 0.4085 - val_binary_io_u: 0.5703
# Epoch 4/50
# 46/46 [==============================] - 6s 132ms/step - loss: 0.4005 - binary_io_u: 0.4962 - val_loss: 0.3961 - val_binary_io_u: 0.6376
# Epoch 5/50
# 46/46 [==============================] - 6s 130ms/step - loss: 0.3534 - binary_io_u: 0.4946 - val_loss: 0.3243 - val_binary_io_u: 0.6255
# Epoch 6/50
# 46/46 [==============================] - 6s 132ms/step - loss: 0.3140 - binary_io_u: 0.4897 - val_loss: 0.3344 - val_binary_io_u: 0.4239
# Epoch 7/50
# 46/46 [==============================] - 6s 131ms/step - loss: 0.3616 - binary_io_u: 0.5197 - val_loss: 0.2875 - val_binary_io_u: 0.4239
# Epoch 8/50
# 46/46 [==============================] - 6s 131ms/step - loss: 0.2988 - binary_io_u: 0.5374 - val_loss: 0.2764 - val_binary_io_u: 0.4239
# Epoch 9/50
# 46/46 [==============================] - 6s 132ms/step - loss: 0.2729 - binary_io_u: 0.6035 - val_loss: 0.2518 - val_binary_io_u: 0.6385
# Epoch 10/50
# 46/46 [==============================] - 6s 131ms/step - loss: 0.2643 - binary_io_u: 0.6316 - val_loss: 0.2489 - val_binary_io_u: 0.6385
# Epoch 11/50
# 46/46 [==============================] - 6s 131ms/step - loss: 0.2556 - binary_io_u: 0.6564 - val_loss: 0.2372 - val_binary_io_u: 0.6360
# Epoch 12/50
# 46/46 [==============================] - 6s 131ms/step - loss: 0.2510 - binary_io_u: 0.6611 - val_loss: 0.2328 - val_binary_io_u: 0.7755
# Epoch 13/50
# 46/46 [==============================] - 6s 131ms/step - loss: 0.2417 - binary_io_u: 0.6712 - val_loss: 0.2391 - val_binary_io_u: 0.6347
# Epoch 14/50
# 46/46 [==============================] - 6s 132ms/step - loss: 0.2532 - binary_io_u: 0.6451 - val_loss: 0.2171 - val_binary_io_u: 0.8037
# Epoch 15/50
# 46/46 [==============================] - 6s 131ms/step - loss: 0.2256 - binary_io_u: 0.7103 - val_loss: 0.2479 - val_binary_io_u: 0.6360
# Epoch 16/50
# 46/46 [==============================] - 6s 132ms/step - loss: 0.2411 - binary_io_u: 0.6517 - val_loss: 0.2730 - val_binary_io_u: 0.5819
# Epoch 17/50
# 46/46 [==============================] - 6s 130ms/step - loss: 0.2469 - binary_io_u: 0.6459 - val_loss: 0.2040 - val_binary_io_u: 0.7947
# Epoch 18/50
# 46/46 [==============================] - 6s 131ms/step - loss: 0.2153 - binary_io_u: 0.7155 - val_loss: 0.1963 - val_binary_io_u: 0.8165
# Epoch 19/50
# 46/46 [==============================] - 6s 135ms/step - loss: 0.2066 - binary_io_u: 0.7556 - val_loss: 0.1916 - val_binary_io_u: 0.8123
# Epoch 20/50
# 46/46 [==============================] - 6s 140ms/step - loss: 0.2079 - binary_io_u: 0.7273 - val_loss: 0.2058 - val_binary_io_u: 0.6378
# Epoch 21/50
# 46/46 [==============================] - 6s 140ms/step - loss: 0.2074 - binary_io_u: 0.7242 - val_loss: 0.1851 - val_binary_io_u: 0.7917
# Epoch 22/50
# 46/46 [==============================] - 6s 136ms/step - loss: 0.1946 - binary_io_u: 0.7697 - val_loss: 0.1822 - val_binary_io_u: 0.8069
# Epoch 23/50
# 46/46 [==============================] - 6s 132ms/step - loss: 0.1923 - binary_io_u: 0.7783 - val_loss: 0.1787 - val_binary_io_u: 0.8082
# Epoch 24/50
# 46/46 [==============================] - 7s 143ms/step - loss: 0.2011 - binary_io_u: 0.7190 - val_loss: 0.1787 - val_binary_io_u: 0.8017
# Epoch 25/50
# 46/46 [==============================] - 6s 132ms/step - loss: 0.1928 - binary_io_u: 0.7278 - val_loss: 0.1837 - val_binary_io_u: 0.7773
# Epoch 26/50
# 46/46 [==============================] - 6s 136ms/step - loss: 0.1845 - binary_io_u: 0.7689 - val_loss: 0.2102 - val_binary_io_u: 0.7181
# Epoch 27/50
# 46/46 [==============================] - 6s 133ms/step - loss: 0.1857 - binary_io_u: 0.7505 - val_loss: 0.1675 - val_binary_io_u: 0.8004
# Epoch 28/50
# 46/46 [==============================] - 6s 138ms/step - loss: 0.1822 - binary_io_u: 0.7610 - val_loss: 0.1744 - val_binary_io_u: 0.7901
# Epoch 29/50
# 46/46 [==============================] - 6s 133ms/step - loss: 0.1762 - binary_io_u: 0.7772 - val_loss: 0.1685 - val_binary_io_u: 0.8011
# Epoch 30/50
# 46/46 [==============================] - 6s 137ms/step - loss: 0.1828 - binary_io_u: 0.7556 - val_loss: 0.1900 - val_binary_io_u: 0.6370
# Epoch 31/50
# 46/46 [==============================] - 6s 135ms/step - loss: 0.1826 - binary_io_u: 0.7424 - val_loss: 0.1614 - val_binary_io_u: 0.8087
# Epoch 32/50
# 46/46 [==============================] - 6s 133ms/step - loss: 0.1684 - binary_io_u: 0.7974 - val_loss: 0.1737 - val_binary_io_u: 0.7778
# Epoch 33/50
# 46/46 [==============================] - 6s 133ms/step - loss: 0.1755 - binary_io_u: 0.7636 - val_loss: 0.1748 - val_binary_io_u: 0.7746
# Epoch 34/50
# 46/46 [==============================] - 6s 135ms/step - loss: 0.1716 - binary_io_u: 0.7775 - val_loss: 0.1602 - val_binary_io_u: 0.8105
# Epoch 35/50
# 46/46 [==============================] - 6s 132ms/step - loss: 0.1671 - binary_io_u: 0.7912 - val_loss: 0.1717 - val_binary_io_u: 0.7773
# Epoch 36/50
# 46/46 [==============================] - 6s 132ms/step - loss: 0.1674 - binary_io_u: 0.7858 - val_loss: 0.1528 - val_binary_io_u: 0.8132
# Epoch 37/50
# 46/46 [==============================] - 6s 131ms/step - loss: 0.1639 - binary_io_u: 0.7936 - val_loss: 0.1600 - val_binary_io_u: 0.7936
# Epoch 38/50
# 46/46 [==============================] - 6s 132ms/step - loss: 0.1638 - binary_io_u: 0.7912 - val_loss: 0.1495 - val_binary_io_u: 0.8141
# Epoch 39/50
# 46/46 [==============================] - 6s 132ms/step - loss: 0.1639 - binary_io_u: 0.7911 - val_loss: 0.1491 - val_binary_io_u: 0.8127
# Epoch 40/50
# 46/46 [==============================] - 6s 130ms/step - loss: 0.1584 - binary_io_u: 0.7989 - val_loss: 0.1547 - val_binary_io_u: 0.8031
# Epoch 41/50
# 46/46 [==============================] - 6s 130ms/step - loss: 0.1657 - binary_io_u: 0.7793 - val_loss: 0.1543 - val_binary_io_u: 0.7910
# Epoch 42/50
# 46/46 [==============================] - 6s 130ms/step - loss: 0.1625 - binary_io_u: 0.7779 - val_loss: 0.1604 - val_binary_io_u: 0.7984
# Epoch 43/50
# 46/46 [==============================] - 6s 130ms/step - loss: 0.1566 - binary_io_u: 0.7953 - val_loss: 0.1454 - val_binary_io_u: 0.8101
# Epoch 44/50
# 46/46 [==============================] - 6s 129ms/step - loss: 0.1572 - binary_io_u: 0.7969 - val_loss: 0.1479 - val_binary_io_u: 0.8108
# Epoch 45/50
# 46/46 [==============================] - 6s 131ms/step - loss: 0.1559 - binary_io_u: 0.7976 - val_loss: 0.1589 - val_binary_io_u: 0.7897
# Epoch 46/50
# 46/46 [==============================] - 6s 130ms/step - loss: 0.1608 - binary_io_u: 0.7901 - val_loss: 0.1469 - val_binary_io_u: 0.8165
# Epoch 47/50
# 46/46 [==============================] - 6s 130ms/step - loss: 0.1563 - binary_io_u: 0.7952 - val_loss: 0.1459 - val_binary_io_u: 0.8083
# Epoch 48/50
# 46/46 [==============================] - 6s 134ms/step - loss: 0.1577 - binary_io_u: 0.7924 - val_loss: 0.1424 - val_binary_io_u: 0.8165
# Epoch 49/50
# 46/46 [==============================] - 6s 140ms/step - loss: 0.1523 - binary_io_u: 0.8005 - val_loss: 0.1463 - val_binary_io_u: 0.8109
# Epoch 50/50
# 46/46 [==============================] - 6s 131ms/step - loss: 0.1519 - binary_io_u: 0.8005 - val_loss: 0.1430 - val_binary_io_u: 0.8126

# %%
val_acc_per_epoch = history.history['val_binary_io_u']
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Best epoch: 46

# %%
# use the best number of epochs
hypermodel = tuner.hypermodel.build(best_hps)

# FROM = 2023/03/30
# # REMEMBER TO CHANGE THE NAME OF THE MODEL!!
checkpointer = ModelCheckpoint('model-FCNEp=0Model_20230330.h5', verbose=1, save_best_only=True)
# Retrain the model--> USE THE NEW_TRAIN
result = hypermodel.fit(newtrain_0, Y_train, epochs=best_epoch, validation_split=0.2, callbacks=[checkpointer])
# Out:
# Epoch 1/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.8358 - binary_io_u_1: 0.1175
# Epoch 1: val_loss improved from inf to 0.53340, saving model to model-FCNEp=0Model_20230330.h5
# 46/46 [==============================] - 7s 136ms/step - loss: 0.8339 - binary_io_u_1: 0.1174 - val_loss: 0.5334 - val_binary_io_u_1: 0.0834
# Epoch 2/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.5209 - binary_io_u_1: 0.3275
# Epoch 2: val_loss improved from 0.53340 to 0.45009, saving model to model-FCNEp=0Model_20230330.h5
# 46/46 [==============================] - 6s 134ms/step - loss: 0.5212 - binary_io_u_1: 0.3280 - val_loss: 0.4501 - val_binary_io_u_1: 0.5580
# Epoch 3/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.4417 - binary_io_u_1: 0.4621
# Epoch 3: val_loss did not improve from 0.45009
# 46/46 [==============================] - 6s 132ms/step - loss: 0.4414 - binary_io_u_1: 0.4628 - val_loss: 0.4907 - val_binary_io_u_1: 0.6305
# Epoch 4/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.4376 - binary_io_u_1: 0.4920
# Epoch 4: val_loss did not improve from 0.45009
# 46/46 [==============================] - 6s 135ms/step - loss: 0.4392 - binary_io_u_1: 0.4920 - val_loss: 0.4990 - val_binary_io_u_1: 0.4239
# Epoch 5/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.4486 - binary_io_u_1: 0.4746
# Epoch 5: val_loss did not improve from 0.45009
# 46/46 [==============================] - 6s 137ms/step - loss: 0.4491 - binary_io_u_1: 0.4748 - val_loss: 0.5179 - val_binary_io_u_1: 0.4239
# Epoch 6/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.5957 - binary_io_u_1: 0.4914
# Epoch 6: val_loss improved from 0.45009 to 0.31450, saving model to model-FCNEp=0Model_20230330.h5
# 46/46 [==============================] - 6s 139ms/step - loss: 0.5945 - binary_io_u_1: 0.4913 - val_loss: 0.3145 - val_binary_io_u_1: 0.4607
# Epoch 7/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.3360 - binary_io_u_1: 0.4728
# Epoch 7: val_loss did not improve from 0.31450
# 46/46 [==============================] - 6s 135ms/step - loss: 0.3360 - binary_io_u_1: 0.4742 - val_loss: 0.4190 - val_binary_io_u_1: 0.6380
# Epoch 8/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.3478 - binary_io_u_1: 0.5335
# Epoch 8: val_loss improved from 0.31450 to 0.26662, saving model to model-FCNEp=0Model_20230330.h5
# 46/46 [==============================] - 6s 130ms/step - loss: 0.3482 - binary_io_u_1: 0.5328 - val_loss: 0.2666 - val_binary_io_u_1: 0.6378
# Epoch 9/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.3063 - binary_io_u_1: 0.5523
# Epoch 9: val_loss did not improve from 0.26662
# 46/46 [==============================] - 6s 130ms/step - loss: 0.3073 - binary_io_u_1: 0.5527 - val_loss: 0.2910 - val_binary_io_u_1: 0.6327
# Epoch 10/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.3095 - binary_io_u_1: 0.5662
# Epoch 10: val_loss improved from 0.26662 to 0.22942, saving model to model-FCNEp=0Model_20230330.h5
# 46/46 [==============================] - 6s 131ms/step - loss: 0.3096 - binary_io_u_1: 0.5660 - val_loss: 0.2294 - val_binary_io_u_1: 0.7548
# Epoch 11/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.2472 - binary_io_u_1: 0.6759
# Epoch 11: val_loss improved from 0.22942 to 0.22817, saving model to model-FCNEp=0Model_20230330.h5
# 46/46 [==============================] - 6s 131ms/step - loss: 0.2473 - binary_io_u_1: 0.6759 - val_loss: 0.2282 - val_binary_io_u_1: 0.7118
# Epoch 12/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.2256 - binary_io_u_1: 0.7000
# Epoch 12: val_loss improved from 0.22817 to 0.20506, saving model to model-FCNEp=0Model_20230330.h5
# 46/46 [==============================] - 6s 129ms/step - loss: 0.2257 - binary_io_u_1: 0.6995 - val_loss: 0.2051 - val_binary_io_u_1: 0.8083
# Epoch 13/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.2415 - binary_io_u_1: 0.6604
# Epoch 13: val_loss improved from 0.20506 to 0.20053, saving model to model-FCNEp=0Model_20230330.h5
# 46/46 [==============================] - 6s 134ms/step - loss: 0.2408 - binary_io_u_1: 0.6604 - val_loss: 0.2005 - val_binary_io_u_1: 0.6378
# Epoch 14/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.2344 - binary_io_u_1: 0.6723
# Epoch 14: val_loss did not improve from 0.20053
# 46/46 [==============================] - 6s 137ms/step - loss: 0.2348 - binary_io_u_1: 0.6710 - val_loss: 0.2925 - val_binary_io_u_1: 0.5952
# Epoch 15/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.2264 - binary_io_u_1: 0.6855
# Epoch 15: val_loss did not improve from 0.20053
# 46/46 [==============================] - 7s 145ms/step - loss: 0.2262 - binary_io_u_1: 0.6860 - val_loss: 0.2317 - val_binary_io_u_1: 0.6876
# Epoch 16/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.2037 - binary_io_u_1: 0.7077
# Epoch 16: val_loss improved from 0.20053 to 0.19271, saving model to model-FCNEp=0Model_20230330.h5
# 46/46 [==============================] - 6s 133ms/step - loss: 0.2041 - binary_io_u_1: 0.7076 - val_loss: 0.1927 - val_binary_io_u_1: 0.7601
# Epoch 17/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.1837 - binary_io_u_1: 0.7605
# Epoch 17: val_loss improved from 0.19271 to 0.16930, saving model to model-FCNEp=0Model_20230330.h5
# 46/46 [==============================] - 7s 150ms/step - loss: 0.1835 - binary_io_u_1: 0.7608 - val_loss: 0.1693 - val_binary_io_u_1: 0.8102
# Epoch 18/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.1820 - binary_io_u_1: 0.7557
# Epoch 18: val_loss improved from 0.16930 to 0.16502, saving model to model-FCNEp=0Model_20230330.h5
# 46/46 [==============================] - 6s 136ms/step - loss: 0.1819 - binary_io_u_1: 0.7561 - val_loss: 0.1650 - val_binary_io_u_1: 0.8020
# Epoch 19/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.1773 - binary_io_u_1: 0.7759
# Epoch 19: val_loss did not improve from 0.16502
# 46/46 [==============================] - 6s 131ms/step - loss: 0.1776 - binary_io_u_1: 0.7743 - val_loss: 0.1965 - val_binary_io_u_1: 0.7466
# Epoch 20/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.1904 - binary_io_u_1: 0.7352
# Epoch 20: val_loss did not improve from 0.16502
# 46/46 [==============================] - 6s 133ms/step - loss: 0.1905 - binary_io_u_1: 0.7355 - val_loss: 0.2157 - val_binary_io_u_1: 0.6305
# Epoch 21/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.1966 - binary_io_u_1: 0.7167
# Epoch 21: val_loss improved from 0.16502 to 0.15666, saving model to model-FCNEp=0Model_20230330.h5
# 46/46 [==============================] - 6s 133ms/step - loss: 0.1963 - binary_io_u_1: 0.7171 - val_loss: 0.1567 - val_binary_io_u_1: 0.7923
# Epoch 22/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.1666 - binary_io_u_1: 0.7792
# Epoch 22: val_loss did not improve from 0.15666
# 46/46 [==============================] - 6s 134ms/step - loss: 0.1668 - binary_io_u_1: 0.7788 - val_loss: 0.1757 - val_binary_io_u_1: 0.7812
# Epoch 23/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.1714 - binary_io_u_1: 0.7638
# Epoch 23: val_loss improved from 0.15666 to 0.15358, saving model to model-FCNEp=0Model_20230330.h5
# 46/46 [==============================] - 6s 133ms/step - loss: 0.1719 - binary_io_u_1: 0.7640 - val_loss: 0.1536 - val_binary_io_u_1: 0.8065
# Epoch 24/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.1596 - binary_io_u_1: 0.7918
# Epoch 24: val_loss improved from 0.15358 to 0.15013, saving model to model-FCNEp=0Model_20230330.h5
# 46/46 [==============================] - 6s 134ms/step - loss: 0.1596 - binary_io_u_1: 0.7920 - val_loss: 0.1501 - val_binary_io_u_1: 0.8147
# Epoch 25/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.1627 - binary_io_u_1: 0.7855
# Epoch 25: val_loss did not improve from 0.15013
# 46/46 [==============================] - 6s 138ms/step - loss: 0.1625 - binary_io_u_1: 0.7856 - val_loss: 0.1727 - val_binary_io_u_1: 0.6450
# Epoch 26/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.1686 - binary_io_u_1: 0.7657
# Epoch 26: val_loss did not improve from 0.15013
# 46/46 [==============================] - 6s 135ms/step - loss: 0.1685 - binary_io_u_1: 0.7657 - val_loss: 0.1661 - val_binary_io_u_1: 0.7778
# Epoch 27/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.1644 - binary_io_u_1: 0.7700
# Epoch 27: val_loss improved from 0.15013 to 0.14900, saving model to model-FCNEp=0Model_20230330.h5
# 46/46 [==============================] - 6s 132ms/step - loss: 0.1646 - binary_io_u_1: 0.7682 - val_loss: 0.1490 - val_binary_io_u_1: 0.7950
# Epoch 28/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.2862 - binary_io_u_1: 0.6814
# Epoch 28: val_loss did not improve from 0.14900
# 46/46 [==============================] - 6s 132ms/step - loss: 0.2864 - binary_io_u_1: 0.6809 - val_loss: 0.2722 - val_binary_io_u_1: 0.6360
# Epoch 29/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.1886 - binary_io_u_1: 0.7518
# Epoch 29: val_loss improved from 0.14900 to 0.14463, saving model to model-FCNEp=0Model_20230330.h5
# 46/46 [==============================] - 6s 129ms/step - loss: 0.1885 - binary_io_u_1: 0.7519 - val_loss: 0.1446 - val_binary_io_u_1: 0.8043
# Epoch 30/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.1599 - binary_io_u_1: 0.7873
# Epoch 30: val_loss did not improve from 0.14463
# 46/46 [==============================] - 6s 130ms/step - loss: 0.1600 - binary_io_u_1: 0.7875 - val_loss: 0.1464 - val_binary_io_u_1: 0.8071
# Epoch 31/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.1566 - binary_io_u_1: 0.7893
# Epoch 31: val_loss did not improve from 0.14463
# 46/46 [==============================] - 6s 130ms/step - loss: 0.1564 - binary_io_u_1: 0.7892 - val_loss: 0.1450 - val_binary_io_u_1: 0.8136
# Epoch 32/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.1573 - binary_io_u_1: 0.7894
# Epoch 32: val_loss did not improve from 0.14463
# 46/46 [==============================] - 6s 131ms/step - loss: 0.1571 - binary_io_u_1: 0.7896 - val_loss: 0.1457 - val_binary_io_u_1: 0.7942
# Epoch 33/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.1526 - binary_io_u_1: 0.7942
# Epoch 33: val_loss did not improve from 0.14463
# 46/46 [==============================] - 6s 136ms/step - loss: 0.1527 - binary_io_u_1: 0.7943 - val_loss: 0.1463 - val_binary_io_u_1: 0.8092
# Epoch 34/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.1600 - binary_io_u_1: 0.7836
# Epoch 34: val_loss improved from 0.14463 to 0.14304, saving model to model-FCNEp=0Model_20230330.h5
# 46/46 [==============================] - 6s 138ms/step - loss: 0.1598 - binary_io_u_1: 0.7839 - val_loss: 0.1430 - val_binary_io_u_1: 0.8025
# Epoch 35/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.1562 - binary_io_u_1: 0.7864
# Epoch 35: val_loss did not improve from 0.14304
# 46/46 [==============================] - 6s 134ms/step - loss: 0.1566 - binary_io_u_1: 0.7864 - val_loss: 0.2048 - val_binary_io_u_1: 0.7504
# Epoch 36/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.1745 - binary_io_u_1: 0.7576
# Epoch 36: val_loss did not improve from 0.14304
# 46/46 [==============================] - 6s 134ms/step - loss: 0.1742 - binary_io_u_1: 0.7582 - val_loss: 0.1856 - val_binary_io_u_1: 0.7108
# Epoch 37/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.1950 - binary_io_u_1: 0.7327
# Epoch 37: val_loss did not improve from 0.14304
# 46/46 [==============================] - 6s 132ms/step - loss: 0.1951 - binary_io_u_1: 0.7329 - val_loss: 0.1622 - val_binary_io_u_1: 0.7841
# Epoch 38/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.1615 - binary_io_u_1: 0.7816
# Epoch 38: val_loss did not improve from 0.14304
# 46/46 [==============================] - 6s 132ms/step - loss: 0.1614 - binary_io_u_1: 0.7819 - val_loss: 0.1444 - val_binary_io_u_1: 0.7987
# Epoch 39/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.1576 - binary_io_u_1: 0.7867
# Epoch 39: val_loss did not improve from 0.14304
# 46/46 [==============================] - 6s 132ms/step - loss: 0.1575 - binary_io_u_1: 0.7869 - val_loss: 0.1432 - val_binary_io_u_1: 0.7987
# Epoch 40/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.1663 - binary_io_u_1: 0.7717
# Epoch 40: val_loss improved from 0.14304 to 0.14210, saving model to model-FCNEp=0Model_20230330.h5
# 46/46 [==============================] - 6s 132ms/step - loss: 0.1664 - binary_io_u_1: 0.7721 - val_loss: 0.1421 - val_binary_io_u_1: 0.8060
# Epoch 41/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.1507 - binary_io_u_1: 0.7957
# Epoch 41: val_loss did not improve from 0.14210
# 46/46 [==============================] - 6s 137ms/step - loss: 0.1509 - binary_io_u_1: 0.7957 - val_loss: 0.1427 - val_binary_io_u_1: 0.8037
# Epoch 42/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.1509 - binary_io_u_1: 0.7921
# Epoch 42: val_loss did not improve from 0.14210
# 46/46 [==============================] - 6s 140ms/step - loss: 0.1512 - binary_io_u_1: 0.7920 - val_loss: 0.1445 - val_binary_io_u_1: 0.8003
# Epoch 43/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.1498 - binary_io_u_1: 0.7954
# Epoch 43: val_loss improved from 0.14210 to 0.13854, saving model to model-FCNEp=0Model_20230330.h5
# 46/46 [==============================] - 6s 135ms/step - loss: 0.1501 - binary_io_u_1: 0.7947 - val_loss: 0.1385 - val_binary_io_u_1: 0.8072
# Epoch 44/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.1532 - binary_io_u_1: 0.7936
# Epoch 44: val_loss did not improve from 0.13854
# 46/46 [==============================] - 6s 136ms/step - loss: 0.1532 - binary_io_u_1: 0.7938 - val_loss: 0.1871 - val_binary_io_u_1: 0.7790
# Epoch 45/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.1603 - binary_io_u_1: 0.7879
# Epoch 45: val_loss improved from 0.13854 to 0.13805, saving model to model-FCNEp=0Model_20230330.h5
# 46/46 [==============================] - 6s 138ms/step - loss: 0.1600 - binary_io_u_1: 0.7881 - val_loss: 0.1381 - val_binary_io_u_1: 0.8072
# Epoch 46/46
# 45/46 [============================>.] - ETA: 0s - loss: 0.1639 - binary_io_u_1: 0.7735
# Epoch 46: val_loss did not improve from 0.13805
# 46/46 [==============================] - 6s 134ms/step - loss: 0.1640 - binary_io_u_1: 0.7736 - val_loss: 0.1758 - val_binary_io_u_1: 0.7771

# %%
# ALTER THE NAMING CONVENTIONS..
def plot_training(hist):
    '''
    This function take training model and plot history of accuracy and losses with the best epoch in both of them.
    '''

    # Define needed variables--> these two need to be diff
    tr_acc = hist.history['binary_io_u_1']
    tr_loss = hist.history['loss']
    val_acc = hist.history['val_binary_io_u_1']
    val_loss = hist.history['val_loss']
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]
    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'

    # Plot training history
    plt.figure(figsize= (20, 8))
    plt.style.use('fivethirtyeight')

    plt.subplot(1, 2, 1)
    plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
    plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
    plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training and Validation Binary IOU')
    plt.xlabel('Epochs')
    plt.ylabel('Binary IOU')
    plt.legend()

    # change the title!!
    plt.suptitle("FCN trained with Ep = 0", fontsize=30)
    plt.tight_layout
    plt.savefig('model-FCNEp=0Model_20230330.png')

    plt.show()

# %%
# results.history
plot_training(result)

# %%
# we could stop here...
