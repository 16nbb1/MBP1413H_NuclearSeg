# %%
import os
import sys
import glob
import random
import warnings
import shutil
from distutils.dir_util import copy_tree


import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

from keras.models import Model, load_model
from keras.layers import Input
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
# from keras.layers.merge import concatenate
from keras.layers import concatenate

from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

import tensorflow as tf
from tensorflow.keras.metrics import Metric

import skimage.io

# %%
# Set some parameters
IMG_WIDTH = 128
IMG_HEIGHT = 128
# IMG_CHANNELS = 3
IMG_CHANNELS = 1

# %%
# the small set for experimentation!
TRAIN_PATH = './FORmodels/trainset_raw/'

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
seed = 42
random.seed = seed
np.random.seed = seed

# Get train and test IDs
train_ids = next(os.walk(TRAIN_PATH))[1]
len(train_ids)
# Out:
# 1809

# %%
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH), dtype=np.bool)
Y_train.shape
# Out:
# /var/folders/qr/np1v1r_53zqc4t2j9qztcrxh0000gn/T/ipykernel_40326/187304916.py:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH), dtype=np.bool)
# (1809, 128, 128)

# %%
# Get and resize train images and masks
X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH), dtype=np.uint8)
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
print('Getting and resizing train images and masks ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    pather = TRAIN_PATH + id_    
    img = imread(pather + '/images/' + id_ + '.png')
    X_train[n] = img
    
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
        
    pattern = pather+'/masks/*'
    for fname in glob.glob(pattern, recursive=True):

        mask_ = imread(fname)     
        mask_ = resize(mask_,(IMG_HEIGHT, IMG_WIDTH, 1))
#         mask_ = np.expand_dims(mask_, axis=1)        
        mask = np.maximum(mask, mask_)
        
    Y_train[n] = mask
# Out:
# Getting and resizing train images and masks ...
# /var/folders/qr/np1v1r_53zqc4t2j9qztcrxh0000gn/T/ipykernel_40326/431872359.py:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
#   0%|                                                  | 0/1809 [00:00<?, ?it/s]/var/folders/qr/np1v1r_53zqc4t2j9qztcrxh0000gn/T/ipykernel_40326/431872359.py:11: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
# 100%|███████████████████████████████████████| 1809/1809 [02:41<00:00, 11.22it/s]

# %%
# Check if training data looks all right
# DOUBLE CHECK MASKS!!
ix = random.randint(0, len(train_ids))

print(ix, train_ids[ix])
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()
# Out:
# 1535 5419302571113e9aa74c7c0a9575333ca539b871a16c86ee92b35170b4ddc52e_updown

# %%
# allowing for hyperparam tuning
import keras_tuner as kt
hp = kt.HyperParameters()

# %%
def model_builder(hp):

    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    s = Lambda(lambda x: x / 255) (inputs)

    c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (s)
    c1 = Dropout(0.1) (c1)
    c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c1)
    p1 = MaxPooling2D((2, 2)) (c1)

    c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p1)
    c2 = Dropout(0.1) (c2)
    c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c2)
    p2 = MaxPooling2D((2, 2)) (c2)

    c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p2)
    c3 = Dropout(0.2) (c3)
    c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c3)
    p3 = MaxPooling2D((2, 2)) (c3)

    c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p3)
    c4 = Dropout(0.2) (c4)
    c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c4)
    p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

    c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p4)
    c5 = Dropout(0.3) (c5)
    c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c5)

    u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c5)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u6)
    c6 = Dropout(0.2) (c6)
    c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c6)

    u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u7)
    c7 = Dropout(0.2) (c7)
    c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c7)

    u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u8)
    c8 = Dropout(0.1) (c8)
    c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c8)

    u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u9)
    c9 = Dropout(0.1) (c9)
    c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c9)

    outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)

    model = Model(inputs=[inputs], outputs=[outputs])

    # here we're using the hyperparam for learning rate!
    model.compile(tf.keras.optimizers.Adam(hp.Float('learning_rate', 1e-4, 1e-2, sampling='log'), amsgrad= True), loss='binary_crossentropy', metrics=tf.keras.metrics.BinaryIoU(target_class_ids=[0, 1], threshold=0.3))

#     model.summary()
    
    return model

# %%
tuner = kt.RandomSearch(
    model_builder,
    objective = kt.Objective("mean_io_u", direction="max"),
    max_trials=5)
# Out:
# INFO:tensorflow:Reloading Tuner from ./untitled_project/tuner0.json

# %%
# TURNING OFF STOP EARLY
tuner.search(X_train, Y_train, epochs=5, validation_split=0.2)

best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"""
The hyperparameter search is complete. The optimal number of units in the first densely-connected
layer is ... and the optimal learning rate for the optimizer
is {best_hps.get('learning_rate')}.
""")
# Out:
# INFO:tensorflow:Oracle triggered exit
#
# The hyperparameter search is complete. The optimal number of units in the first densely-connected
# layer is ... and the optimal learning rate for the optimizer
# is 0.0008259900546842376.

# %%
model = tuner.hypermodel.build(best_hps)
# Out:
# 2023-04-01 18:02:26.280533: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
## ADDING ADVERSARIAL ATTACK...
loss_object = tf.keras.losses.BinaryCrossentropy()

def create_adversarial_pattern(input_image, input_label):
    input_image = tf.convert_to_tensor(np.reshape(input_image, (-1, 128, 128, 1)), dtype=tf.float32)
    input_label = np.reshape(input_label, (-1, 128, 128, 1))

#     Record operations for automatic differentiation??
    with tf.GradientTape() as tape:

        tape.watch(input_image)
        prediction = model(input_image)
        
        loss = loss_object(input_label, prediction)

#   # Get the gradients of the loss w.r.t to the input image.
    gradient = tape.gradient(loss, input_image)

    # Get the sign of the gradients to create the perturbation
    signed_grad = tf.sign(gradient)
    
    return signed_grad

# %%
# Get the input label of the image. -->  THIS NEEDS TO BE A LOOP THROUGH THE IMAGES!!
# WE CAN RANDOMIZE HOW MANY GET A PERTURBATION!!

pert = []

for i in range(len(X_train)):
    pert.append(create_adversarial_pattern(X_train[i],Y_train[i]))

# %%
# trying to randomize --> let's say we take random values between 0 and 50
# making a function for adding peterubation!!!!!
def addingep():
    newtrain = []
    randos = []

    for i in range(len(X_train)): 
        pert[i] = tf.reshape(pert[i], [1, 128, 128])
        lol = random.randint(0, 50)
        randos.append(lol)
        
        new = X_train[i] +  lol* pert[i] * 0.5 + 0.5
        newtrain.append(np.squeeze(new.numpy()))

    newtrain = np.asarray(newtrain)
    newtrain = np.squeeze(newtrain)
    
    plt.hist(randos)
    plt.title('Random epsilon values')
    plt.xlabel('Epsilon value')
    plt.ylabel('Frequency')
    plt.savefig('RandEpVals_histo.png')

    return newtrain

# %%
# Generates a new X_train
newtrain_VAR = addingep()

# %%
X_train.shape
# Out:
# (1809, 128, 128)

# %%
newtrain_VAR.shape
# Out:
# (1809, 128, 128)

# %%
# Let's visualize what we've done here...
# Perform a sanity check on some random training samples
ix = random.randint(0, len(newtrain_VAR))
print(ix)
imshow(X_train[ix])
plt.title('Raw Image')
plt.show()
imshow(newtrain_VAR[ix].astype('uint8'))
plt.title('Variable Epsilon Image')
plt.show()
imshow(np.squeeze(pert[ix]))
plt.title('Ep=2 Perturbation')
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.title('Mask')
plt.show()
# Out:
# 1038

# %%
# increasing epoch val to 50!!
history = model.fit(newtrain_VAR, Y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 46/46 [==============================] - 60s 1s/step - loss: 0.2928 - binary_io_u: 0.5703 - val_loss: 0.1460 - val_binary_io_u: 0.7920
# Epoch 2/50
# 46/46 [==============================] - 59s 1s/step - loss: 0.1538 - binary_io_u: 0.7834 - val_loss: 0.1302 - val_binary_io_u: 0.8081
# Epoch 3/50
# 46/46 [==============================] - 225s 5s/step - loss: 0.1328 - binary_io_u: 0.8085 - val_loss: 0.1186 - val_binary_io_u: 0.8253
# Epoch 4/50
# 46/46 [==============================] - 59s 1s/step - loss: 0.1194 - binary_io_u: 0.8274 - val_loss: 0.1043 - val_binary_io_u: 0.8554
# Epoch 5/50
# 46/46 [==============================] - 59s 1s/step - loss: 0.1155 - binary_io_u: 0.8336 - val_loss: 0.1007 - val_binary_io_u: 0.8530
# Epoch 6/50
# 46/46 [==============================] - 999s 17s/step - loss: 0.1088 - binary_io_u: 0.8411 - val_loss: 0.3121 - val_binary_io_u: 0.7643
# Epoch 7/50
# 46/46 [==============================] - 237s 5s/step - loss: 0.1145 - binary_io_u: 0.8367 - val_loss: 0.1023 - val_binary_io_u: 0.8440
# Epoch 8/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.1062 - binary_io_u: 0.8445 - val_loss: 0.0951 - val_binary_io_u: 0.8450
# Epoch 9/50
# 46/46 [==============================] - 60s 1s/step - loss: 0.1013 - binary_io_u: 0.8502 - val_loss: 0.0902 - val_binary_io_u: 0.8651
# Epoch 10/50
# 46/46 [==============================] - 59s 1s/step - loss: 0.1008 - binary_io_u: 0.8502 - val_loss: 0.0914 - val_binary_io_u: 0.8628
# Epoch 11/50
# 46/46 [==============================] - 60s 1s/step - loss: 0.0980 - binary_io_u: 0.8530 - val_loss: 0.0880 - val_binary_io_u: 0.8656
# Epoch 12/50
# 46/46 [==============================] - 60s 1s/step - loss: 0.0992 - binary_io_u: 0.8531 - val_loss: 0.0878 - val_binary_io_u: 0.8725
# Epoch 13/50
# 46/46 [==============================] - 60s 1s/step - loss: 0.0943 - binary_io_u: 0.8572 - val_loss: 0.0886 - val_binary_io_u: 0.8626
# Epoch 14/50
# 46/46 [==============================] - 516s 11s/step - loss: 0.0951 - binary_io_u: 0.8568 - val_loss: 0.0881 - val_binary_io_u: 0.8632
# Epoch 15/50
# 46/46 [==============================] - 59s 1s/step - loss: 0.0918 - binary_io_u: 0.8612 - val_loss: 0.0874 - val_binary_io_u: 0.8691
# Epoch 16/50
# 46/46 [==============================] - 2623s 58s/step - loss: 0.0916 - binary_io_u: 0.8622 - val_loss: 0.0841 - val_binary_io_u: 0.8665
# Epoch 17/50
# 46/46 [==============================] - 170s 4s/step - loss: 0.0903 - binary_io_u: 0.8627 - val_loss: 0.0836 - val_binary_io_u: 0.8725
# Epoch 18/50
# 46/46 [==============================] - 60s 1s/step - loss: 0.0917 - binary_io_u: 0.8606 - val_loss: 0.0888 - val_binary_io_u: 0.8631
# Epoch 19/50
# 46/46 [==============================] - 59s 1s/step - loss: 0.0894 - binary_io_u: 0.8636 - val_loss: 0.0897 - val_binary_io_u: 0.8794
# Epoch 20/50
# 46/46 [==============================] - 59s 1s/step - loss: 0.0888 - binary_io_u: 0.8659 - val_loss: 0.0822 - val_binary_io_u: 0.8639
# Epoch 21/50
# 46/46 [==============================] - 59s 1s/step - loss: 0.0857 - binary_io_u: 0.8686 - val_loss: 0.0814 - val_binary_io_u: 0.8740
# Epoch 22/50
# 46/46 [==============================] - 59s 1s/step - loss: 0.0847 - binary_io_u: 0.8692 - val_loss: 0.0791 - val_binary_io_u: 0.8782
# Epoch 23/50
# 46/46 [==============================] - 59s 1s/step - loss: 0.0857 - binary_io_u: 0.8681 - val_loss: 0.0781 - val_binary_io_u: 0.8769
# Epoch 24/50
# 46/46 [==============================] - 59s 1s/step - loss: 0.0837 - binary_io_u: 0.8705 - val_loss: 0.0773 - val_binary_io_u: 0.8815
# Epoch 25/50
# 46/46 [==============================] - 59s 1s/step - loss: 0.0849 - binary_io_u: 0.8695 - val_loss: 0.0809 - val_binary_io_u: 0.8715
# Epoch 26/50
# 46/46 [==============================] - 60s 1s/step - loss: 0.0897 - binary_io_u: 0.8636 - val_loss: 0.0821 - val_binary_io_u: 0.8676
# Epoch 27/50
# 46/46 [==============================] - 60s 1s/step - loss: 0.0909 - binary_io_u: 0.8610 - val_loss: 0.0805 - val_binary_io_u: 0.8762
# Epoch 28/50
# 46/46 [==============================] - 60s 1s/step - loss: 0.0850 - binary_io_u: 0.8681 - val_loss: 0.0799 - val_binary_io_u: 0.8783
# Epoch 29/50
# 46/46 [==============================] - 60s 1s/step - loss: 0.0860 - binary_io_u: 0.8687 - val_loss: 0.0815 - val_binary_io_u: 0.8722
# Epoch 30/50
# 46/46 [==============================] - 59s 1s/step - loss: 0.0853 - binary_io_u: 0.8670 - val_loss: 0.0774 - val_binary_io_u: 0.8759
# Epoch 31/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.0832 - binary_io_u: 0.8710 - val_loss: 0.0774 - val_binary_io_u: 0.8840
# Epoch 32/50
# 46/46 [==============================] - 60s 1s/step - loss: 0.0820 - binary_io_u: 0.8730 - val_loss: 0.0760 - val_binary_io_u: 0.8774
# Epoch 33/50
# 46/46 [==============================] - 60s 1s/step - loss: 0.0815 - binary_io_u: 0.8731 - val_loss: 0.0758 - val_binary_io_u: 0.8748
# Epoch 34/50
# 46/46 [==============================] - 60s 1s/step - loss: 0.0814 - binary_io_u: 0.8732 - val_loss: 0.0750 - val_binary_io_u: 0.8846
# Epoch 35/50
# 46/46 [==============================] - 59s 1s/step - loss: 0.0802 - binary_io_u: 0.8756 - val_loss: 0.0773 - val_binary_io_u: 0.8750
# Epoch 36/50
# 46/46 [==============================] - 60s 1s/step - loss: 0.0796 - binary_io_u: 0.8756 - val_loss: 0.0773 - val_binary_io_u: 0.8819
# Epoch 37/50
# 46/46 [==============================] - 60s 1s/step - loss: 0.0792 - binary_io_u: 0.8759 - val_loss: 0.0760 - val_binary_io_u: 0.8868
# Epoch 38/50
# 46/46 [==============================] - 60s 1s/step - loss: 0.0781 - binary_io_u: 0.8782 - val_loss: 0.0762 - val_binary_io_u: 0.8724
# Epoch 39/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.0818 - binary_io_u: 0.8717 - val_loss: 0.0753 - val_binary_io_u: 0.8793
# Epoch 40/50
# 46/46 [==============================] - 59s 1s/step - loss: 0.0803 - binary_io_u: 0.8740 - val_loss: 0.0734 - val_binary_io_u: 0.8855
# Epoch 41/50
# 46/46 [==============================] - 554s 12s/step - loss: 0.0785 - binary_io_u: 0.8766 - val_loss: 0.0737 - val_binary_io_u: 0.8846
# Epoch 42/50
# 46/46 [==============================] - 870s 15s/step - loss: 0.0777 - binary_io_u: 0.8774 - val_loss: 0.0722 - val_binary_io_u: 0.8867
# Epoch 43/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.0780 - binary_io_u: 0.8779 - val_loss: 0.0728 - val_binary_io_u: 0.8826
# Epoch 44/50
# 46/46 [==============================] - 72s 2s/step - loss: 0.0765 - binary_io_u: 0.8794 - val_loss: 0.0730 - val_binary_io_u: 0.8784
# Epoch 45/50
# 46/46 [==============================] - 83s 2s/step - loss: 0.0767 - binary_io_u: 0.8794 - val_loss: 0.0745 - val_binary_io_u: 0.8881
# Epoch 46/50
# 46/46 [==============================] - 91s 2s/step - loss: 0.0758 - binary_io_u: 0.8807 - val_loss: 0.0721 - val_binary_io_u: 0.8930
# Epoch 47/50
# 46/46 [==============================] - 126s 3s/step - loss: 0.0753 - binary_io_u: 0.8802 - val_loss: 0.0717 - val_binary_io_u: 0.8898
# Epoch 48/50
# 46/46 [==============================] - 174s 4s/step - loss: 0.0768 - binary_io_u: 0.8787 - val_loss: 0.0719 - val_binary_io_u: 0.8879
# Epoch 49/50
# 46/46 [==============================] - 137s 3s/step - loss: 0.0784 - binary_io_u: 0.8782 - val_loss: 0.0732 - val_binary_io_u: 0.8866
# Epoch 50/50
# 46/46 [==============================] - 126s 3s/step - loss: 0.0789 - binary_io_u: 0.8761 - val_loss: 0.0750 - val_binary_io_u: 0.8758

# %%
val_acc_per_epoch = history.history['val_binary_io_u']
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Best epoch: 46

# %%
# use the best number of epochs
hypermodel = tuner.hypermodel.build(best_hps)

# FROM = 2023/03/30
# # REMEMBER TO CHANGE THE NAME OF THE MODEL!!
checkpointer = ModelCheckpoint('model-UNetEp=VARModel_20230330.h5', verbose=1, save_best_only=True)
# Retrain the model--> USE THE NEW_TRAIN
result = hypermodel.fit(newtrain_VAR, Y_train, epochs=best_epoch, validation_split=0.2, callbacks=[checkpointer])
# Out:
# Epoch 1/46
# 46/46 [==============================] - ETA: 0s - loss: 0.2422 - binary_io_u_1: 0.6488
# Epoch 1: val_loss improved from inf to 0.73378, saving model to model-UNetEp=VARModel_20230330.h5
# 46/46 [==============================] - 61s 1s/step - loss: 0.2422 - binary_io_u_1: 0.6488 - val_loss: 0.7338 - val_binary_io_u_1: 0.6450
# Epoch 2/46
# 46/46 [==============================] - ETA: 0s - loss: 0.1483 - binary_io_u_1: 0.7862
# Epoch 2: val_loss improved from 0.73378 to 0.12978, saving model to model-UNetEp=VARModel_20230330.h5
# 46/46 [==============================] - 60s 1s/step - loss: 0.1483 - binary_io_u_1: 0.7862 - val_loss: 0.1298 - val_binary_io_u_1: 0.7938
# Epoch 3/46
# 46/46 [==============================] - ETA: 0s - loss: 0.1299 - binary_io_u_1: 0.8104
# Epoch 3: val_loss improved from 0.12978 to 0.11961, saving model to model-UNetEp=VARModel_20230330.h5
# 46/46 [==============================] - 60s 1s/step - loss: 0.1299 - binary_io_u_1: 0.8104 - val_loss: 0.1196 - val_binary_io_u_1: 0.8365
# Epoch 4/46
# 46/46 [==============================] - ETA: 0s - loss: 0.1172 - binary_io_u_1: 0.8287
# Epoch 4: val_loss improved from 0.11961 to 0.10844, saving model to model-UNetEp=VARModel_20230330.h5
# 46/46 [==============================] - 61s 1s/step - loss: 0.1172 - binary_io_u_1: 0.8287 - val_loss: 0.1084 - val_binary_io_u_1: 0.8325
# Epoch 5/46
# 46/46 [==============================] - ETA: 0s - loss: 0.1104 - binary_io_u_1: 0.8371
# Epoch 5: val_loss improved from 0.10844 to 0.09978, saving model to model-UNetEp=VARModel_20230330.h5
# 46/46 [==============================] - 60s 1s/step - loss: 0.1104 - binary_io_u_1: 0.8371 - val_loss: 0.0998 - val_binary_io_u_1: 0.8509
# Epoch 6/46
# 46/46 [==============================] - ETA: 0s - loss: 0.1056 - binary_io_u_1: 0.8425
# Epoch 6: val_loss did not improve from 0.09978
# 46/46 [==============================] - 59s 1s/step - loss: 0.1056 - binary_io_u_1: 0.8425 - val_loss: 0.1169 - val_binary_io_u_1: 0.8410
# Epoch 7/46
# 46/46 [==============================] - ETA: 0s - loss: 0.1004 - binary_io_u_1: 0.8494
# Epoch 7: val_loss did not improve from 0.09978
# 46/46 [==============================] - 59s 1s/step - loss: 0.1004 - binary_io_u_1: 0.8494 - val_loss: 0.1008 - val_binary_io_u_1: 0.8492
# Epoch 8/46
# 46/46 [==============================] - ETA: 0s - loss: 0.1015 - binary_io_u_1: 0.8480
# Epoch 8: val_loss did not improve from 0.09978
# 46/46 [==============================] - 59s 1s/step - loss: 0.1015 - binary_io_u_1: 0.8480 - val_loss: 0.2788 - val_binary_io_u_1: 0.7797
# Epoch 9/46
# 46/46 [==============================] - ETA: 0s - loss: 0.1036 - binary_io_u_1: 0.8441
# Epoch 9: val_loss improved from 0.09978 to 0.09100, saving model to model-UNetEp=VARModel_20230330.h5
# 46/46 [==============================] - 59s 1s/step - loss: 0.1036 - binary_io_u_1: 0.8441 - val_loss: 0.0910 - val_binary_io_u_1: 0.8529
# Epoch 10/46
# 46/46 [==============================] - ETA: 0s - loss: 0.0996 - binary_io_u_1: 0.8493
# Epoch 10: val_loss improved from 0.09100 to 0.09052, saving model to model-UNetEp=VARModel_20230330.h5
# 46/46 [==============================] - 60s 1s/step - loss: 0.0996 - binary_io_u_1: 0.8493 - val_loss: 0.0905 - val_binary_io_u_1: 0.8640
# Epoch 11/46
# 46/46 [==============================] - ETA: 0s - loss: 0.0976 - binary_io_u_1: 0.8523
# Epoch 11: val_loss improved from 0.09052 to 0.08879, saving model to model-UNetEp=VARModel_20230330.h5
# 46/46 [==============================] - 59s 1s/step - loss: 0.0976 - binary_io_u_1: 0.8523 - val_loss: 0.0888 - val_binary_io_u_1: 0.8629
# Epoch 12/46
# 46/46 [==============================] - ETA: 0s - loss: 0.0949 - binary_io_u_1: 0.8561
# Epoch 12: val_loss improved from 0.08879 to 0.08878, saving model to model-UNetEp=VARModel_20230330.h5
# 46/46 [==============================] - 60s 1s/step - loss: 0.0949 - binary_io_u_1: 0.8561 - val_loss: 0.0888 - val_binary_io_u_1: 0.8591
# Epoch 13/46
# 46/46 [==============================] - ETA: 0s - loss: 0.0905 - binary_io_u_1: 0.8612
# Epoch 13: val_loss improved from 0.08878 to 0.08613, saving model to model-UNetEp=VARModel_20230330.h5
# 46/46 [==============================] - 59s 1s/step - loss: 0.0905 - binary_io_u_1: 0.8612 - val_loss: 0.0861 - val_binary_io_u_1: 0.8748
# Epoch 14/46
# 46/46 [==============================] - ETA: 0s - loss: 0.0916 - binary_io_u_1: 0.8599
# Epoch 14: val_loss improved from 0.08613 to 0.08393, saving model to model-UNetEp=VARModel_20230330.h5
# 46/46 [==============================] - 60s 1s/step - loss: 0.0916 - binary_io_u_1: 0.8599 - val_loss: 0.0839 - val_binary_io_u_1: 0.8654
# Epoch 15/46
# 46/46 [==============================] - ETA: 0s - loss: 0.0915 - binary_io_u_1: 0.8609
# Epoch 15: val_loss improved from 0.08393 to 0.08246, saving model to model-UNetEp=VARModel_20230330.h5
# 46/46 [==============================] - 60s 1s/step - loss: 0.0915 - binary_io_u_1: 0.8609 - val_loss: 0.0825 - val_binary_io_u_1: 0.8648
# Epoch 16/46
# 46/46 [==============================] - ETA: 0s - loss: 0.0913 - binary_io_u_1: 0.8596
# Epoch 16: val_loss improved from 0.08246 to 0.08063, saving model to model-UNetEp=VARModel_20230330.h5
# 46/46 [==============================] - 59s 1s/step - loss: 0.0913 - binary_io_u_1: 0.8596 - val_loss: 0.0806 - val_binary_io_u_1: 0.8727
# Epoch 17/46
# 46/46 [==============================] - ETA: 0s - loss: 0.0871 - binary_io_u_1: 0.8654
# Epoch 17: val_loss improved from 0.08063 to 0.07964, saving model to model-UNetEp=VARModel_20230330.h5
# 46/46 [==============================] - 59s 1s/step - loss: 0.0871 - binary_io_u_1: 0.8654 - val_loss: 0.0796 - val_binary_io_u_1: 0.8755
# Epoch 18/46
# 46/46 [==============================] - ETA: 0s - loss: 0.0874 - binary_io_u_1: 0.8648
# Epoch 18: val_loss did not improve from 0.07964
# 46/46 [==============================] - 59s 1s/step - loss: 0.0874 - binary_io_u_1: 0.8648 - val_loss: 0.0825 - val_binary_io_u_1: 0.8772
# Epoch 19/46
# 46/46 [==============================] - ETA: 0s - loss: 0.0876 - binary_io_u_1: 0.8640
# Epoch 19: val_loss did not improve from 0.07964
# 46/46 [==============================] - 59s 1s/step - loss: 0.0876 - binary_io_u_1: 0.8640 - val_loss: 0.0806 - val_binary_io_u_1: 0.8686
# Epoch 20/46
# 46/46 [==============================] - ETA: 0s - loss: 0.0848 - binary_io_u_1: 0.8683
# Epoch 20: val_loss improved from 0.07964 to 0.07878, saving model to model-UNetEp=VARModel_20230330.h5
# 46/46 [==============================] - 60s 1s/step - loss: 0.0848 - binary_io_u_1: 0.8683 - val_loss: 0.0788 - val_binary_io_u_1: 0.8727
# Epoch 21/46
# 46/46 [==============================] - ETA: 0s - loss: 0.0841 - binary_io_u_1: 0.8689
# Epoch 21: val_loss did not improve from 0.07878
# 46/46 [==============================] - 59s 1s/step - loss: 0.0841 - binary_io_u_1: 0.8689 - val_loss: 0.0791 - val_binary_io_u_1: 0.8759
# Epoch 22/46
# 46/46 [==============================] - ETA: 0s - loss: 0.0848 - binary_io_u_1: 0.8677
# Epoch 22: val_loss did not improve from 0.07878
# 46/46 [==============================] - 59s 1s/step - loss: 0.0848 - binary_io_u_1: 0.8677 - val_loss: 0.0837 - val_binary_io_u_1: 0.8597
# Epoch 23/46
# 46/46 [==============================] - ETA: 0s - loss: 0.1083 - binary_io_u_1: 0.8417
# Epoch 23: val_loss did not improve from 0.07878
# 46/46 [==============================] - 59s 1s/step - loss: 0.1083 - binary_io_u_1: 0.8417 - val_loss: 0.0854 - val_binary_io_u_1: 0.8711
# Epoch 24/46
# 46/46 [==============================] - ETA: 0s - loss: 0.0936 - binary_io_u_1: 0.8601
# Epoch 24: val_loss did not improve from 0.07878
# 46/46 [==============================] - 59s 1s/step - loss: 0.0936 - binary_io_u_1: 0.8601 - val_loss: 0.0823 - val_binary_io_u_1: 0.8742
# Epoch 25/46
# 46/46 [==============================] - ETA: 0s - loss: 0.0880 - binary_io_u_1: 0.8657
# Epoch 25: val_loss did not improve from 0.07878
# 46/46 [==============================] - 691s 15s/step - loss: 0.0880 - binary_io_u_1: 0.8657 - val_loss: 0.0791 - val_binary_io_u_1: 0.8765
# Epoch 26/46
# 46/46 [==============================] - ETA: 0s - loss: 0.0897 - binary_io_u_1: 0.8635
# Epoch 26: val_loss did not improve from 0.07878
# 46/46 [==============================] - 69s 1s/step - loss: 0.0897 - binary_io_u_1: 0.8635 - val_loss: 0.0841 - val_binary_io_u_1: 0.8669
# Epoch 27/46
# 46/46 [==============================] - ETA: 0s - loss: 0.0858 - binary_io_u_1: 0.8677
# Epoch 27: val_loss did not improve from 0.07878
# 46/46 [==============================] - 1007s 22s/step - loss: 0.0858 - binary_io_u_1: 0.8677 - val_loss: 0.0854 - val_binary_io_u_1: 0.8720
# Epoch 28/46
# 46/46 [==============================] - ETA: 0s - loss: 0.0856 - binary_io_u_1: 0.8687
# Epoch 28: val_loss improved from 0.07878 to 0.07784, saving model to model-UNetEp=VARModel_20230330.h5
# 46/46 [==============================] - 58s 1s/step - loss: 0.0856 - binary_io_u_1: 0.8687 - val_loss: 0.0778 - val_binary_io_u_1: 0.8762
# Epoch 29/46
# 46/46 [==============================] - ETA: 0s - loss: 0.0828 - binary_io_u_1: 0.8710
# Epoch 29: val_loss did not improve from 0.07784
# 46/46 [==============================] - 64s 1s/step - loss: 0.0828 - binary_io_u_1: 0.8710 - val_loss: 0.0781 - val_binary_io_u_1: 0.8833
# Epoch 30/46
# 46/46 [==============================] - ETA: 0s - loss: 0.0824 - binary_io_u_1: 0.8725
# Epoch 30: val_loss did not improve from 0.07784
# 46/46 [==============================] - 72s 2s/step - loss: 0.0824 - binary_io_u_1: 0.8725 - val_loss: 0.0788 - val_binary_io_u_1: 0.8744
# Epoch 31/46
# 46/46 [==============================] - ETA: 0s - loss: 0.0816 - binary_io_u_1: 0.8717
# Epoch 31: val_loss did not improve from 0.07784
# 46/46 [==============================] - 78s 2s/step - loss: 0.0816 - binary_io_u_1: 0.8717 - val_loss: 0.0801 - val_binary_io_u_1: 0.8790
# Epoch 32/46
# 46/46 [==============================] - ETA: 0s - loss: 0.0818 - binary_io_u_1: 0.8735
# Epoch 32: val_loss improved from 0.07784 to 0.07624, saving model to model-UNetEp=VARModel_20230330.h5
# 46/46 [==============================] - 82s 2s/step - loss: 0.0818 - binary_io_u_1: 0.8735 - val_loss: 0.0762 - val_binary_io_u_1: 0.8721
# Epoch 33/46
# 46/46 [==============================] - ETA: 0s - loss: 0.0806 - binary_io_u_1: 0.8732
# Epoch 33: val_loss improved from 0.07624 to 0.07585, saving model to model-UNetEp=VARModel_20230330.h5
# 46/46 [==============================] - 87s 2s/step - loss: 0.0806 - binary_io_u_1: 0.8732 - val_loss: 0.0758 - val_binary_io_u_1: 0.8837
# Epoch 34/46
# 46/46 [==============================] - ETA: 0s - loss: 0.0811 - binary_io_u_1: 0.8752
# Epoch 34: val_loss did not improve from 0.07585
# 46/46 [==============================] - 88s 2s/step - loss: 0.0811 - binary_io_u_1: 0.8752 - val_loss: 0.0815 - val_binary_io_u_1: 0.8745
# Epoch 35/46
# 46/46 [==============================] - ETA: 0s - loss: 0.0796 - binary_io_u_1: 0.8744
# Epoch 35: val_loss improved from 0.07585 to 0.07541, saving model to model-UNetEp=VARModel_20230330.h5
# 46/46 [==============================] - 88s 2s/step - loss: 0.0796 - binary_io_u_1: 0.8744 - val_loss: 0.0754 - val_binary_io_u_1: 0.8806
# Epoch 36/46
# 46/46 [==============================] - ETA: 0s - loss: 0.0794 - binary_io_u_1: 0.8754
# Epoch 36: val_loss improved from 0.07541 to 0.07451, saving model to model-UNetEp=VARModel_20230330.h5
# 46/46 [==============================] - 89s 2s/step - loss: 0.0794 - binary_io_u_1: 0.8754 - val_loss: 0.0745 - val_binary_io_u_1: 0.8849
# Epoch 37/46
# 46/46 [==============================] - ETA: 0s - loss: 0.0807 - binary_io_u_1: 0.8745
# Epoch 37: val_loss did not improve from 0.07451
# 46/46 [==============================] - 89s 2s/step - loss: 0.0807 - binary_io_u_1: 0.8745 - val_loss: 0.0781 - val_binary_io_u_1: 0.8756
# Epoch 38/46
# 46/46 [==============================] - ETA: 0s - loss: 0.0792 - binary_io_u_1: 0.8748
# Epoch 38: val_loss did not improve from 0.07451
# 46/46 [==============================] - 90s 2s/step - loss: 0.0792 - binary_io_u_1: 0.8748 - val_loss: 0.0745 - val_binary_io_u_1: 0.8860
# Epoch 39/46
# 46/46 [==============================] - ETA: 0s - loss: 0.0787 - binary_io_u_1: 0.8770
# Epoch 39: val_loss did not improve from 0.07451
# 46/46 [==============================] - 94s 2s/step - loss: 0.0787 - binary_io_u_1: 0.8770 - val_loss: 0.0745 - val_binary_io_u_1: 0.8849
# Epoch 40/46
# 46/46 [==============================] - ETA: 0s - loss: 0.0785 - binary_io_u_1: 0.8756
# Epoch 40: val_loss did not improve from 0.07451
# 46/46 [==============================] - 98s 2s/step - loss: 0.0785 - binary_io_u_1: 0.8756 - val_loss: 0.0791 - val_binary_io_u_1: 0.8841
# Epoch 41/46
# 46/46 [==============================] - ETA: 0s - loss: 0.0777 - binary_io_u_1: 0.8776
# Epoch 41: val_loss did not improve from 0.07451
# 46/46 [==============================] - 105s 2s/step - loss: 0.0777 - binary_io_u_1: 0.8776 - val_loss: 0.0750 - val_binary_io_u_1: 0.8811
# Epoch 42/46
# 46/46 [==============================] - ETA: 0s - loss: 0.0775 - binary_io_u_1: 0.8778
# Epoch 42: val_loss improved from 0.07451 to 0.07303, saving model to model-UNetEp=VARModel_20230330.h5
# 46/46 [==============================] - 103s 2s/step - loss: 0.0775 - binary_io_u_1: 0.8778 - val_loss: 0.0730 - val_binary_io_u_1: 0.8868
# Epoch 43/46
# 46/46 [==============================] - ETA: 0s - loss: 0.0802 - binary_io_u_1: 0.8743
# Epoch 43: val_loss did not improve from 0.07303
# 46/46 [==============================] - 102s 2s/step - loss: 0.0802 - binary_io_u_1: 0.8743 - val_loss: 0.0743 - val_binary_io_u_1: 0.8852
# Epoch 44/46
# 46/46 [==============================] - ETA: 0s - loss: 0.0775 - binary_io_u_1: 0.8778
# Epoch 44: val_loss did not improve from 0.07303
# 46/46 [==============================] - 102s 2s/step - loss: 0.0775 - binary_io_u_1: 0.8778 - val_loss: 0.0798 - val_binary_io_u_1: 0.8750
# Epoch 45/46
# 46/46 [==============================] - ETA: 0s - loss: 0.0806 - binary_io_u_1: 0.8733
# Epoch 45: val_loss did not improve from 0.07303
# 46/46 [==============================] - 105s 2s/step - loss: 0.0806 - binary_io_u_1: 0.8733 - val_loss: 0.0867 - val_binary_io_u_1: 0.8776
# Epoch 46/46
# 46/46 [==============================] - ETA: 0s - loss: 0.0770 - binary_io_u_1: 0.8785
# Epoch 46: val_loss did not improve from 0.07303
# 46/46 [==============================] - 108s 2s/step - loss: 0.0770 - binary_io_u_1: 0.8785 - val_loss: 0.0771 - val_binary_io_u_1: 0.8857

# %%
# ALTER THE NAMING CONVENTIONS..
def plot_training(hist):
    '''
    This function take training model and plot history of accuracy and losses with the best epoch in both of them.
    '''

    # Define needed variables--> these two need to be diff
    tr_acc = hist.history['binary_io_u_1']
    tr_loss = hist.history['loss']
    val_acc = hist.history['val_binary_io_u_1']
    val_loss = hist.history['val_loss']
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]
    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'

    # Plot training history
    plt.figure(figsize= (20, 8))
    plt.style.use('fivethirtyeight')

    plt.subplot(1, 2, 1)
    plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
    plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
    plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training and Validation Binary IOU')
    plt.xlabel('Epochs')
    plt.ylabel('Binary IOU')
    plt.legend()

    # change the title!!
    plt.suptitle("Unet trained with VAR Epsilon", fontsize=30)
    plt.tight_layout
    plt.savefig('model-UNetEp=VARModel_20230330.png')
    plt.show()

# %%
# results.history
plot_training(result)

# %%
# we could stop here...
