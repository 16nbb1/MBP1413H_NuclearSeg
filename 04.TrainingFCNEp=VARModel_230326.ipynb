# %%
import os
import sys
import glob
import random
import warnings
import shutil
from distutils.dir_util import copy_tree


import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
# from keras.layers.merge import concatenate
from keras.layers import concatenate

from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

import tensorflow as tf
from tensorflow.keras.metrics import Metric

import skimage.io

# %%
# Set some parameters
IMG_WIDTH = 128
IMG_HEIGHT = 128
# IMG_CHANNELS = 3
IMG_CHANNELS = 1

# %%
# the small set for experimentation!
TRAIN_PATH = './FORmodels/trainset_raw/'

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
seed = 42
random.seed = seed
np.random.seed = seed

# Get train and test IDs
train_ids = next(os.walk(TRAIN_PATH))[1]
len(train_ids)
# Out:
# 1809

# %%
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH), dtype=np.bool)
Y_train.shape
# Out:
# /var/folders/qr/np1v1r_53zqc4t2j9qztcrxh0000gn/T/ipykernel_83462/187304916.py:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH), dtype=np.bool)
# (1809, 128, 128)

# %%
# Get and resize train images and masks
X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH), dtype=np.uint8)
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
print('Getting and resizing train images and masks ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    pather = TRAIN_PATH + id_    
    img = imread(pather + '/images/' + id_ + '.png')
    X_train[n] = img
    
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
        
    pattern = pather+'/masks/*'
    for fname in glob.glob(pattern, recursive=True):

        mask_ = imread(fname)     
        mask_ = resize(mask_,(IMG_HEIGHT, IMG_WIDTH, 1))
#         mask_ = np.expand_dims(mask_, axis=1)        
        mask = np.maximum(mask, mask_)
        
    Y_train[n] = mask
# Out:
# Getting and resizing train images and masks ...
# /var/folders/qr/np1v1r_53zqc4t2j9qztcrxh0000gn/T/ipykernel_83462/431872359.py:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
#   0%|                                                  | 0/1809 [00:00<?, ?it/s]/var/folders/qr/np1v1r_53zqc4t2j9qztcrxh0000gn/T/ipykernel_83462/431872359.py:11: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
# 100%|███████████████████████████████████████| 1809/1809 [02:44<00:00, 11.00it/s]

# %%
# Check if training data looks all right
# DOUBLE CHECK MASKS!!
ix = random.randint(0, len(train_ids))

print(ix, train_ids[ix])
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()
# Out:
# 466 dabfee30b46d23569c63fa7253ef10b2407fbe8023035a5030252313cb718097

# %%
# allowing for hyperparam tuning
import keras_tuner as kt
hp = kt.HyperParameters()

# %%
def model_builder(hp):

    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))

    output_1 = Dense(64, activation='relu')(inputs)
    output_2 = Dense(64, activation='relu')(output_1)
    outputs = Dense(1, activation='sigmoid')(output_2)

    model = Model(inputs=[inputs], outputs=[outputs])

    # here we're using the hyperparam for learning rate!
    model.compile(tf.keras.optimizers.Adam(hp.Float('learning_rate', 1e-4, 1e-2, sampling='log'), amsgrad= True), loss='binary_crossentropy', metrics=tf.keras.metrics.BinaryIoU(target_class_ids=[0, 1], threshold=0.3))

#     model.summary()
    
    return model

# %%
tuner = kt.RandomSearch(
    model_builder,
    objective = kt.Objective("mean_io_u", direction="max"),
    max_trials=5)
# Out:
# INFO:tensorflow:Reloading Tuner from ./untitled_project/tuner0.json

# %%
# TURNING OFF STOP EARLY
tuner.search(X_train, Y_train, epochs=5, validation_split=0.2)

best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"""
The hyperparameter search is complete. The optimal number of units in the first densely-connected
layer is ... and the optimal learning rate for the optimizer
is {best_hps.get('learning_rate')}.
""")
# Out:
# INFO:tensorflow:Oracle triggered exit
#
# The hyperparameter search is complete. The optimal number of units in the first densely-connected
# layer is ... and the optimal learning rate for the optimizer
# is 0.0017991073735913667.

# %%
model = tuner.hypermodel.build(best_hps)
# Out:
# 2023-03-30 20:34:24.783424: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
## ADDING ADVERSARIAL ATTACK...
loss_object = tf.keras.losses.BinaryCrossentropy()

def create_adversarial_pattern(input_image, input_label):
    input_image = tf.convert_to_tensor(np.reshape(input_image, (-1, 128, 128, 1)), dtype=tf.float32)
    input_label = np.reshape(input_label, (-1, 128, 128, 1))

#     Record operations for automatic differentiation??
    with tf.GradientTape() as tape:

        tape.watch(input_image)
        prediction = model(input_image)
        
        loss = loss_object(input_label, prediction)

#   # Get the gradients of the loss w.r.t to the input image.
    gradient = tape.gradient(loss, input_image)

    # Get the sign of the gradients to create the perturbation
    signed_grad = tf.sign(gradient)
    
    return signed_grad

# %%
# Get the input label of the image. -->  THIS NEEDS TO BE A LOOP THROUGH THE IMAGES!!
# WE CAN RANDOMIZE HOW MANY GET A PERTURBATION!!

pert = []

for i in range(len(X_train)):
    pert.append(create_adversarial_pattern(X_train[i],Y_train[i]))

# %%
# trying to randomize --> let's say we take random values between 0 and 50
# making a function for adding peterubation!!!!!
def addingep():
    newtrain = []
    randos = []

    for i in range(len(X_train)): 
        pert[i] = tf.reshape(pert[i], [1, 128, 128])
        lol = random.randint(0, 50)
        randos.append(lol)
        
        new = X_train[i] +  lol* pert[i] * 0.5 + 0.5
        newtrain.append(np.squeeze(new.numpy()))

    newtrain = np.asarray(newtrain)
    newtrain = np.squeeze(newtrain)
    
    plt.hist(randos)
    plt.title('Random epsilon values')
    plt.xlabel('Epsilon value')
    plt.ylabel('Frequency')
    plt.savefig('RandEpVals_FCN_histo.png')

    return newtrain

# %%
# Generates a new X_train
newtrain_VAR = addingep()

# %%
X_train.shape
# Out:
# (1809, 128, 128)

# %%
# Let's visualize what we've done here...
# Perform a sanity check on some random training samples
ix = random.randint(0, len(newtrain_VAR))
print(ix)
imshow(X_train[ix])
plt.title('Raw Image')
plt.show()
imshow(newtrain_VAR[ix].astype('uint8'))
plt.title('Epsilon=0 Image')
plt.show()
imshow(np.squeeze(pert[ix]))
plt.title('Ep=2 Perturbation')
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.title('Mask')
plt.show()
# Out:
# 979

# %%
# increasing epoch val to 50!!
# tf.config.run_functions_eagerly(True)
history = model.fit(newtrain_VAR, Y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 46/46 [==============================] - 7s 137ms/step - loss: 0.7198 - binary_io_u: 0.2787 - val_loss: 0.4487 - val_binary_io_u: 0.2786
# Epoch 2/50
# 46/46 [==============================] - 6s 135ms/step - loss: 0.3919 - binary_io_u: 0.3781 - val_loss: 0.3810 - val_binary_io_u: 0.3656
# Epoch 3/50
# 46/46 [==============================] - 6s 131ms/step - loss: 0.3394 - binary_io_u: 0.5250 - val_loss: 0.3071 - val_binary_io_u: 0.4239
# Epoch 4/50
# 46/46 [==============================] - 6s 136ms/step - loss: 0.3062 - binary_io_u: 0.5955 - val_loss: 0.2501 - val_binary_io_u: 0.6622
# Epoch 5/50
# 46/46 [==============================] - 6s 135ms/step - loss: 0.2665 - binary_io_u: 0.6100 - val_loss: 0.3035 - val_binary_io_u: 0.6663
# Epoch 6/50
# 46/46 [==============================] - 6s 137ms/step - loss: 0.2580 - binary_io_u: 0.6399 - val_loss: 0.2575 - val_binary_io_u: 0.6670
# Epoch 7/50
# 46/46 [==============================] - 6s 133ms/step - loss: 0.2519 - binary_io_u: 0.6406 - val_loss: 0.2103 - val_binary_io_u: 0.7874
# Epoch 8/50
# 46/46 [==============================] - 6s 138ms/step - loss: 0.2200 - binary_io_u: 0.6821 - val_loss: 0.2271 - val_binary_io_u: 0.6800
# Epoch 9/50
# 46/46 [==============================] - 6s 133ms/step - loss: 0.2115 - binary_io_u: 0.7008 - val_loss: 0.2100 - val_binary_io_u: 0.7316
# Epoch 10/50
# 46/46 [==============================] - 6s 135ms/step - loss: 0.2083 - binary_io_u: 0.7059 - val_loss: 0.1774 - val_binary_io_u: 0.8264
# Epoch 11/50
# 46/46 [==============================] - 6s 138ms/step - loss: 0.1939 - binary_io_u: 0.7238 - val_loss: 0.1664 - val_binary_io_u: 0.6939
# Epoch 12/50
# 46/46 [==============================] - 6s 134ms/step - loss: 0.2248 - binary_io_u: 0.6795 - val_loss: 0.2130 - val_binary_io_u: 0.7246
# Epoch 13/50
# 46/46 [==============================] - 6s 131ms/step - loss: 0.2094 - binary_io_u: 0.6882 - val_loss: 0.1645 - val_binary_io_u: 0.8212
# Epoch 14/50
# 46/46 [==============================] - 6s 132ms/step - loss: 0.1708 - binary_io_u: 0.7533 - val_loss: 0.1580 - val_binary_io_u: 0.8221
# Epoch 15/50
# 46/46 [==============================] - 6s 130ms/step - loss: 0.1658 - binary_io_u: 0.7571 - val_loss: 0.1656 - val_binary_io_u: 0.8071
# Epoch 16/50
# 46/46 [==============================] - 6s 138ms/step - loss: 0.1701 - binary_io_u: 0.7583 - val_loss: 0.1510 - val_binary_io_u: 0.6855
# Epoch 17/50
# 46/46 [==============================] - 6s 131ms/step - loss: 0.1618 - binary_io_u: 0.7637 - val_loss: 0.1483 - val_binary_io_u: 0.8212
# Epoch 18/50
# 46/46 [==============================] - 6s 129ms/step - loss: 0.2197 - binary_io_u: 0.7188 - val_loss: 0.2450 - val_binary_io_u: 0.6604
# Epoch 19/50
# 46/46 [==============================] - 6s 130ms/step - loss: 0.1756 - binary_io_u: 0.7344 - val_loss: 0.1387 - val_binary_io_u: 0.8313
# Epoch 20/50
# 46/46 [==============================] - 6s 134ms/step - loss: 0.1493 - binary_io_u: 0.8103 - val_loss: 0.1380 - val_binary_io_u: 0.8277
# Epoch 21/50
# 46/46 [==============================] - 6s 135ms/step - loss: 0.1516 - binary_io_u: 0.7934 - val_loss: 0.1485 - val_binary_io_u: 0.8170
# Epoch 22/50
# 46/46 [==============================] - 6s 130ms/step - loss: 0.1523 - binary_io_u: 0.7795 - val_loss: 0.1552 - val_binary_io_u: 0.8037
# Epoch 23/50
# 46/46 [==============================] - 6s 135ms/step - loss: 0.1564 - binary_io_u: 0.7644 - val_loss: 0.1589 - val_binary_io_u: 0.6662
# Epoch 24/50
# 46/46 [==============================] - 6s 137ms/step - loss: 0.1579 - binary_io_u: 0.7698 - val_loss: 0.1333 - val_binary_io_u: 0.8191
# Epoch 25/50
# 46/46 [==============================] - 6s 134ms/step - loss: 0.1550 - binary_io_u: 0.7775 - val_loss: 0.1440 - val_binary_io_u: 0.8002
# Epoch 26/50
# 46/46 [==============================] - 6s 138ms/step - loss: 0.1504 - binary_io_u: 0.7925 - val_loss: 0.1307 - val_binary_io_u: 0.8339
# Epoch 27/50
# 46/46 [==============================] - 6s 133ms/step - loss: 0.1531 - binary_io_u: 0.7805 - val_loss: 0.1602 - val_binary_io_u: 0.7981
# Epoch 28/50
# 46/46 [==============================] - 6s 135ms/step - loss: 0.1628 - binary_io_u: 0.7609 - val_loss: 0.1458 - val_binary_io_u: 0.8185
# Epoch 29/50
# 46/46 [==============================] - 7s 154ms/step - loss: 0.1707 - binary_io_u: 0.7538 - val_loss: 0.1334 - val_binary_io_u: 0.8214
# Epoch 30/50
# 46/46 [==============================] - 7s 145ms/step - loss: 0.1424 - binary_io_u: 0.8141 - val_loss: 0.1531 - val_binary_io_u: 0.6837
# Epoch 31/50
# 46/46 [==============================] - 7s 144ms/step - loss: 0.1549 - binary_io_u: 0.7724 - val_loss: 0.1291 - val_binary_io_u: 0.8245
# Epoch 32/50
# 46/46 [==============================] - 7s 145ms/step - loss: 0.1432 - binary_io_u: 0.8079 - val_loss: 0.1456 - val_binary_io_u: 0.8157
# Epoch 33/50
# 46/46 [==============================] - 6s 133ms/step - loss: 0.1468 - binary_io_u: 0.8020 - val_loss: 0.1362 - val_binary_io_u: 0.7694
# Epoch 34/50
# 46/46 [==============================] - 6s 132ms/step - loss: 0.1549 - binary_io_u: 0.7729 - val_loss: 0.1278 - val_binary_io_u: 0.8351
# Epoch 35/50
# 46/46 [==============================] - 6s 138ms/step - loss: 0.1411 - binary_io_u: 0.8117 - val_loss: 0.1448 - val_binary_io_u: 0.8130
# Epoch 36/50
# 46/46 [==============================] - 6s 133ms/step - loss: 0.1534 - binary_io_u: 0.7824 - val_loss: 0.1451 - val_binary_io_u: 0.7127
# Epoch 37/50
# 46/46 [==============================] - 6s 139ms/step - loss: 0.1463 - binary_io_u: 0.7948 - val_loss: 0.1270 - val_binary_io_u: 0.8351
# Epoch 38/50
# 46/46 [==============================] - 6s 130ms/step - loss: 0.1415 - binary_io_u: 0.8120 - val_loss: 0.1302 - val_binary_io_u: 0.8319
# Epoch 39/50
# 46/46 [==============================] - 6s 137ms/step - loss: 0.1417 - binary_io_u: 0.8134 - val_loss: 0.1337 - val_binary_io_u: 0.7899
# Epoch 40/50
# 46/46 [==============================] - 6s 139ms/step - loss: 0.1423 - binary_io_u: 0.8109 - val_loss: 0.1294 - val_binary_io_u: 0.8180
# Epoch 41/50
# 46/46 [==============================] - 6s 141ms/step - loss: 0.1410 - binary_io_u: 0.8077 - val_loss: 0.1365 - val_binary_io_u: 0.8293
# Epoch 42/50
# 46/46 [==============================] - 6s 134ms/step - loss: 0.1468 - binary_io_u: 0.7986 - val_loss: 0.1341 - val_binary_io_u: 0.8278
# Epoch 43/50
# 46/46 [==============================] - 6s 134ms/step - loss: 0.1474 - binary_io_u: 0.7977 - val_loss: 0.1303 - val_binary_io_u: 0.8091
# Epoch 44/50
# 46/46 [==============================] - 6s 131ms/step - loss: 0.1420 - binary_io_u: 0.8085 - val_loss: 0.1385 - val_binary_io_u: 0.7624
# Epoch 45/50
# 46/46 [==============================] - 6s 129ms/step - loss: 0.1460 - binary_io_u: 0.8024 - val_loss: 0.1267 - val_binary_io_u: 0.8296
# Epoch 46/50
# 46/46 [==============================] - 6s 134ms/step - loss: 0.1451 - binary_io_u: 0.8034 - val_loss: 0.1262 - val_binary_io_u: 0.8342
# Epoch 47/50
# 46/46 [==============================] - 6s 141ms/step - loss: 0.1437 - binary_io_u: 0.8069 - val_loss: 0.1340 - val_binary_io_u: 0.7892
# Epoch 48/50
# 46/46 [==============================] - 6s 136ms/step - loss: 0.1467 - binary_io_u: 0.8016 - val_loss: 0.1298 - val_binary_io_u: 0.8308
# Epoch 49/50
# 46/46 [==============================] - 6s 134ms/step - loss: 0.1399 - binary_io_u: 0.8138 - val_loss: 0.1295 - val_binary_io_u: 0.8284
# Epoch 50/50
# 46/46 [==============================] - 6s 130ms/step - loss: 0.1456 - binary_io_u: 0.8006 - val_loss: 0.1313 - val_binary_io_u: 0.8334

# %%
val_acc_per_epoch = history.history['val_binary_io_u']
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Best epoch: 34

# %%
# use the best number of epochs
hypermodel = tuner.hypermodel.build(best_hps)

# FROM = 2023/03/30
# # REMEMBER TO CHANGE THE NAME OF THE MODEL!!
checkpointer = ModelCheckpoint('model-FCNEp=VARModel_20230330.h5', verbose=1, save_best_only=True)
# Retrain the model--> USE THE NEW_TRAIN
result = hypermodel.fit(newtrain_VAR, Y_train, epochs=best_epoch, validation_split=0.2, callbacks=[checkpointer])
# Out:
# Epoch 1/34
# 45/46 [============================>.] - ETA: 0s - loss: 0.6034 - binary_io_u_1: 0.3016
# Epoch 1: val_loss improved from inf to 0.39644, saving model to model-FCNEp=VARModel_20230330.h5
# 46/46 [==============================] - 7s 138ms/step - loss: 0.6017 - binary_io_u_1: 0.3022 - val_loss: 0.3964 - val_binary_io_u_1: 0.3630
# Epoch 2/34
# 45/46 [============================>.] - ETA: 0s - loss: 0.4008 - binary_io_u_1: 0.4065
# Epoch 2: val_loss improved from 0.39644 to 0.31481, saving model to model-FCNEp=VARModel_20230330.h5
# 46/46 [==============================] - 6s 139ms/step - loss: 0.4002 - binary_io_u_1: 0.4074 - val_loss: 0.3148 - val_binary_io_u_1: 0.5842
# Epoch 3/34
# 45/46 [============================>.] - ETA: 0s - loss: 0.2996 - binary_io_u_1: 0.5838
# Epoch 3: val_loss improved from 0.31481 to 0.26581, saving model to model-FCNEp=VARModel_20230330.h5
# 46/46 [==============================] - 7s 151ms/step - loss: 0.2993 - binary_io_u_1: 0.5836 - val_loss: 0.2658 - val_binary_io_u_1: 0.5241
# Epoch 4/34
# 45/46 [============================>.] - ETA: 0s - loss: 0.2739 - binary_io_u_1: 0.5940
# Epoch 4: val_loss did not improve from 0.26581
# 46/46 [==============================] - 7s 142ms/step - loss: 0.2738 - binary_io_u_1: 0.5946 - val_loss: 0.2907 - val_binary_io_u_1: 0.6669
# Epoch 5/34
# 45/46 [============================>.] - ETA: 0s - loss: 0.2868 - binary_io_u_1: 0.6118
# Epoch 5: val_loss improved from 0.26581 to 0.21818, saving model to model-FCNEp=VARModel_20230330.h5
# 46/46 [==============================] - 6s 141ms/step - loss: 0.2863 - binary_io_u_1: 0.6123 - val_loss: 0.2182 - val_binary_io_u_1: 0.8348
# Epoch 6/34
# 45/46 [============================>.] - ETA: 0s - loss: 0.2387 - binary_io_u_1: 0.6626
# Epoch 6: val_loss did not improve from 0.21818
# 46/46 [==============================] - 7s 143ms/step - loss: 0.2388 - binary_io_u_1: 0.6630 - val_loss: 0.3080 - val_binary_io_u_1: 0.6659
# Epoch 7/34
# 45/46 [============================>.] - ETA: 0s - loss: 0.3128 - binary_io_u_1: 0.5966
# Epoch 7: val_loss did not improve from 0.21818
# 46/46 [==============================] - 7s 143ms/step - loss: 0.3128 - binary_io_u_1: 0.5963 - val_loss: 0.4445 - val_binary_io_u_1: 0.4324
# Epoch 8/34
# 45/46 [============================>.] - ETA: 0s - loss: 0.2428 - binary_io_u_1: 0.6536
# Epoch 8: val_loss improved from 0.21818 to 0.21264, saving model to model-FCNEp=VARModel_20230330.h5
# 46/46 [==============================] - 6s 137ms/step - loss: 0.2426 - binary_io_u_1: 0.6523 - val_loss: 0.2126 - val_binary_io_u_1: 0.7371
# Epoch 9/34
# 45/46 [============================>.] - ETA: 0s - loss: 0.2135 - binary_io_u_1: 0.7044
# Epoch 9: val_loss improved from 0.21264 to 0.20460, saving model to model-FCNEp=VARModel_20230330.h5
# 46/46 [==============================] - 6s 140ms/step - loss: 0.2136 - binary_io_u_1: 0.7043 - val_loss: 0.2046 - val_binary_io_u_1: 0.7562
# Epoch 10/34
# 45/46 [============================>.] - ETA: 0s - loss: 0.2106 - binary_io_u_1: 0.6957
# Epoch 10: val_loss improved from 0.20460 to 0.18709, saving model to model-FCNEp=VARModel_20230330.h5
# 46/46 [==============================] - 6s 141ms/step - loss: 0.2105 - binary_io_u_1: 0.6960 - val_loss: 0.1871 - val_binary_io_u_1: 0.8182
# Epoch 11/34
# 45/46 [============================>.] - ETA: 0s - loss: 0.1921 - binary_io_u_1: 0.7395
# Epoch 11: val_loss improved from 0.18709 to 0.17619, saving model to model-FCNEp=VARModel_20230330.h5
# 46/46 [==============================] - 7s 145ms/step - loss: 0.1918 - binary_io_u_1: 0.7398 - val_loss: 0.1762 - val_binary_io_u_1: 0.6674
# Epoch 12/34
# 45/46 [============================>.] - ETA: 0s - loss: 0.2003 - binary_io_u_1: 0.7083
# Epoch 12: val_loss did not improve from 0.17619
# 46/46 [==============================] - 6s 135ms/step - loss: 0.2011 - binary_io_u_1: 0.7062 - val_loss: 0.1830 - val_binary_io_u_1: 0.8022
# Epoch 13/34
# 45/46 [============================>.] - ETA: 0s - loss: 0.1888 - binary_io_u_1: 0.7241
# Epoch 13: val_loss did not improve from 0.17619
# 46/46 [==============================] - 6s 141ms/step - loss: 0.1889 - binary_io_u_1: 0.7246 - val_loss: 0.1822 - val_binary_io_u_1: 0.7941
# Epoch 14/34
# 45/46 [============================>.] - ETA: 0s - loss: 0.1863 - binary_io_u_1: 0.7291
# Epoch 14: val_loss improved from 0.17619 to 0.17114, saving model to model-FCNEp=VARModel_20230330.h5
# 46/46 [==============================] - 6s 136ms/step - loss: 0.1860 - binary_io_u_1: 0.7290 - val_loss: 0.1711 - val_binary_io_u_1: 0.8174
# Epoch 15/34
# 45/46 [============================>.] - ETA: 0s - loss: 0.1787 - binary_io_u_1: 0.7410
# Epoch 15: val_loss did not improve from 0.17114
# 46/46 [==============================] - 7s 143ms/step - loss: 0.1782 - binary_io_u_1: 0.7417 - val_loss: 0.1741 - val_binary_io_u_1: 0.6667
# Epoch 16/34
# 45/46 [============================>.] - ETA: 0s - loss: 0.2008 - binary_io_u_1: 0.7001
# Epoch 16: val_loss did not improve from 0.17114
# 46/46 [==============================] - 7s 142ms/step - loss: 0.2007 - binary_io_u_1: 0.6991 - val_loss: 0.1719 - val_binary_io_u_1: 0.8056
# Epoch 17/34
# 45/46 [============================>.] - ETA: 0s - loss: 0.1796 - binary_io_u_1: 0.7354
# Epoch 17: val_loss improved from 0.17114 to 0.15423, saving model to model-FCNEp=VARModel_20230330.h5
# 46/46 [==============================] - 6s 132ms/step - loss: 0.1797 - binary_io_u_1: 0.7354 - val_loss: 0.1542 - val_binary_io_u_1: 0.8014
# Epoch 18/34
# 45/46 [============================>.] - ETA: 0s - loss: 0.1727 - binary_io_u_1: 0.7495
# Epoch 18: val_loss improved from 0.15423 to 0.15388, saving model to model-FCNEp=VARModel_20230330.h5
# 46/46 [==============================] - 6s 137ms/step - loss: 0.1726 - binary_io_u_1: 0.7498 - val_loss: 0.1539 - val_binary_io_u_1: 0.8314
# Epoch 19/34
# 45/46 [============================>.] - ETA: 0s - loss: 0.1748 - binary_io_u_1: 0.7382
# Epoch 19: val_loss did not improve from 0.15388
# 46/46 [==============================] - 6s 135ms/step - loss: 0.1756 - binary_io_u_1: 0.7356 - val_loss: 0.1689 - val_binary_io_u_1: 0.7938
# Epoch 20/34
# 45/46 [============================>.] - ETA: 0s - loss: 0.1735 - binary_io_u_1: 0.7431
# Epoch 20: val_loss improved from 0.15388 to 0.15133, saving model to model-FCNEp=VARModel_20230330.h5
# 46/46 [==============================] - 7s 143ms/step - loss: 0.1733 - binary_io_u_1: 0.7434 - val_loss: 0.1513 - val_binary_io_u_1: 0.8253
# Epoch 21/34
# 45/46 [============================>.] - ETA: 0s - loss: 0.1661 - binary_io_u_1: 0.7686
# Epoch 21: val_loss improved from 0.15133 to 0.14401, saving model to model-FCNEp=VARModel_20230330.h5
# 46/46 [==============================] - 6s 140ms/step - loss: 0.1661 - binary_io_u_1: 0.7684 - val_loss: 0.1440 - val_binary_io_u_1: 0.8314
# Epoch 22/34
# 45/46 [============================>.] - ETA: 0s - loss: 0.1586 - binary_io_u_1: 0.7868
# Epoch 22: val_loss did not improve from 0.14401
# 46/46 [==============================] - 6s 139ms/step - loss: 0.1586 - binary_io_u_1: 0.7872 - val_loss: 0.1470 - val_binary_io_u_1: 0.8340
# Epoch 23/34
# 45/46 [============================>.] - ETA: 0s - loss: 0.1576 - binary_io_u_1: 0.7849
# Epoch 23: val_loss improved from 0.14401 to 0.14234, saving model to model-FCNEp=VARModel_20230330.h5
# 46/46 [==============================] - 6s 132ms/step - loss: 0.1575 - binary_io_u_1: 0.7856 - val_loss: 0.1423 - val_binary_io_u_1: 0.8224
# Epoch 24/34
# 45/46 [============================>.] - ETA: 0s - loss: 0.1572 - binary_io_u_1: 0.7760
# Epoch 24: val_loss improved from 0.14234 to 0.13961, saving model to model-FCNEp=VARModel_20230330.h5
# 46/46 [==============================] - 6s 130ms/step - loss: 0.1570 - binary_io_u_1: 0.7764 - val_loss: 0.1396 - val_binary_io_u_1: 0.8112
# Epoch 25/34
# 45/46 [============================>.] - ETA: 0s - loss: 0.1623 - binary_io_u_1: 0.7498
# Epoch 25: val_loss did not improve from 0.13961
# 46/46 [==============================] - 6s 131ms/step - loss: 0.1622 - binary_io_u_1: 0.7502 - val_loss: 0.1489 - val_binary_io_u_1: 0.8175
# Epoch 26/34
# 45/46 [============================>.] - ETA: 0s - loss: 0.1525 - binary_io_u_1: 0.7891
# Epoch 26: val_loss improved from 0.13961 to 0.13913, saving model to model-FCNEp=VARModel_20230330.h5
# 46/46 [==============================] - 6s 132ms/step - loss: 0.1523 - binary_io_u_1: 0.7895 - val_loss: 0.1391 - val_binary_io_u_1: 0.8295
# Epoch 27/34
# 45/46 [============================>.] - ETA: 0s - loss: 0.1484 - binary_io_u_1: 0.8023
# Epoch 27: val_loss did not improve from 0.13913
# 46/46 [==============================] - 6s 132ms/step - loss: 0.1483 - binary_io_u_1: 0.8024 - val_loss: 0.1508 - val_binary_io_u_1: 0.8089
# Epoch 28/34
# 45/46 [============================>.] - ETA: 0s - loss: 0.1499 - binary_io_u_1: 0.7894
# Epoch 28: val_loss did not improve from 0.13913
# 46/46 [==============================] - 7s 143ms/step - loss: 0.1497 - binary_io_u_1: 0.7896 - val_loss: 0.1518 - val_binary_io_u_1: 0.8172
# Epoch 29/34
# 45/46 [============================>.] - ETA: 0s - loss: 0.1501 - binary_io_u_1: 0.7935
# Epoch 29: val_loss improved from 0.13913 to 0.13318, saving model to model-FCNEp=VARModel_20230330.h5
# 46/46 [==============================] - 6s 141ms/step - loss: 0.1504 - binary_io_u_1: 0.7931 - val_loss: 0.1332 - val_binary_io_u_1: 0.8293
# Epoch 30/34
# 45/46 [============================>.] - ETA: 0s - loss: 0.1523 - binary_io_u_1: 0.7807
# Epoch 30: val_loss did not improve from 0.13318
# 46/46 [==============================] - 6s 135ms/step - loss: 0.1522 - binary_io_u_1: 0.7811 - val_loss: 0.1668 - val_binary_io_u_1: 0.7904
# Epoch 31/34
# 45/46 [============================>.] - ETA: 0s - loss: 0.1629 - binary_io_u_1: 0.7568
# Epoch 31: val_loss improved from 0.13318 to 0.13092, saving model to model-FCNEp=VARModel_20230330.h5
# 46/46 [==============================] - 6s 140ms/step - loss: 0.1627 - binary_io_u_1: 0.7572 - val_loss: 0.1309 - val_binary_io_u_1: 0.8260
# Epoch 32/34
# 45/46 [============================>.] - ETA: 0s - loss: 0.1436 - binary_io_u_1: 0.8103
# Epoch 32: val_loss did not improve from 0.13092
# 46/46 [==============================] - 7s 142ms/step - loss: 0.1436 - binary_io_u_1: 0.8107 - val_loss: 0.1499 - val_binary_io_u_1: 0.6863
# Epoch 33/34
# 45/46 [============================>.] - ETA: 0s - loss: 0.1551 - binary_io_u_1: 0.7664
# Epoch 33: val_loss did not improve from 0.13092
# 46/46 [==============================] - 7s 145ms/step - loss: 0.1550 - binary_io_u_1: 0.7667 - val_loss: 0.1321 - val_binary_io_u_1: 0.8131
# Epoch 34/34
# 45/46 [============================>.] - ETA: 0s - loss: 0.1604 - binary_io_u_1: 0.7654
# Epoch 34: val_loss improved from 0.13092 to 0.13053, saving model to model-FCNEp=VARModel_20230330.h5
# 46/46 [==============================] - 6s 137ms/step - loss: 0.1600 - binary_io_u_1: 0.7658 - val_loss: 0.1305 - val_binary_io_u_1: 0.8343

# %%
# ALTER THE NAMING CONVENTIONS..
def plot_training(hist):
    '''
    This function take training model and plot history of accuracy and losses with the best epoch in both of them.
    '''

    # Define needed variables--> these two need to be diff
    tr_acc = hist.history['binary_io_u_1']
    tr_loss = hist.history['loss']
    val_acc = hist.history['val_binary_io_u_1']
    val_loss = hist.history['val_loss']
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]
    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'

    # Plot training history
    plt.figure(figsize= (20, 8))
    plt.style.use('fivethirtyeight')

    plt.subplot(1, 2, 1)
    plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
    plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
    plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training and Validation Binary IOU')
    plt.xlabel('Epochs')
    plt.ylabel('Binary IOU')
    plt.legend()

    # change the title!!
    plt.suptitle("FCN trained with VAR Epsilon", fontsize=30)
    plt.tight_layout
    plt.savefig('model-FCNEp=VARModel_20230330.png')
    plt.show()

# %%
# results.history
plot_training(result)

# %%
# we could stop here...
