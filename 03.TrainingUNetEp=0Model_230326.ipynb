# %%
import os
import sys
import glob
import random
import warnings
import shutil
from distutils.dir_util import copy_tree


import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

from keras.models import Model, load_model
from keras.layers import Input
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
# from keras.layers.merge import concatenate
from keras.layers import concatenate

from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

import tensorflow as tf
from tensorflow.keras.metrics import Metric

import skimage.io

# %%
# Set some parameters
IMG_WIDTH = 128
IMG_HEIGHT = 128
# IMG_CHANNELS = 3
IMG_CHANNELS = 1

# %%
# the small set for experimentation!
TRAIN_PATH = './FORmodels/trainset_raw/'

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
seed = 42
random.seed = seed
np.random.seed = seed

# Get train and test IDs
train_ids = next(os.walk(TRAIN_PATH))[1]
len(train_ids)
# Out:
# 1809

# %%
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH), dtype=np.bool)
Y_train.shape
# Out:
# /var/folders/qr/np1v1r_53zqc4t2j9qztcrxh0000gn/T/ipykernel_85504/187304916.py:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH), dtype=np.bool)
# (1809, 128, 128)

# %%
# Get and resize train images and masks
X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH), dtype=np.uint8)
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
print('Getting and resizing train images and masks ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    pather = TRAIN_PATH + id_    
    img = imread(pather + '/images/' + id_ + '.png')
    X_train[n] = img
    
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
        
    pattern = pather+'/masks/*'
    for fname in glob.glob(pattern, recursive=True):

        mask_ = imread(fname)     
        mask_ = resize(mask_,(IMG_HEIGHT, IMG_WIDTH, 1))
#         mask_ = np.expand_dims(mask_, axis=1)        
        mask = np.maximum(mask, mask_)
        
    Y_train[n] = mask
# Out:
# Getting and resizing train images and masks ...
# /var/folders/qr/np1v1r_53zqc4t2j9qztcrxh0000gn/T/ipykernel_85504/431872359.py:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
#   0%|                                                  | 0/1809 [00:00<?, ?it/s]/var/folders/qr/np1v1r_53zqc4t2j9qztcrxh0000gn/T/ipykernel_85504/431872359.py:11: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
# 100%|███████████████████████████████████████| 1809/1809 [02:44<00:00, 11.01it/s]

# %%
# Check if training data looks all right
# DOUBLE CHECK MASKS!!
ix = random.randint(0, len(train_ids))

print(ix, train_ids[ix])
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()
# Out:
# 39 2dec81a678ddcac2b110acffe82427d857695180bd841e3f9736a554acf832af_mirror

# %%
# allowing for hyperparam tuning
import keras_tuner as kt
hp = kt.HyperParameters()

# %%
def model_builder(hp):

    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    s = Lambda(lambda x: x / 255) (inputs)

    c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (s)
    c1 = Dropout(0.1) (c1)
    c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c1)
    p1 = MaxPooling2D((2, 2)) (c1)

    c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p1)
    c2 = Dropout(0.1) (c2)
    c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c2)
    p2 = MaxPooling2D((2, 2)) (c2)

    c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p2)
    c3 = Dropout(0.2) (c3)
    c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c3)
    p3 = MaxPooling2D((2, 2)) (c3)

    c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p3)
    c4 = Dropout(0.2) (c4)
    c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c4)
    p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

    c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p4)
    c5 = Dropout(0.3) (c5)
    c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c5)

    u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c5)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u6)
    c6 = Dropout(0.2) (c6)
    c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c6)

    u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u7)
    c7 = Dropout(0.2) (c7)
    c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c7)

    u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u8)
    c8 = Dropout(0.1) (c8)
    c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c8)

    u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u9)
    c9 = Dropout(0.1) (c9)
    c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c9)

    outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)

    model = Model(inputs=[inputs], outputs=[outputs])

    # here we're using the hyperparam for learning rate!
    model.compile(tf.keras.optimizers.Adam(hp.Float('learning_rate', 1e-4, 1e-2, sampling='log'), amsgrad= True), loss='binary_crossentropy', metrics=tf.keras.metrics.BinaryIoU(target_class_ids=[0, 1], threshold=0.3))

#     model.summary()
    
    return model

# %%
tuner = kt.RandomSearch(
    model_builder,
    objective = kt.Objective("mean_io_u", direction="max"),
    max_trials=5)
# Out:
# INFO:tensorflow:Reloading Tuner from ./untitled_project/tuner0.json

# %%
# TURNING OFF STOP EARLY
tuner.search(X_train, Y_train, epochs=5, validation_split=0.2)

best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"""
The hyperparameter search is complete. The optimal number of units in the first densely-connected
layer is ... and the optimal learning rate for the optimizer
is {best_hps.get('learning_rate')}.
""")
# Out:
# INFO:tensorflow:Oracle triggered exit
#
# The hyperparameter search is complete. The optimal number of units in the first densely-connected
# layer is ... and the optimal learning rate for the optimizer
# is 0.0008259900546842376.

# %%
model = tuner.hypermodel.build(best_hps)
# Out:
# 2023-03-30 21:44:59.528819: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
## ADDING ADVERSARIAL ATTACK...
loss_object = tf.keras.losses.BinaryCrossentropy()

def create_adversarial_pattern(input_image, input_label):
    input_image = tf.convert_to_tensor(np.reshape(input_image, (-1, 128, 128, 1)), dtype=tf.float32)
    input_label = np.reshape(input_label, (-1, 128, 128, 1))

#     Record operations for automatic differentiation??
    with tf.GradientTape() as tape:

        tape.watch(input_image)
        prediction = model(input_image)
        
        loss = loss_object(input_label, prediction)

#   # Get the gradients of the loss w.r.t to the input image.
    gradient = tape.gradient(loss, input_image)

    # Get the sign of the gradients to create the perturbation
    signed_grad = tf.sign(gradient)
    
    return signed_grad

# %%
pert = []

for i in range(len(X_train)):
    pert.append(create_adversarial_pattern(X_train[i],Y_train[i]))

# %%
# making a function for adding peterubation!!!!!
def addingep (ep):
    newtrain = []

    for i in range(len(X_train)): 
        pert[i] = tf.reshape(pert[i], [1, 128, 128])
        new = X_train[i] + ep* pert[i] * 0.5 + 0.5
        newtrain.append(np.squeeze(new.numpy()))

    newtrain = np.asarray(newtrain)
    newtrain = np.squeeze(newtrain)
    
    return newtrain

# %%
# Generates a new X_train
newtrain_0 = addingep(0)

# %%
X_train.shape
# Out:
# (1809, 128, 128)

# %%
newtrain_0.shape
# Out:
# (1809, 128, 128)

# %%
# Let's visualize what we've done here...
# Perform a sanity check on some random training samples
ix = random.randint(0, len(newtrain_0))
print(ix)
imshow(X_train[ix])
plt.title('Raw Image')
plt.show()
imshow(newtrain_0[ix].astype('uint8'))
plt.title('Epsilon=0 Image')
plt.show()
imshow(np.squeeze(pert[ix]))
plt.title('Ep=2 Perturbation')
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.title('Mask')
plt.show()
# Out:
# 987

# %%
# increasing epoch val to 50!!
history = model.fit(newtrain_0, Y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 46/46 [==============================] - 69s 1s/step - loss: 0.2982 - binary_io_u: 0.5587 - val_loss: 0.1555 - val_binary_io_u: 0.7875
# Epoch 2/50
# 46/46 [==============================] - 65s 1s/step - loss: 0.1490 - binary_io_u: 0.7910 - val_loss: 0.1214 - val_binary_io_u: 0.8235
# Epoch 3/50
# 46/46 [==============================] - 66s 1s/step - loss: 0.1225 - binary_io_u: 0.8265 - val_loss: 0.1045 - val_binary_io_u: 0.8492
# Epoch 4/50
# 46/46 [==============================] - 63s 1s/step - loss: 0.1148 - binary_io_u: 0.8353 - val_loss: 0.0987 - val_binary_io_u: 0.8517
# Epoch 5/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.1108 - binary_io_u: 0.8405 - val_loss: 0.1121 - val_binary_io_u: 0.8493
# Epoch 6/50
# 46/46 [==============================] - 60s 1s/step - loss: 0.1064 - binary_io_u: 0.8439 - val_loss: 0.0911 - val_binary_io_u: 0.8595
# Epoch 7/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.1013 - binary_io_u: 0.8494 - val_loss: 0.0882 - val_binary_io_u: 0.8574
# Epoch 8/50
# 46/46 [==============================] - 63s 1s/step - loss: 0.0974 - binary_io_u: 0.8529 - val_loss: 0.0950 - val_binary_io_u: 0.8706
# Epoch 9/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.0964 - binary_io_u: 0.8553 - val_loss: 0.0878 - val_binary_io_u: 0.8676
# Epoch 10/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0923 - binary_io_u: 0.8610 - val_loss: 0.0990 - val_binary_io_u: 0.8336
# Epoch 11/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.0950 - binary_io_u: 0.8569 - val_loss: 0.0855 - val_binary_io_u: 0.8710
# Epoch 12/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0908 - binary_io_u: 0.8623 - val_loss: 0.0812 - val_binary_io_u: 0.8679
# Epoch 13/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0889 - binary_io_u: 0.8635 - val_loss: 0.0833 - val_binary_io_u: 0.8745
# Epoch 14/50
# 46/46 [==============================] - 63s 1s/step - loss: 0.0878 - binary_io_u: 0.8662 - val_loss: 0.0863 - val_binary_io_u: 0.8563
# Epoch 15/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.0880 - binary_io_u: 0.8656 - val_loss: 0.0816 - val_binary_io_u: 0.8732
# Epoch 16/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.0868 - binary_io_u: 0.8657 - val_loss: 0.0848 - val_binary_io_u: 0.8566
# Epoch 17/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.0846 - binary_io_u: 0.8686 - val_loss: 0.0785 - val_binary_io_u: 0.8799
# Epoch 18/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.0847 - binary_io_u: 0.8686 - val_loss: 0.0838 - val_binary_io_u: 0.8726
# Epoch 19/50
# 46/46 [==============================] - 65s 1s/step - loss: 0.0847 - binary_io_u: 0.8692 - val_loss: 0.0833 - val_binary_io_u: 0.8813
# Epoch 20/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0850 - binary_io_u: 0.8703 - val_loss: 0.0816 - val_binary_io_u: 0.8718
# Epoch 21/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0840 - binary_io_u: 0.8689 - val_loss: 0.0811 - val_binary_io_u: 0.8695
# Epoch 22/50
# 46/46 [==============================] - 63s 1s/step - loss: 0.0824 - binary_io_u: 0.8716 - val_loss: 0.0788 - val_binary_io_u: 0.8766
# Epoch 23/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0823 - binary_io_u: 0.8713 - val_loss: 0.0812 - val_binary_io_u: 0.8736
# Epoch 24/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.0837 - binary_io_u: 0.8713 - val_loss: 0.0804 - val_binary_io_u: 0.8648
# Epoch 25/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0811 - binary_io_u: 0.8724 - val_loss: 0.0768 - val_binary_io_u: 0.8781
# Epoch 26/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.0814 - binary_io_u: 0.8724 - val_loss: 0.1453 - val_binary_io_u: 0.7986
# Epoch 27/50
# 46/46 [==============================] - 60s 1s/step - loss: 0.0958 - binary_io_u: 0.8562 - val_loss: 0.0825 - val_binary_io_u: 0.8717
# Epoch 28/50
# 46/46 [==============================] - 60s 1s/step - loss: 0.0868 - binary_io_u: 0.8656 - val_loss: 0.0854 - val_binary_io_u: 0.8709
# Epoch 29/50
# 46/46 [==============================] - 60s 1s/step - loss: 0.0827 - binary_io_u: 0.8712 - val_loss: 0.0852 - val_binary_io_u: 0.8570
# Epoch 30/50
# 46/46 [==============================] - 60s 1s/step - loss: 0.0838 - binary_io_u: 0.8688 - val_loss: 0.0807 - val_binary_io_u: 0.8716
# Epoch 31/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.0827 - binary_io_u: 0.8713 - val_loss: 0.0765 - val_binary_io_u: 0.8807
# Epoch 32/50
# 46/46 [==============================] - 63s 1s/step - loss: 0.0796 - binary_io_u: 0.8740 - val_loss: 0.0756 - val_binary_io_u: 0.8790
# Epoch 33/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0798 - binary_io_u: 0.8744 - val_loss: 0.0778 - val_binary_io_u: 0.8753
# Epoch 34/50
# 46/46 [==============================] - 63s 1s/step - loss: 0.0803 - binary_io_u: 0.8735 - val_loss: 0.0761 - val_binary_io_u: 0.8781
# Epoch 35/50
# 46/46 [==============================] - 64s 1s/step - loss: 0.0790 - binary_io_u: 0.8756 - val_loss: 0.0743 - val_binary_io_u: 0.8889
# Epoch 36/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0788 - binary_io_u: 0.8746 - val_loss: 0.0759 - val_binary_io_u: 0.8826
# Epoch 37/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.0777 - binary_io_u: 0.8758 - val_loss: 0.0748 - val_binary_io_u: 0.8826
# Epoch 38/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0778 - binary_io_u: 0.8755 - val_loss: 0.0786 - val_binary_io_u: 0.8810
# Epoch 39/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0776 - binary_io_u: 0.8757 - val_loss: 0.0775 - val_binary_io_u: 0.8881
# Epoch 40/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0770 - binary_io_u: 0.8771 - val_loss: 0.0753 - val_binary_io_u: 0.8822
# Epoch 41/50
# 46/46 [==============================] - 63s 1s/step - loss: 0.0771 - binary_io_u: 0.8764 - val_loss: 0.0728 - val_binary_io_u: 0.8781
# Epoch 42/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.0805 - binary_io_u: 0.8728 - val_loss: 0.0740 - val_binary_io_u: 0.8830
# Epoch 43/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.0765 - binary_io_u: 0.8773 - val_loss: 0.0754 - val_binary_io_u: 0.8794
# Epoch 44/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.0750 - binary_io_u: 0.8796 - val_loss: 0.0729 - val_binary_io_u: 0.8777
# Epoch 45/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.0763 - binary_io_u: 0.8771 - val_loss: 0.0761 - val_binary_io_u: 0.8785
# Epoch 46/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.0752 - binary_io_u: 0.8804 - val_loss: 0.0722 - val_binary_io_u: 0.8860
# Epoch 47/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.0742 - binary_io_u: 0.8797 - val_loss: 0.0718 - val_binary_io_u: 0.8847
# Epoch 48/50
# 46/46 [==============================] - 62s 1s/step - loss: 0.0745 - binary_io_u: 0.8797 - val_loss: 0.0706 - val_binary_io_u: 0.8869
# Epoch 49/50
# 46/46 [==============================] - 63s 1s/step - loss: 0.0741 - binary_io_u: 0.8794 - val_loss: 0.0780 - val_binary_io_u: 0.8719
# Epoch 50/50
# 46/46 [==============================] - 61s 1s/step - loss: 0.0743 - binary_io_u: 0.8792 - val_loss: 0.0705 - val_binary_io_u: 0.8878

# %%
val_acc_per_epoch = history.history['val_binary_io_u']
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Best epoch: 35

# %%
# use the best number of epochs
hypermodel = tuner.hypermodel.build(best_hps)

# FROM = 2023/03/30
# # REMEMBER TO CHANGE THE NAME OF THE MODEL!!
checkpointer = ModelCheckpoint('model-UNetEp=0Model_20230330.h5', verbose=1, save_best_only=True)
# Retrain the model--> USE THE NEW_TRAIN
result = hypermodel.fit(newtrain_0, Y_train, epochs=best_epoch, validation_split=0.2, callbacks=[checkpointer])
# Out:
# Epoch 1/35
# 46/46 [==============================] - ETA: 0s - loss: 0.2833 - binary_io_u_1: 0.5991
# Epoch 1: val_loss improved from inf to 0.16475, saving model to model-UNetEp=0Model_20230330.h5
# 46/46 [==============================] - 63s 1s/step - loss: 0.2833 - binary_io_u_1: 0.5991 - val_loss: 0.1647 - val_binary_io_u_1: 0.7599
# Epoch 2/35
# 46/46 [==============================] - ETA: 0s - loss: 0.1643 - binary_io_u_1: 0.7621
# Epoch 2: val_loss improved from 0.16475 to 0.13162, saving model to model-UNetEp=0Model_20230330.h5
# 46/46 [==============================] - 63s 1s/step - loss: 0.1643 - binary_io_u_1: 0.7621 - val_loss: 0.1316 - val_binary_io_u_1: 0.7969
# Epoch 3/35
# 46/46 [==============================] - ETA: 0s - loss: 0.1427 - binary_io_u_1: 0.7928
# Epoch 3: val_loss improved from 0.13162 to 0.11691, saving model to model-UNetEp=0Model_20230330.h5
# 46/46 [==============================] - 61s 1s/step - loss: 0.1427 - binary_io_u_1: 0.7928 - val_loss: 0.1169 - val_binary_io_u_1: 0.8420
# Epoch 4/35
# 46/46 [==============================] - ETA: 0s - loss: 0.1206 - binary_io_u_1: 0.8247
# Epoch 4: val_loss improved from 0.11691 to 0.10534, saving model to model-UNetEp=0Model_20230330.h5
# 46/46 [==============================] - 61s 1s/step - loss: 0.1206 - binary_io_u_1: 0.8247 - val_loss: 0.1053 - val_binary_io_u_1: 0.8518
# Epoch 5/35
# 46/46 [==============================] - ETA: 0s - loss: 0.1126 - binary_io_u_1: 0.8355
# Epoch 5: val_loss improved from 0.10534 to 0.10027, saving model to model-UNetEp=0Model_20230330.h5
# 46/46 [==============================] - 64s 1s/step - loss: 0.1126 - binary_io_u_1: 0.8355 - val_loss: 0.1003 - val_binary_io_u_1: 0.8610
# Epoch 6/35
# 46/46 [==============================] - ETA: 0s - loss: 0.1121 - binary_io_u_1: 0.8356
# Epoch 6: val_loss improved from 0.10027 to 0.09790, saving model to model-UNetEp=0Model_20230330.h5
# 46/46 [==============================] - 63s 1s/step - loss: 0.1121 - binary_io_u_1: 0.8356 - val_loss: 0.0979 - val_binary_io_u_1: 0.8553
# Epoch 7/35
# 46/46 [==============================] - ETA: 0s - loss: 0.1080 - binary_io_u_1: 0.8404
# Epoch 7: val_loss improved from 0.09790 to 0.09549, saving model to model-UNetEp=0Model_20230330.h5
# 46/46 [==============================] - 63s 1s/step - loss: 0.1080 - binary_io_u_1: 0.8404 - val_loss: 0.0955 - val_binary_io_u_1: 0.8683
# Epoch 8/35
# 46/46 [==============================] - ETA: 0s - loss: 0.0984 - binary_io_u_1: 0.8518
# Epoch 8: val_loss improved from 0.09549 to 0.08611, saving model to model-UNetEp=0Model_20230330.h5
# 46/46 [==============================] - 63s 1s/step - loss: 0.0984 - binary_io_u_1: 0.8518 - val_loss: 0.0861 - val_binary_io_u_1: 0.8599
# Epoch 9/35
# 46/46 [==============================] - ETA: 0s - loss: 0.1012 - binary_io_u_1: 0.8467
# Epoch 9: val_loss did not improve from 0.08611
# 46/46 [==============================] - 64s 1s/step - loss: 0.1012 - binary_io_u_1: 0.8467 - val_loss: 0.0905 - val_binary_io_u_1: 0.8648
# Epoch 10/35
# 46/46 [==============================] - ETA: 0s - loss: 0.0964 - binary_io_u_1: 0.8536
# Epoch 10: val_loss did not improve from 0.08611
# 46/46 [==============================] - 63s 1s/step - loss: 0.0964 - binary_io_u_1: 0.8536 - val_loss: 0.0907 - val_binary_io_u_1: 0.8527
# Epoch 11/35
# 46/46 [==============================] - ETA: 0s - loss: 0.0937 - binary_io_u_1: 0.8540
# Epoch 11: val_loss improved from 0.08611 to 0.08546, saving model to model-UNetEp=0Model_20230330.h5
# 46/46 [==============================] - 62s 1s/step - loss: 0.0937 - binary_io_u_1: 0.8540 - val_loss: 0.0855 - val_binary_io_u_1: 0.8721
# Epoch 12/35
# 46/46 [==============================] - ETA: 0s - loss: 0.0950 - binary_io_u_1: 0.8558
# Epoch 12: val_loss did not improve from 0.08546
# 46/46 [==============================] - 62s 1s/step - loss: 0.0950 - binary_io_u_1: 0.8558 - val_loss: 0.0902 - val_binary_io_u_1: 0.8523
# Epoch 13/35
# 46/46 [==============================] - ETA: 0s - loss: 0.0919 - binary_io_u_1: 0.8584
# Epoch 13: val_loss improved from 0.08546 to 0.08538, saving model to model-UNetEp=0Model_20230330.h5
# 46/46 [==============================] - 62s 1s/step - loss: 0.0919 - binary_io_u_1: 0.8584 - val_loss: 0.0854 - val_binary_io_u_1: 0.8643
# Epoch 14/35
# 46/46 [==============================] - ETA: 0s - loss: 0.0909 - binary_io_u_1: 0.8590
# Epoch 14: val_loss improved from 0.08538 to 0.08228, saving model to model-UNetEp=0Model_20230330.h5
# 46/46 [==============================] - 61s 1s/step - loss: 0.0909 - binary_io_u_1: 0.8590 - val_loss: 0.0823 - val_binary_io_u_1: 0.8633
# Epoch 15/35
# 46/46 [==============================] - ETA: 0s - loss: 0.0902 - binary_io_u_1: 0.8598
# Epoch 15: val_loss did not improve from 0.08228
# 46/46 [==============================] - 62s 1s/step - loss: 0.0902 - binary_io_u_1: 0.8598 - val_loss: 0.0833 - val_binary_io_u_1: 0.8614
# Epoch 16/35
# 46/46 [==============================] - ETA: 0s - loss: 0.0878 - binary_io_u_1: 0.8631
# Epoch 16: val_loss did not improve from 0.08228
# 46/46 [==============================] - 63s 1s/step - loss: 0.0878 - binary_io_u_1: 0.8631 - val_loss: 0.0834 - val_binary_io_u_1: 0.8677
# Epoch 17/35
# 46/46 [==============================] - ETA: 0s - loss: 0.0873 - binary_io_u_1: 0.8654
# Epoch 17: val_loss did not improve from 0.08228
# 46/46 [==============================] - 61s 1s/step - loss: 0.0873 - binary_io_u_1: 0.8654 - val_loss: 0.0873 - val_binary_io_u_1: 0.8424
# Epoch 18/35
# 46/46 [==============================] - ETA: 0s - loss: 0.0880 - binary_io_u_1: 0.8623
# Epoch 18: val_loss did not improve from 0.08228
# 46/46 [==============================] - 63s 1s/step - loss: 0.0880 - binary_io_u_1: 0.8623 - val_loss: 0.0846 - val_binary_io_u_1: 0.8734
# Epoch 19/35
# 46/46 [==============================] - ETA: 0s - loss: 0.0864 - binary_io_u_1: 0.8659
# Epoch 19: val_loss improved from 0.08228 to 0.08112, saving model to model-UNetEp=0Model_20230330.h5
# 46/46 [==============================] - 61s 1s/step - loss: 0.0864 - binary_io_u_1: 0.8659 - val_loss: 0.0811 - val_binary_io_u_1: 0.8735
# Epoch 20/35
# 46/46 [==============================] - ETA: 0s - loss: 0.0921 - binary_io_u_1: 0.8590
# Epoch 20: val_loss did not improve from 0.08112
# 46/46 [==============================] - 63s 1s/step - loss: 0.0921 - binary_io_u_1: 0.8590 - val_loss: 0.0851 - val_binary_io_u_1: 0.8677
# Epoch 21/35
# 46/46 [==============================] - ETA: 0s - loss: 0.0896 - binary_io_u_1: 0.8628
# Epoch 21: val_loss did not improve from 0.08112
# 46/46 [==============================] - 64s 1s/step - loss: 0.0896 - binary_io_u_1: 0.8628 - val_loss: 0.0832 - val_binary_io_u_1: 0.8640
# Epoch 22/35
# 46/46 [==============================] - ETA: 0s - loss: 0.0869 - binary_io_u_1: 0.8652
# Epoch 22: val_loss improved from 0.08112 to 0.07863, saving model to model-UNetEp=0Model_20230330.h5
# 46/46 [==============================] - 62s 1s/step - loss: 0.0869 - binary_io_u_1: 0.8652 - val_loss: 0.0786 - val_binary_io_u_1: 0.8728
# Epoch 23/35
# 46/46 [==============================] - ETA: 0s - loss: 0.0851 - binary_io_u_1: 0.8666
# Epoch 23: val_loss improved from 0.07863 to 0.07785, saving model to model-UNetEp=0Model_20230330.h5
# 46/46 [==============================] - 62s 1s/step - loss: 0.0851 - binary_io_u_1: 0.8666 - val_loss: 0.0778 - val_binary_io_u_1: 0.8726
# Epoch 24/35
# 46/46 [==============================] - ETA: 0s - loss: 0.0844 - binary_io_u_1: 0.8673
# Epoch 24: val_loss did not improve from 0.07785
# 46/46 [==============================] - 63s 1s/step - loss: 0.0844 - binary_io_u_1: 0.8673 - val_loss: 0.0840 - val_binary_io_u_1: 0.8642
# Epoch 25/35
# 46/46 [==============================] - ETA: 0s - loss: 0.0842 - binary_io_u_1: 0.8679
# Epoch 25: val_loss did not improve from 0.07785
# 46/46 [==============================] - 65s 1s/step - loss: 0.0842 - binary_io_u_1: 0.8679 - val_loss: 0.0796 - val_binary_io_u_1: 0.8797
# Epoch 26/35
# 46/46 [==============================] - ETA: 0s - loss: 0.0840 - binary_io_u_1: 0.8700
# Epoch 26: val_loss did not improve from 0.07785
# 46/46 [==============================] - 64s 1s/step - loss: 0.0840 - binary_io_u_1: 0.8700 - val_loss: 0.0793 - val_binary_io_u_1: 0.8665
# Epoch 27/35
# 46/46 [==============================] - ETA: 0s - loss: 0.0827 - binary_io_u_1: 0.8703
# Epoch 27: val_loss did not improve from 0.07785
# 46/46 [==============================] - 62s 1s/step - loss: 0.0827 - binary_io_u_1: 0.8703 - val_loss: 0.0912 - val_binary_io_u_1: 0.8631
# Epoch 28/35
# 46/46 [==============================] - ETA: 0s - loss: 0.0853 - binary_io_u_1: 0.8662
# Epoch 28: val_loss improved from 0.07785 to 0.07622, saving model to model-UNetEp=0Model_20230330.h5
# 46/46 [==============================] - 61s 1s/step - loss: 0.0853 - binary_io_u_1: 0.8662 - val_loss: 0.0762 - val_binary_io_u_1: 0.8823
# Epoch 29/35
# 46/46 [==============================] - ETA: 0s - loss: 0.0820 - binary_io_u_1: 0.8709
# Epoch 29: val_loss did not improve from 0.07622
# 46/46 [==============================] - 62s 1s/step - loss: 0.0820 - binary_io_u_1: 0.8709 - val_loss: 0.0764 - val_binary_io_u_1: 0.8796
# Epoch 30/35
# 46/46 [==============================] - ETA: 0s - loss: 0.0814 - binary_io_u_1: 0.8718
# Epoch 30: val_loss improved from 0.07622 to 0.07441, saving model to model-UNetEp=0Model_20230330.h5
# 46/46 [==============================] - 62s 1s/step - loss: 0.0814 - binary_io_u_1: 0.8718 - val_loss: 0.0744 - val_binary_io_u_1: 0.8835
# Epoch 31/35
# 46/46 [==============================] - ETA: 0s - loss: 0.0803 - binary_io_u_1: 0.8728
# Epoch 31: val_loss improved from 0.07441 to 0.07435, saving model to model-UNetEp=0Model_20230330.h5
# 46/46 [==============================] - 62s 1s/step - loss: 0.0803 - binary_io_u_1: 0.8728 - val_loss: 0.0743 - val_binary_io_u_1: 0.8761
# Epoch 32/35
# 46/46 [==============================] - ETA: 0s - loss: 0.0804 - binary_io_u_1: 0.8729
# Epoch 32: val_loss did not improve from 0.07435
# 46/46 [==============================] - 62s 1s/step - loss: 0.0804 - binary_io_u_1: 0.8729 - val_loss: 0.0793 - val_binary_io_u_1: 0.8785
# Epoch 33/35
# 46/46 [==============================] - ETA: 0s - loss: 0.0819 - binary_io_u_1: 0.8711
# Epoch 33: val_loss did not improve from 0.07435
# 46/46 [==============================] - 62s 1s/step - loss: 0.0819 - binary_io_u_1: 0.8711 - val_loss: 0.0756 - val_binary_io_u_1: 0.8824
# Epoch 34/35
# 46/46 [==============================] - ETA: 0s - loss: 0.0788 - binary_io_u_1: 0.8735
# Epoch 34: val_loss improved from 0.07435 to 0.07342, saving model to model-UNetEp=0Model_20230330.h5
# 46/46 [==============================] - 62s 1s/step - loss: 0.0788 - binary_io_u_1: 0.8735 - val_loss: 0.0734 - val_binary_io_u_1: 0.8800
# Epoch 35/35
# 46/46 [==============================] - ETA: 0s - loss: 0.0782 - binary_io_u_1: 0.8744
# Epoch 35: val_loss did not improve from 0.07342
# 46/46 [==============================] - 62s 1s/step - loss: 0.0782 - binary_io_u_1: 0.8744 - val_loss: 0.0751 - val_binary_io_u_1: 0.8751

# %%
# ALTER THE NAMING CONVENTIONS..
def plot_training(hist):
    '''
    This function take training model and plot history of accuracy and losses with the best epoch in both of them.
    '''

    # Define needed variables--> these two need to be diff
    tr_acc = hist.history['binary_io_u_1']
    tr_loss = hist.history['loss']
    val_acc = hist.history['val_binary_io_u_1']
    val_loss = hist.history['val_loss']
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]
    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'

    # Plot training history
    plt.figure(figsize= (20, 8))
    plt.style.use('fivethirtyeight')

    plt.subplot(1, 2, 1)
    plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
    plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
    plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training and Validation Binary IOU')
    plt.xlabel('Epochs')
    plt.ylabel('Binary IOU')
    plt.legend()

    # change the title!!
    plt.suptitle("Unet trained with Ep = 0", fontsize=30)
    plt.tight_layout
    plt.savefig('model-UNetEp=0Model_20230330.png')
    plt.show()

# %%
# results.history
plot_training(result)

# %%
# we could stop here...
